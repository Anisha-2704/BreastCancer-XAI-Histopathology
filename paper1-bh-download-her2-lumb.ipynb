# %%
import subprocess
import sys
import os
import json
import requests
import numpy as np
import pandas as pd

# ============================================================
# STEP 0 — Install system dependencies
# ============================================================
print("Installing system dependencies...")
subprocess.run(["apt-get", "install", "-y", "-q", "openslide-tools"],
               check=True, capture_output=True)
subprocess.run([sys.executable, "-m", "pip", "install", "openslide-python", "-q"],
               check=True, capture_output=True)

import openslide
print(f"openslide: {openslide.__version__} ✓")

# ============================================================
# STEP 1 — Setup directories + load clinical data
# ============================================================
OUTPUT_DIR = "/kaggle/working/output"
SVS_DIR = "/kaggle/working/svs"
PATCHES_DIR = "/kaggle/working/patches/BH/BLOCKS_NORM_MACENKO"
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(SVS_DIR, exist_ok=True)
os.makedirs(PATCHES_DIR, exist_ok=True)

SUBTYPE_MAP = {
    "BRCA_LumA": "LumA", "BRCA_LumB": "LumB",
    "BRCA_Her2": "Her2", "BRCA_Basal": "Basal"
}

# Find clinical file by walking input — don't hardcode path
clinical_path = None
for root, dirs, files in os.walk("/kaggle/input"):
    dirs[:] = [d for d in dirs if d != "BLOCKS_NORM_MACENKO"]
    for f in files:
        if f == "data_clinical_patient.txt":
            clinical_path = os.path.join(root, f)
            break
    if clinical_path:
        break

print(f"Clinical file found: {clinical_path}")
assert clinical_path is not None, "Clinical file not found — check dataset is attached"

df_clinical = pd.read_csv(clinical_path, sep="\t", comment="#", low_memory=False)

bh = df_clinical[df_clinical["PATIENT_ID"].str.startswith("TCGA-BH-")].copy()
bh["subtype_mapped"] = bh["SUBTYPE"].map(SUBTYPE_MAP)
bh_valid = bh[bh["subtype_mapped"].notna()].copy()

target_subtypes = ["Her2", "LumB"]
bh_target = bh_valid[bh_valid["subtype_mapped"].isin(target_subtypes)]
target_patient_ids = bh_target["PATIENT_ID"].tolist()

print(f"BH target patients: {len(target_patient_ids)}")
print(f"  Her2: {(bh_target['subtype_mapped']=='Her2').sum()}")
print(f"  LumB: {(bh_target['subtype_mapped']=='LumB').sum()}")

# ============================================================
# STEP 2 — Query GDC for DX1 file IDs
# ============================================================
print("\nQuerying GDC API...")
endpoint = "https://api.gdc.cancer.gov/files"
filters = {
    "op": "and",
    "content": [
        {"op": "in", "content": {"field": "cases.submitter_id", "value": target_patient_ids}},
        {"op": "=", "content": {"field": "data_type", "value": "Slide Image"}},
        {"op": "=", "content": {"field": "data_format", "value": "SVS"}},
        {"op": "like", "content": {"field": "file_name", "value": "%DX1%"}}
    ]
}
params = {
    "filters": json.dumps(filters),
    "fields": "file_id,file_name,cases.submitter_id,file_size",
    "format": "JSON",
    "size": 500
}
response = requests.get(endpoint, params=params)
hits = response.json()["data"]["hits"]

manifest = []
for hit in hits:
    case = hit.get("cases", [{}])[0].get("submitter_id", "unknown")
    subtype_vals = bh_target[bh_target["PATIENT_ID"] == case]["subtype_mapped"].values
    if len(subtype_vals) == 0:
        continue
    manifest.append({
        "file_id": hit["file_id"],
        "file_name": hit["file_name"],
        "patient_id": case,
        "subtype": subtype_vals[0],
        "file_size_gb": hit.get("file_size", 0) / 1e9
    })

manifest_df = pd.DataFrame(manifest)
print(f"Found {len(manifest_df)} DX1 slides")
print(manifest_df.groupby("subtype")[["file_id"]].count())
print(f"Total estimated size: {manifest_df['file_size_gb'].sum():.1f} GB")

# ============================================================
# STEP 3 — Macenko normalization (pure numpy, no staintools)
# ============================================================
def macenko_normalize(img, Io=240, alpha=1, beta=0.15):
    HERef = np.array([[0.5626, 0.2159],
                      [0.7201, 0.8012],
                      [0.4062, 0.5581]])
    maxCRef = np.array([1.9705, 1.0308])

    img = img.astype(np.float64)
    img = np.clip(img, 1, 255)
    OD = -np.log(img / Io)
    ODhat = OD.reshape(-1, 3)
    ODhat = ODhat[~np.any(ODhat < beta, axis=1)]

    if len(ODhat) < 10:
        return img.astype(np.uint8)

    _, _, V = np.linalg.svd(ODhat, full_matrices=False)
    V = V[:2].T
    That = ODhat @ V
    phi = np.arctan2(That[:, 1], That[:, 0])
    minPhi = np.percentile(phi, alpha)
    maxPhi = np.percentile(phi, 100 - alpha)
    vMin = V @ np.array([np.cos(minPhi), np.sin(minPhi)])
    vMax = V @ np.array([np.cos(maxPhi), np.sin(maxPhi)])

    if vMin[0] > vMax[0]:
        HE = np.array([vMin, vMax]).T
    else:
        HE = np.array([vMax, vMin]).T

    OD_flat = OD.reshape(-1, 3)
    C = np.linalg.lstsq(HE, OD_flat.T, rcond=None)[0]
    maxC = np.percentile(C, 99, axis=1)
    maxC = np.where(maxC == 0, 1e-6, maxC)
    C = C / maxC[:, np.newaxis] * maxCRef[:, np.newaxis]

    with np.errstate(over="ignore"):
        Inorm = Io * np.exp(-HERef @ C)
    Inorm = np.clip(Inorm, 0, 255).T.reshape(img.shape).astype(np.uint8)
    return Inorm

# ============================================================
# STEP 4 — Tissue detection
# ============================================================
def is_tissue_patch(img, threshold=0.5, sat_threshold=20):
    from skimage.color import rgb2hsv
    hsv = rgb2hsv(img)
    return np.mean(hsv[:, :, 1] > sat_threshold / 255.0) > threshold

# ============================================================
# STEP 5 — Patch extraction from one SVS
# ============================================================
def extract_patches_from_svs(svs_path, patient_id, subtype,
                              patches_base_dir, patch_size=256,
                              target_mpp=1.0, max_patches=2000):
    from PIL import Image as PILImage
    slide = openslide.OpenSlide(svs_path)

    mpp_x = float(slide.properties.get(openslide.PROPERTY_NAME_MPP_X, 0.5))
    level = slide.get_best_level_for_downsample(mpp_x / target_mpp)
    level_downsample = slide.level_downsamples[level]
    actual_mpp = mpp_x * level_downsample
    patch_size_level0 = int(patch_size * (target_mpp / mpp_x))

    w0, h0 = slide.dimensions
    patch_dir = os.path.join(patches_base_dir, patient_id)
    os.makedirs(patch_dir, exist_ok=True)

    coords = [(x, y)
              for x in range(0, w0 - patch_size_level0, patch_size_level0)
              for y in range(0, h0 - patch_size_level0, patch_size_level0)]

    np.random.seed(42)
    np.random.shuffle(coords)

    patches_meta = []
    extracted = 0
    skipped_bg = 0

    for x, y in coords:
        if extracted >= max_patches:
            break
        patch = slide.read_region((x, y), level, (patch_size, patch_size))
        patch_np = np.array(patch.convert("RGB"))

        if not is_tissue_patch(patch_np):
            skipped_bg += 1
            continue

        try:
            patch_norm = macenko_normalize(patch_np)
        except Exception:
            patch_norm = patch_np

        fname = f"{patient_id}_({x},{y}).jpg"
        fpath = os.path.join(patch_dir, fname)
        PILImage.fromarray(patch_norm).save(fpath, quality=95)

        patches_meta.append({
            "patient_id": patient_id,
            "subtype_clean": subtype,
            "institution": "BH",
            "patch_path": fpath,
            "x": x, "y": y,
            "actual_mpp": round(actual_mpp, 4)
        })
        extracted += 1

    slide.close()
    print(f"  {patient_id} ({subtype}): {extracted} patches, {skipped_bg} background skipped")
    return patches_meta

# ============================================================
# STEP 6 — Download one SVS at a time → extract → delete
# ============================================================
def download_svs(file_id, file_name, dest_dir):
    url = f"https://api.gdc.cancer.gov/data/{file_id}"
    dest_path = os.path.join(dest_dir, file_name)
    response = requests.get(url, stream=True, timeout=3600)
    response.raise_for_status()
    with open(dest_path, "wb") as f:
        for chunk in response.iter_content(chunk_size=8 * 1024 * 1024):
            if chunk:
                f.write(chunk)
    return dest_path

all_patches_meta = []
failed_files = []

print(f"\nStarting: {len(manifest_df)} slides, download one → extract → delete → repeat")

for idx, row in manifest_df.iterrows():
    file_id = row["file_id"]
    file_name = row["file_name"]
    patient_id = row["patient_id"]
    subtype = row["subtype"]
    size_gb = row["file_size_gb"]

    print(f"\n[{idx+1}/{len(manifest_df)}] {patient_id} ({subtype}) | {size_gb:.2f} GB")

    statvfs = os.statvfs("/kaggle/working")
    free_gb = (statvfs.f_frsize * statvfs.f_bavail) / 1e9
    print(f"  Free disk: {free_gb:.1f} GB")

    if free_gb < size_gb + 1.5:
        print(f"  SKIPPING — not enough disk space")
        failed_files.append({"file_id": file_id, "patient_id": patient_id,
                             "subtype": subtype, "reason": "disk_full"})
        continue

    try:
        print(f"  Downloading...")
        svs_path = download_svs(file_id, file_name, SVS_DIR)
        print(f"  Downloaded: {os.path.getsize(svs_path)/1e9:.2f} GB")
    except Exception as e:
        print(f"  DOWNLOAD FAILED: {e}")
        failed_files.append({"file_id": file_id, "patient_id": patient_id,
                             "subtype": subtype, "reason": f"download_failed: {e}"})
        continue

    try:
        meta = extract_patches_from_svs(
            svs_path, patient_id, subtype,
            PATCHES_DIR, patch_size=256, target_mpp=1.0, max_patches=2000
        )
        all_patches_meta.extend(meta)
    except Exception as e:
        print(f"  EXTRACTION FAILED: {e}")
        failed_files.append({"file_id": file_id, "patient_id": patient_id,
                             "subtype": subtype, "reason": f"extraction_error: {e}"})

    os.remove(svs_path)
    print(f"  SVS deleted. Total patches so far: {len(all_patches_meta)}")

# ============================================================
# STEP 7 — Save all outputs
# ============================================================
patches_df = pd.DataFrame(all_patches_meta)
print(f"\nTotal BH patches extracted: {len(patches_df)}")
if len(patches_df) > 0:
    print(patches_df["subtype_clean"].value_counts())

patches_df.to_csv(os.path.join(OUTPUT_DIR, "bh_her2_lumb_patches.csv"), index=False)

if failed_files:
    pd.DataFrame(failed_files).to_csv(
        os.path.join(OUTPUT_DIR, "bh_failed_files.csv"), index=False)
    print(f"Failed: {len(failed_files)} — see bh_failed_files.csv")

print(f"\nOutputs in {OUTPUT_DIR}/:")
for f in sorted(os.listdir(OUTPUT_DIR)):
    size = os.path.getsize(os.path.join(OUTPUT_DIR, f)) / 1e6
    print(f"  - {f} ({size:.1f} MB)")

print("\nDone. Next: create Dataset from output → then A8 notebook.")
# Out:
# Installing system dependencies...
# openslide: 1.4.6 ✓
# Clinical file found: /kaggle/input/datasets/anishapanja/brca-pancancer-atlas-clinical/data_clinical_patient.txt
# BH target patients: 31
#   Her2: 8
#   LumB: 23
#
# Querying GDC API...
# Found 122 DX1 slides
#          file_id
# subtype
# Her2          35
# LumB          87
# Total estimated size: 64.5 GB
#
# Starting: 122 slides, download one → extract → delete → repeat
#
# [1/122] TCGA-BH-A0BZ (LumB) | 0.74 GB
#   Free disk: 20.9 GB
#   Downloading...
#   Downloaded: 0.74 GB
#   TCGA-BH-A0BZ (LumB): 1701 patches, 5787 background skipped
#   SVS deleted. Total patches so far: 1701
#
# [2/122] TCGA-BH-A1F8 (LumB) | 2.01 GB
#   Free disk: 20.9 GB
#   Downloading...
#   Downloaded: 2.01 GB
#   TCGA-BH-A1F8 (LumB): 2000 patches, 2653 background skipped
#   SVS deleted. Total patches so far: 3701
#
# [3/122] TCGA-BH-A1F8 (LumB) | 0.06 GB
#   Free disk: 20.9 GB
#   Downloading...
#   Downloaded: 0.06 GB
#   TCGA-BH-A1F8 (LumB): 97 patches, 3261 background skipped
#   SVS deleted. Total patches so far: 3798
#
# [4/122] TCGA-BH-A0H0 (LumB) | 0.93 GB
#   Free disk: 20.9 GB
#   Downloading...
#   Downloaded: 0.93 GB
#   TCGA-BH-A0H0 (LumB): 1671 patches, 7079 background skipped
#   SVS deleted. Total patches so far: 5469
#
# [5/122] TCGA-BH-A0H0 (LumB) | 0.99 GB
#   Free disk: 20.8 GB
#   Downloading...
#   Downloaded: 0.99 GB
#   TCGA-BH-A0H0 (LumB): 1397 patches, 8043 background skipped
#   SVS deleted. Total patches so far: 6866
#
# [6/122] TCGA-BH-A0BF (LumB) | 0.61 GB
#   Free disk: 20.8 GB
#   Downloading...
#   Downloaded: 0.61 GB
#   TCGA-BH-A0BF (LumB): 984 patches, 7101 background skipped
#   SVS deleted. Total patches so far: 7850
#
# [7/122] TCGA-BH-A0BF (LumB) | 0.10 GB
#   Free disk: 20.7 GB
#   Downloading...
#   Downloaded: 0.10 GB
#   TCGA-BH-A0BF (LumB): 286 patches, 4745 background skipped
#   SVS deleted. Total patches so far: 8136
#
# [8/122] TCGA-BH-A209 (LumB) | 0.05 GB
#   Free disk: 20.7 GB
#   Downloading...
#   Downloaded: 0.05 GB
#   TCGA-BH-A209 (LumB): 49 patches, 3251 background skipped
#   SVS deleted. Total patches so far: 8185
#
# [9/122] TCGA-BH-A209 (LumB) | 2.49 GB
#   Free disk: 20.7 GB
#   Downloading...
#   Downloaded: 2.49 GB
#   TCGA-BH-A209 (LumB): 2000 patches, 2869 background skipped
#   SVS deleted. Total patches so far: 10185
#
# [10/122] TCGA-BH-A18L (LumB) | 0.27 GB
#   Free disk: 20.7 GB
#   Downloading...
#   Downloaded: 0.27 GB
#   TCGA-BH-A18L (LumB): 679 patches, 2111 background skipped
#   SVS deleted. Total patches so far: 10864
#
# [11/122] TCGA-BH-A18L (LumB) | 0.08 GB
#   Free disk: 20.7 GB
#   Downloading...
#   Downloaded: 0.08 GB
#   TCGA-BH-A18L (LumB): 227 patches, 4687 background skipped
#   SVS deleted. Total patches so far: 11091
#
# [12/122] TCGA-BH-A18L (LumB) | 0.05 GB
#   Free disk: 20.6 GB
#   Downloading...
#   Downloaded: 0.05 GB
#   TCGA-BH-A18L (LumB): 80 patches, 3490 background skipped
#   SVS deleted. Total patches so far: 11171
#
# [13/122] TCGA-BH-A1FD (LumB) | 0.10 GB
#   Free disk: 20.6 GB
#   Downloading...
#   Downloaded: 0.10 GB
#   TCGA-BH-A1FD (LumB): 537 patches, 4137 background skipped
#   SVS deleted. Total patches so far: 11708
#
# [14/122] TCGA-BH-A1FD (LumB) | 0.06 GB
#   Free disk: 20.6 GB
#   Downloading...
#   Downloaded: 0.06 GB
#   TCGA-BH-A1FD (LumB): 237 patches, 2753 background skipped
#   SVS deleted. Total patches so far: 11945
#
# [15/122] TCGA-BH-A0BF (LumB) | 0.10 GB
#   Free disk: 20.6 GB
#   Downloading...
#   Downloaded: 0.10 GB
#   TCGA-BH-A0BF (LumB): 102 patches, 3288 background skipped
#   SVS deleted. Total patches so far: 12047
#
# [16/122] TCGA-BH-A0BF (LumB) | 1.64 GB
#   Free disk: 20.6 GB
#   Downloading...
#   Downloaded: 1.64 GB
#   TCGA-BH-A0BF (LumB): 2000 patches, 3115 background skipped
#   SVS deleted. Total patches so far: 14047
#
# [17/122] TCGA-BH-A0BF (LumB) | 0.16 GB
#   Free disk: 20.6 GB
#   Downloading...
#   Downloaded: 0.16 GB
#   TCGA-BH-A0BF (LumB): 1359 patches, 7362 background skipped
#   SVS deleted. Total patches so far: 15406
#
# [18/122] TCGA-BH-A209 (LumB) | 0.10 GB
#   Free disk: 20.5 GB
#   Downloading...
#   Downloaded: 0.10 GB
#   TCGA-BH-A209 (LumB): 71 patches, 1183 background skipped
#   SVS deleted. Total patches so far: 15477
#
# [19/122] TCGA-BH-A18L (LumB) | 1.33 GB
#   Free disk: 20.5 GB
#   Downloading...
#   Downloaded: 1.33 GB
#   TCGA-BH-A18L (LumB): 2000 patches, 2441 background skipped
#   SVS deleted. Total patches so far: 17477
#
# [20/122] TCGA-BH-A0BZ (LumB) | 0.13 GB
#   Free disk: 20.5 GB
#   Downloading...
#   Downloaded: 0.13 GB
#   TCGA-BH-A0BZ (LumB): 8 patches, 7692 background skipped
#   SVS deleted. Total patches so far: 17485
#
# [21/122] TCGA-BH-A0BZ (LumB) | 0.63 GB
#   Free disk: 20.5 GB
#   Downloading...
#   Downloaded: 0.63 GB
#   TCGA-BH-A0BZ (LumB): 1750 patches, 3002 background skipped
#   SVS deleted. Total patches so far: 19235
#
# [22/122] TCGA-BH-A1EN (Her2) | 0.10 GB
#   Free disk: 20.5 GB
#   Downloading...
#   Downloaded: 0.10 GB
#   TCGA-BH-A1EN (Her2): 344 patches, 4213 background skipped
#   SVS deleted. Total patches so far: 19579
#
# [23/122] TCGA-BH-A1F2 (LumB) | 0.07 GB
#   Free disk: 20.4 GB
#   Downloading...
#   Downloaded: 0.07 GB
#   TCGA-BH-A1F2 (LumB): 252 patches, 2529 background skipped
#   SVS deleted. Total patches so far: 19831
#
# [24/122] TCGA-BH-A0HW (LumB) | 0.67 GB
#   Free disk: 20.4 GB
#   Downloading...
#   Downloaded: 0.67 GB
#   TCGA-BH-A0HW (LumB): 1174 patches, 6008 background skipped
#   SVS deleted. Total patches so far: 21005
#
# [25/122] TCGA-BH-A0C3 (LumB) | 0.28 GB
#   Free disk: 20.4 GB
#   Downloading...
#   Downloaded: 0.28 GB
#   TCGA-BH-A0C3 (LumB): 509 patches, 2507 background skipped
#   SVS deleted. Total patches so far: 21514
#
# [26/122] TCGA-BH-A0C3 (LumB) | 0.24 GB
#   Free disk: 20.4 GB
#   Downloading...
#   Downloaded: 0.24 GB
#   TCGA-BH-A0C3 (LumB): 554 patches, 2391 background skipped
#   SVS deleted. Total patches so far: 22068
#
# [27/122] TCGA-BH-A0C3 (LumB) | 0.09 GB
#   Free disk: 20.4 GB
#   Downloading...
#   Downloaded: 0.09 GB
#   TCGA-BH-A0C3 (LumB): 683 patches, 3046 background skipped
#   SVS deleted. Total patches so far: 22751
#
# [28/122] TCGA-BH-A0C7 (LumB) | 0.22 GB
#   Free disk: 20.4 GB
#   Downloading...
#   Downloaded: 0.22 GB
#   TCGA-BH-A0C7 (LumB): 375 patches, 2635 background skipped
#   SVS deleted. Total patches so far: 23126
#
# [29/122] TCGA-BH-A0HW (LumB) | 0.72 GB
#   Free disk: 20.4 GB
#   Downloading...
#   Downloaded: 0.72 GB
#   TCGA-BH-A0HW (LumB): 1495 patches, 6508 background skipped
#   SVS deleted. Total patches so far: 24621
#
# [30/122] TCGA-BH-A0HW (LumB) | 1.64 GB
#   Free disk: 20.3 GB
#   Downloading...
#   Downloaded: 1.64 GB
#   TCGA-BH-A0HW (LumB): 2000 patches, 4693 background skipped
#   SVS deleted. Total patches so far: 26621
#
# [31/122] TCGA-BH-A0C3 (LumB) | 1.08 GB
#   Free disk: 20.3 GB
#   Downloading...
#   Downloaded: 1.08 GB
#   TCGA-BH-A0C3 (LumB): 2000 patches, 7291 background skipped
#   SVS deleted. Total patches so far: 28621
#
# [32/122] TCGA-BH-A0C3 (LumB) | 0.22 GB
#   Free disk: 20.2 GB
#   Downloading...
#   Downloaded: 0.22 GB
#   TCGA-BH-A0C3 (LumB): 801 patches, 837 background skipped
#   SVS deleted. Total patches so far: 29422
#
# [33/122] TCGA-BH-A1FM (LumB) | 0.18 GB
#   Free disk: 20.2 GB
#   Downloading...
#   Downloaded: 0.18 GB
#   TCGA-BH-A1FM (LumB): 357 patches, 1843 background skipped
#   SVS deleted. Total patches so far: 29779
#
# [34/122] TCGA-BH-A0C7 (LumB) | 1.74 GB
#   Free disk: 20.2 GB
#   Downloading...
#   Downloaded: 1.74 GB
#   TCGA-BH-A0C7 (LumB): 2000 patches, 2237 background skipped
#   SVS deleted. Total patches so far: 31779
#
# [35/122] TCGA-BH-A0AU (LumB) | 0.06 GB
#   Free disk: 20.1 GB
#   Downloading...
#   Downloaded: 0.06 GB
#   TCGA-BH-A0AU (LumB): 227 patches, 3007 background skipped
#   SVS deleted. Total patches so far: 32006
#
# [36/122] TCGA-BH-A0HY (LumB) | 0.39 GB
#   Free disk: 20.1 GB
#   Downloading...
#   Downloaded: 0.39 GB
#   TCGA-BH-A0HY (LumB): 953 patches, 2860 background skipped
#   SVS deleted. Total patches so far: 32959
#
# [37/122] TCGA-BH-A0C3 (LumB) | 0.23 GB
#   Free disk: 20.1 GB
#   Downloading...
#   Downloaded: 0.23 GB
#   TCGA-BH-A0C3 (LumB): 435 patches, 1721 background skipped
#   SVS deleted. Total patches so far: 33394
#
# [38/122] TCGA-BH-A1FM (LumB) | 0.06 GB
#   Free disk: 20.1 GB
#   Downloading...
#   Downloaded: 0.06 GB
#   TCGA-BH-A1FM (LumB): 386 patches, 2089 background skipped
#   SVS deleted. Total patches so far: 33780
#
# [39/122] TCGA-BH-A1FM (LumB) | 0.87 GB
#   Free disk: 20.1 GB
#   Downloading...
#   Downloaded: 0.87 GB
#   TCGA-BH-A1FM (LumB): 2000 patches, 2209 background skipped
#   SVS deleted. Total patches so far: 35780
#
# [40/122] TCGA-BH-A0C7 (LumB) | 0.26 GB
#   Free disk: 20.0 GB
#   Downloading...
#   Downloaded: 0.26 GB
#   TCGA-BH-A0C7 (LumB): 603 patches, 1920 background skipped
#   SVS deleted. Total patches so far: 36383
#
# [41/122] TCGA-BH-A0AU (LumB) | 0.06 GB
#   Free disk: 20.0 GB
#   Downloading...
#   Downloaded: 0.06 GB
#   TCGA-BH-A0AU (LumB): 510 patches, 1677 background skipped
#   SVS deleted. Total patches so far: 36893
#
# [42/122] TCGA-BH-A1EV (Her2) | 0.11 GB
#   Free disk: 20.0 GB
#   Downloading...
#   Downloaded: 0.11 GB
#   TCGA-BH-A1EV (Her2): 97 patches, 1895 background skipped
#   SVS deleted. Total patches so far: 36990
#
# [43/122] TCGA-BH-A1EV (Her2) | 0.08 GB
#   Free disk: 20.0 GB
#   Downloading...
#   Downloaded: 0.08 GB
#   TCGA-BH-A1EV (Her2): 465 patches, 3087 background skipped
#   SVS deleted. Total patches so far: 37455
#
# [44/122] TCGA-BH-A1EV (Her2) | 1.31 GB
#   Free disk: 20.0 GB
#   Downloading...
#   Downloaded: 1.31 GB
#   TCGA-BH-A1EV (Her2): 2000 patches, 2520 background skipped
#   SVS deleted. Total patches so far: 39455
#
# [45/122] TCGA-BH-A1EV (Her2) | 0.06 GB
#   Free disk: 20.0 GB
#   Downloading...
#   Downloaded: 0.06 GB
#   TCGA-BH-A1EV (Her2): 249 patches, 2541 background skipped
#   SVS deleted. Total patches so far: 39704
#
# [46/122] TCGA-BH-A0HY (LumB) | 0.40 GB
#   Free disk: 19.9 GB
#   Downloading...
#   Downloaded: 0.40 GB
#   TCGA-BH-A0HY (LumB): 891 patches, 3474 background skipped
#   SVS deleted. Total patches so far: 40595
#
# [47/122] TCGA-BH-A204 (LumB) | 0.05 GB
#   Free disk: 19.9 GB
#   Downloading...
#   Downloaded: 0.05 GB
#   TCGA-BH-A204 (LumB): 49 patches, 3056 background skipped
#   SVS deleted. Total patches so far: 40644
#
# [48/122] TCGA-BH-A204 (LumB) | 1.12 GB
#   Free disk: 19.9 GB
#   Downloading...
#   Downloaded: 1.12 GB
#   TCGA-BH-A204 (LumB): 2000 patches, 1859 background skipped
#   SVS deleted. Total patches so far: 42644
#
# [49/122] TCGA-BH-A18U (LumB) | 0.22 GB
#   Free disk: 19.9 GB
#   Downloading...
#   Downloaded: 0.22 GB
#   TCGA-BH-A18U (LumB): 403 patches, 1613 background skipped
#   SVS deleted. Total patches so far: 43047
#
# [50/122] TCGA-BH-A0B7 (Her2) | 0.62 GB
#   Free disk: 19.9 GB
#   Downloading...
#   Downloaded: 0.62 GB
#   TCGA-BH-A0B7 (Her2): 1241 patches, 5424 background skipped
#   SVS deleted. Total patches so far: 44288
#
# [51/122] TCGA-BH-A18P (Her2) | 0.40 GB
#   Free disk: 19.8 GB
#   Downloading...
#   Downloaded: 0.40 GB
#   TCGA-BH-A18P (Her2): 865 patches, 2575 background skipped
#   SVS deleted. Total patches so far: 45153
#
# [52/122] TCGA-BH-A18P (Her2) | 0.07 GB
#   Free disk: 19.8 GB
#   Downloading...
#   Downloaded: 0.07 GB
#   TCGA-BH-A18P (Her2): 198 patches, 3058 background skipped
#   SVS deleted. Total patches so far: 45351
#
# [53/122] TCGA-BH-A204 (LumB) | 0.21 GB
#   Free disk: 19.8 GB
#   Downloading...
#   Downloaded: 0.21 GB
#   TCGA-BH-A204 (LumB): 439 patches, 2081 background skipped
#   SVS deleted. Total patches so far: 45790
#
# [54/122] TCGA-BH-A0B7 (Her2) | 0.54 GB
#   Free disk: 19.8 GB
#   Downloading...
#   Downloaded: 0.54 GB
#   TCGA-BH-A0B7 (Her2): 1087 patches, 4217 background skipped
#   SVS deleted. Total patches so far: 46877
#
# [55/122] TCGA-BH-A18U (LumB) | 0.09 GB
#   Free disk: 19.8 GB
#   Downloading...
#   Downloaded: 0.09 GB
#   TCGA-BH-A18U (LumB): 859 patches, 2373 background skipped
#   SVS deleted. Total patches so far: 47736
#
# [56/122] TCGA-BH-A18U (LumB) | 0.07 GB
#   Free disk: 19.8 GB
#   Downloading...
#   Downloaded: 0.07 GB
#   TCGA-BH-A18U (LumB): 286 patches, 3386 background skipped
#   SVS deleted. Total patches so far: 48022
#
# [57/122] TCGA-BH-A18P (Her2) | 1.43 GB
#   Free disk: 19.7 GB
#   Downloading...
#   Downloaded: 1.43 GB
#   TCGA-BH-A18P (Her2): 2000 patches, 4294 background skipped
#   SVS deleted. Total patches so far: 50022
#
# [58/122] TCGA-BH-A18P (Her2) | 0.08 GB
#   Free disk: 19.7 GB
#   Downloading...
#   Downloaded: 0.08 GB
#   TCGA-BH-A18P (Her2): 434 patches, 3886 background skipped
#   SVS deleted. Total patches so far: 50456
#
# [59/122] TCGA-BH-A18P (Her2) | 0.07 GB
#   Free disk: 19.7 GB
#   Downloading...
#   Downloaded: 0.07 GB
#   TCGA-BH-A18P (Her2): 168 patches, 3552 background skipped
#   SVS deleted. Total patches so far: 50624
#
# [60/122] TCGA-BH-A0B7 (Her2) | 0.92 GB
#   Free disk: 19.7 GB
#   Downloading...
#   Downloaded: 0.92 GB
#   TCGA-BH-A0B7 (Her2): 2000 patches, 4261 background skipped
#   SVS deleted. Total patches so far: 52624
#
# [61/122] TCGA-BH-A18U (LumB) | 1.61 GB
#   Free disk: 19.6 GB
#   Downloading...
#   Downloaded: 1.61 GB
#   TCGA-BH-A18U (LumB): 2000 patches, 5285 background skipped
#   SVS deleted. Total patches so far: 54624
#
# [62/122] TCGA-BH-A0B7 (Her2) | 0.09 GB
#   Free disk: 19.6 GB
#   Downloading...
#   Downloaded: 0.09 GB
#   TCGA-BH-A0B7 (Her2): 501 patches, 3573 background skipped
#   SVS deleted. Total patches so far: 55125
#
# [63/122] TCGA-BH-A0B7 (Her2) | 0.04 GB
#   Free disk: 19.6 GB
#   Downloading...
#   Downloaded: 0.04 GB
#   TCGA-BH-A0B7 (Her2): 143 patches, 1897 background skipped
#   SVS deleted. Total patches so far: 55268
#
# [64/122] TCGA-BH-A18P (Her2) | 0.09 GB
#   Free disk: 19.6 GB
#   Downloading...
#   Downloaded: 0.09 GB
#   TCGA-BH-A18P (Her2): 319 patches, 3905 background skipped
#   SVS deleted. Total patches so far: 55587
#
# [65/122] TCGA-BH-A0HU (LumB) | 0.40 GB
#   Free disk: 19.6 GB
#   Downloading...
#   Downloaded: 0.40 GB
#   TCGA-BH-A0HU (LumB): 514 patches, 5063 background skipped
#   SVS deleted. Total patches so far: 56101
#
# [66/122] TCGA-BH-A0HU (LumB) | 1.00 GB
#   Free disk: 19.5 GB
#   Downloading...
#   Downloaded: 1.00 GB
#   TCGA-BH-A0HU (LumB): 1840 patches, 5428 background skipped
#   SVS deleted. Total patches so far: 57941
#
# [67/122] TCGA-BH-A0AU (LumB) | 0.37 GB
#   Free disk: 19.5 GB
#   Downloading...
#   Downloaded: 0.37 GB
#   TCGA-BH-A0AU (LumB): 783 patches, 2399 background skipped
#   SVS deleted. Total patches so far: 58724
#
# [68/122] TCGA-BH-A0AU (LumB) | 0.51 GB
#   Free disk: 19.5 GB
#   Downloading...
#   Downloaded: 0.51 GB
#   TCGA-BH-A0AU (LumB): 1246 patches, 2554 background skipped
#   SVS deleted. Total patches so far: 59970
#
# [69/122] TCGA-BH-A0AU (LumB) | 1.23 GB
#   Free disk: 19.4 GB
#   Downloading...
#   Downloaded: 1.23 GB
#   TCGA-BH-A0AU (LumB): 2000 patches, 3904 background skipped
#   SVS deleted. Total patches so far: 61970
#
# [70/122] TCGA-BH-A1EV (Her2) | 0.05 GB
#   Free disk: 19.4 GB
#   Downloading...
#   Downloaded: 0.05 GB
#   TCGA-BH-A1EV (Her2): 237 patches, 1947 background skipped
#   SVS deleted. Total patches so far: 62207
#
# [71/122] TCGA-BH-A0HY (LumB) | 1.52 GB
#   Free disk: 19.4 GB
#   Downloading...
#   Downloaded: 1.52 GB
#   TCGA-BH-A0HY (LumB): 2000 patches, 5077 background skipped
#   SVS deleted. Total patches so far: 64207
#
# [72/122] TCGA-BH-A0EE (Her2) | 0.66 GB
#   Free disk: 19.3 GB
#   Downloading...
#   Downloaded: 0.66 GB
#   TCGA-BH-A0EE (Her2): 929 patches, 7135 background skipped
#   SVS deleted. Total patches so far: 65136
#
# [73/122] TCGA-BH-A0W3 (LumB) | 0.27 GB
#   Free disk: 19.3 GB
#   Downloading...
#   Downloaded: 0.27 GB
#   TCGA-BH-A0W3 (LumB): 573 patches, 2053 background skipped
#   SVS deleted. Total patches so far: 65709
#
# [74/122] TCGA-BH-A0W3 (LumB) | 0.30 GB
#   Free disk: 19.3 GB
#   Downloading...
#   Downloaded: 0.30 GB
#   TCGA-BH-A0W3 (LumB): 835 patches, 2203 background skipped
#   SVS deleted. Total patches so far: 66544
#
# [75/122] TCGA-BH-A203 (Her2) | 1.49 GB
#   Free disk: 19.3 GB
#   Downloading...
#   Downloaded: 1.49 GB
#   TCGA-BH-A203 (Her2): 2000 patches, 4454 background skipped
#   SVS deleted. Total patches so far: 68544
#
# [76/122] TCGA-BH-A1FJ (LumB) | 0.25 GB
#   Free disk: 19.2 GB
#   Downloading...
#   Downloaded: 0.25 GB
#   TCGA-BH-A1FJ (LumB): 467 patches, 2447 background skipped
#   SVS deleted. Total patches so far: 69011
#
# [77/122] TCGA-BH-A1FJ (LumB) | 0.04 GB
#   Free disk: 19.2 GB
#   Downloading...
#   Downloaded: 0.04 GB
#   TCGA-BH-A1FJ (LumB): 249 patches, 1315 background skipped
#   SVS deleted. Total patches so far: 69260
#
# [78/122] TCGA-BH-A1FJ (LumB) | 0.07 GB
#   Free disk: 19.2 GB
#   Downloading...
#   Downloaded: 0.07 GB
#   TCGA-BH-A1FJ (LumB): 227 patches, 2813 background skipped
#   SVS deleted. Total patches so far: 69487
#
# [79/122] TCGA-BH-A1FJ (LumB) | 0.05 GB
#   Free disk: 19.2 GB
#   Downloading...
#   Downloaded: 0.05 GB
#   TCGA-BH-A1FJ (LumB): 110 patches, 2959 background skipped
#   SVS deleted. Total patches so far: 69597
#
# [80/122] TCGA-BH-A1FJ (LumB) | 1.68 GB
#   Free disk: 19.2 GB
#   Downloading...
#   Downloaded: 1.68 GB
#   TCGA-BH-A1FJ (LumB): 2000 patches, 3136 background skipped
#   SVS deleted. Total patches so far: 71597
#
# [81/122] TCGA-BH-A18R (Her2) | 1.78 GB
#   Free disk: 19.1 GB
#   Downloading...
#   Downloaded: 1.78 GB
#   TCGA-BH-A18R (Her2): 2000 patches, 1639 background skipped
#   SVS deleted. Total patches so far: 73597
#
# [82/122] TCGA-BH-A18R (Her2) | 0.08 GB
#   Free disk: 19.1 GB
#   Downloading...
#   Downloaded: 0.08 GB
#   TCGA-BH-A18R (Her2): 397 patches, 3779 background skipped
#   SVS deleted. Total patches so far: 73994
#
# [83/122] TCGA-BH-A18R (Her2) | 0.07 GB
#   Free disk: 19.0 GB
#   Downloading...
#   Downloaded: 0.07 GB
#   TCGA-BH-A18R (Her2): 313 patches, 3783 background skipped
#   SVS deleted. Total patches so far: 74307
#
# [84/122] TCGA-BH-A202 (LumB) | 1.67 GB
#   Free disk: 19.0 GB
#   Downloading...
#   Downloaded: 1.67 GB
#   TCGA-BH-A202 (LumB): 2000 patches, 5097 background skipped
#   SVS deleted. Total patches so far: 76307
#
# [85/122] TCGA-BH-A0AW (Her2) | 0.75 GB
#   Free disk: 19.0 GB
#   Downloading...
#   Downloaded: 0.75 GB
#   TCGA-BH-A0AW (Her2): 1853 patches, 4263 background skipped
#   SVS deleted. Total patches so far: 78160
#
# [86/122] TCGA-BH-A0EE (Her2) | 1.69 GB
#   Free disk: 18.9 GB
#   Downloading...
#   Downloaded: 1.69 GB
#   TCGA-BH-A0EE (Her2): 2000 patches, 4237 background skipped
#   SVS deleted. Total patches so far: 80160
#
# [87/122] TCGA-BH-A0W3 (LumB) | 1.71 GB
#   Free disk: 18.9 GB
#   Downloading...
#   Downloaded: 1.71 GB
#   TCGA-BH-A0W3 (LumB): 2000 patches, 5560 background skipped
#   SVS deleted. Total patches so far: 82160
#
# [88/122] TCGA-BH-A203 (Her2) | 0.20 GB
#   Free disk: 18.8 GB
#   Downloading...
#   Downloaded: 0.20 GB
#   TCGA-BH-A203 (Her2): 199 patches, 2768 background skipped
#   SVS deleted. Total patches so far: 82359
#
# [89/122] TCGA-BH-A203 (Her2) | 0.04 GB
#   Free disk: 18.8 GB
#   Downloading...
#   Downloaded: 0.04 GB
#   TCGA-BH-A203 (Her2): 60 patches, 2079 background skipped
#   SVS deleted. Total patches so far: 82419
#
# [90/122] TCGA-BH-A1FJ (LumB) | 0.06 GB
#   Free disk: 18.8 GB
#   Downloading...
#   Downloaded: 0.06 GB
#   TCGA-BH-A1FJ (LumB): 364 patches, 1612 background skipped
#   SVS deleted. Total patches so far: 82783
#
# [91/122] TCGA-BH-A18R (Her2) | 0.05 GB
#   Free disk: 18.8 GB
#   Downloading...
#   Downloaded: 0.05 GB
#   TCGA-BH-A18R (Her2): 363 patches, 2102 background skipped
#   SVS deleted. Total patches so far: 83146
#
# [92/122] TCGA-BH-A18R (Her2) | 0.07 GB
#   Free disk: 18.8 GB
#   Downloading...
#   Downloaded: 0.07 GB
#   TCGA-BH-A18R (Her2): 342 patches, 4138 background skipped
#   SVS deleted. Total patches so far: 83488
#
# [93/122] TCGA-BH-A18R (Her2) | 0.27 GB
#   Free disk: 18.8 GB
#   Downloading...
#   Downloaded: 0.27 GB
#   TCGA-BH-A18R (Her2): 541 patches, 2011 background skipped
#   SVS deleted. Total patches so far: 84029
#
# [94/122] TCGA-BH-A202 (LumB) | 0.32 GB
#   Free disk: 18.8 GB
#   Downloading...
#   Downloaded: 0.32 GB
#   TCGA-BH-A202 (LumB): 464 patches, 3793 background skipped
#   SVS deleted. Total patches so far: 84493
#
# [95/122] TCGA-BH-A0AW (Her2) | 0.76 GB
#   Free disk: 18.8 GB
#   Downloading...
#   Downloaded: 0.76 GB
#   TCGA-BH-A0AW (Her2): 1835 patches, 5591 background skipped
#   SVS deleted. Total patches so far: 86328
#
# [96/122] TCGA-BH-A0AW (Her2) | 1.35 GB
#   Free disk: 18.7 GB
#   Downloading...
#   Downloaded: 1.35 GB
#   TCGA-BH-A0AW (Her2): 2000 patches, 5732 background skipped
#   SVS deleted. Total patches so far: 88328
#
# [97/122] TCGA-BH-A0EE (Her2) | 0.47 GB
#   Free disk: 18.7 GB
#   Downloading...
#   Downloaded: 0.47 GB
#   TCGA-BH-A0EE (Her2): 739 patches, 4277 background skipped
#   SVS deleted. Total patches so far: 89067
#
# [98/122] TCGA-BH-A1FN (LumB) | 1.03 GB
#   Free disk: 18.7 GB
#   Downloading...
#   Downloaded: 1.03 GB
#   TCGA-BH-A1FN (LumB): 2000 patches, 3233 background skipped
#   SVS deleted. Total patches so far: 91067
#
# [99/122] TCGA-BH-A1FN (LumB) | 0.33 GB
#   Free disk: 18.6 GB
#   Downloading...
#   Downloaded: 0.33 GB
#   TCGA-BH-A1FN (LumB): 602 patches, 3205 background skipped
#   SVS deleted. Total patches so far: 91669
#
# [100/122] TCGA-BH-A1FN (LumB) | 0.10 GB
#   Free disk: 18.6 GB
#   Downloading...
#   Downloaded: 0.10 GB
#   TCGA-BH-A1FN (LumB): 727 patches, 3728 background skipped
#   SVS deleted. Total patches so far: 92396
#
# [101/122] TCGA-BH-A0BD (LumB) | 0.33 GB
#   Free disk: 18.6 GB
#   Downloading...
#   Downloaded: 0.33 GB
#   TCGA-BH-A0BD (LumB): 454 patches, 3180 background skipped
#   SVS deleted. Total patches so far: 92850
#
# [102/122] TCGA-BH-A0BD (LumB) | 1.16 GB
#   Free disk: 18.6 GB
#   Downloading...
#   Downloaded: 1.16 GB
#   TCGA-BH-A0BD (LumB): 1493 patches, 7971 background skipped
#   SVS deleted. Total patches so far: 94343
#
# [103/122] TCGA-BH-A0BD (LumB) | 0.40 GB
#   Free disk: 18.5 GB
#   Downloading...
#   Downloaded: 0.40 GB
#   TCGA-BH-A0BD (LumB): 585 patches, 4203 background skipped
#   SVS deleted. Total patches so far: 94928
#
# [104/122] TCGA-BH-A0C0 (LumB) | 0.05 GB
#   Free disk: 18.5 GB
#   Downloading...
#   Downloaded: 0.05 GB
#   TCGA-BH-A0C0 (LumB): 380 patches, 1828 background skipped
#   SVS deleted. Total patches so far: 95308
#
# [105/122] TCGA-BH-A1FD (LumB) | 0.17 GB
#   Free disk: 18.5 GB
#   Downloading...
#   Downloaded: 0.17 GB
#   TCGA-BH-A1FD (LumB): 395 patches, 1477 background skipped
#   SVS deleted. Total patches so far: 95703
#
# [106/122] TCGA-BH-A1FD (LumB) | 0.07 GB
#   Free disk: 18.5 GB
#   Downloading...
#   Downloaded: 0.07 GB
#   TCGA-BH-A1FD (LumB): 329 patches, 2391 background skipped
#   SVS deleted. Total patches so far: 96032
#
# [107/122] TCGA-BH-A1FD (LumB) | 0.08 GB
#   Free disk: 18.5 GB
#   Downloading...
#   Downloaded: 0.08 GB
#   TCGA-BH-A1FD (LumB): 448 patches, 2918 background skipped
#   SVS deleted. Total patches so far: 96480
#
# [108/122] TCGA-BH-A0HU (LumB) | 0.61 GB
#   Free disk: 18.5 GB
#   Downloading...
#   Downloaded: 0.61 GB
#   TCGA-BH-A0HU (LumB): 904 patches, 7556 background skipped
#   SVS deleted. Total patches so far: 97384
#
# [109/122] TCGA-BH-A0C0 (LumB) | 0.05 GB
#   Free disk: 18.4 GB
#   Downloading...
#   Downloaded: 0.05 GB
#   TCGA-BH-A0C0 (LumB): 317 patches, 2059 background skipped
#   SVS deleted. Total patches so far: 97701
#
# [110/122] TCGA-BH-A0C0 (LumB) | 1.48 GB
#   Free disk: 18.4 GB
#   Downloading...
#   Downloaded: 1.48 GB
#   TCGA-BH-A0C0 (LumB): 2000 patches, 2190 background skipped
#   SVS deleted. Total patches so far: 99701
#
# [111/122] TCGA-BH-A0C0 (LumB) | 0.67 GB
#   Free disk: 18.4 GB
#   Downloading...
#   Downloaded: 0.67 GB
#   TCGA-BH-A0C0 (LumB): 1663 patches, 3282 background skipped
#   SVS deleted. Total patches so far: 101364
#
# [112/122] TCGA-BH-A0C0 (LumB) | 0.48 GB
#   Free disk: 18.3 GB
#   Downloading...
#   Downloaded: 0.48 GB
#   TCGA-BH-A0C0 (LumB): 957 patches, 3957 background skipped
#   SVS deleted. Total patches so far: 102321
#
# [113/122] TCGA-BH-A0BZ (LumB) | 1.17 GB
#   Free disk: 18.3 GB
#   Downloading...
#   Downloaded: 1.17 GB
#   TCGA-BH-A0BZ (LumB): 2000 patches, 4719 background skipped
#   SVS deleted. Total patches so far: 104321
#
# [114/122] TCGA-BH-A1EN (Her2) | 0.04 GB
#   Free disk: 18.3 GB
#   Downloading...
#   Downloaded: 0.04 GB
#   TCGA-BH-A1EN (Her2): 519 patches, 1087 background skipped
#   SVS deleted. Total patches so far: 104840
#
# [115/122] TCGA-BH-A1EN (Her2) | 0.29 GB
#   Free disk: 18.3 GB
#   Downloading...
#   Downloaded: 0.29 GB
#   TCGA-BH-A1EN (Her2): 596 patches, 2788 background skipped
#   SVS deleted. Total patches so far: 105436
#
# [116/122] TCGA-BH-A1EN (Her2) | 1.50 GB
#   Free disk: 18.2 GB
#   Downloading...
#   Downloaded: 1.50 GB
#   TCGA-BH-A1EN (Her2): 2000 patches, 2797 background skipped
#   SVS deleted. Total patches so far: 107436
#
# [117/122] TCGA-BH-A18L (LumB) | 0.09 GB
#   Free disk: 18.2 GB
#   Downloading...
#   Downloaded: 0.09 GB
#   TCGA-BH-A18L (LumB): 588 patches, 3768 background skipped
#   SVS deleted. Total patches so far: 108024
#
# [118/122] TCGA-BH-A18L (LumB) | 0.11 GB
#   Free disk: 18.2 GB
#   Downloading...
#   Downloaded: 0.11 GB
#   TCGA-BH-A18L (LumB): 298 patches, 6998 background skipped
#   SVS deleted. Total patches so far: 108322
#
# [119/122] TCGA-BH-A1F8 (LumB) | 0.10 GB
#   Free disk: 18.2 GB
#   Downloading...
#   Downloaded: 0.10 GB
#   TCGA-BH-A1F8 (LumB): 137 patches, 1203 background skipped
#   SVS deleted. Total patches so far: 108459
#
# [120/122] TCGA-BH-A0BF (LumB) | 0.26 GB
#   Free disk: 18.2 GB
#   Downloading...
#   Downloaded: 0.26 GB
#   TCGA-BH-A0BF (LumB): 1627 patches, 3261 background skipped
#   SVS deleted. Total patches so far: 110086
#
# [121/122] TCGA-BH-A1F2 (LumB) | 0.37 GB
#   Free disk: 18.1 GB
#   Downloading...
#   Downloaded: 0.37 GB
#   TCGA-BH-A1F2 (LumB): 534 patches, 4458 background skipped
#   SVS deleted. Total patches so far: 110620
#
# [122/122] TCGA-BH-A1F2 (LumB) | 0.82 GB
#   Free disk: 18.1 GB
#   Downloading...
#   Downloaded: 0.82 GB
#   TCGA-BH-A1F2 (LumB): 1925 patches, 5264 background skipped
#   SVS deleted. Total patches so far: 112545
#
# Total BH patches extracted: 112545
# subtype_clean
# LumB    81511
# Her2    31034
# Name: count, dtype: int64
#
# Outputs in /kaggle/working/output/:
#   - bh_her2_lumb_patches.csv (14.9 MB)
#
# Done. Next: create Dataset from output → then A8 notebook.
