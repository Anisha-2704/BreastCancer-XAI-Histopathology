# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/anishapanja/bc-xai-macenko-reference-a2e2/reference_tile.png
# /kaggle/input/datasets/anishapanja/brca-pancancer-atlas-clinical/data_clinical_patient.txt

# %%
# Install OpenSlide system tools for reading SVS whole-slide images.
import subprocess
subprocess.run(["apt-get", "install", "-y", "openslide-tools", "-q"], check=True)

# Install only libraries that work on Kaggle Python 3.12.
# Do NOT install staintools because it imports missing spams on Python 3.12.
subprocess.run(["pip", "install", "openslide-python", "scikit-image", "requests", "-q"], check=True)

# Import standard libraries.
import os
import gc
import csv
import json
import shutil
import random
import traceback
from pathlib import Path

# Import scientific and image-processing libraries.
import cv2
import numpy as np
import pandas as pd
import requests
import openslide
from PIL import Image

# Fixed random seed for reproducibility.
SEED = 42
rng = random.Random(SEED)

# Site and batch settings.
SITE_CODE = "A8"
BATCH_SIZE = 15

# Frozen preprocessing parameters.
PATCH_SIZE = 256
STRIDE = 256
TARGET_MPP = 1.0
MIN_TISSUE_FRACTION = 0.50
SATURATION_THRESHOLD = 15
MAX_PATCHES_PER_PATIENT = 2000
JPEG_QUALITY = 95

# Output paths.
WORK_DIR = Path("/kaggle/working")
PATCH_ROOT = WORK_DIR / "patches" / SITE_CODE
TMP_DIR = WORK_DIR / "tmp_svs"
LOG_PATH = WORK_DIR / "preprocessing_log.csv"

# Create output folders.
PATCH_ROOT.mkdir(parents=True, exist_ok=True)
TMP_DIR.mkdir(parents=True, exist_ok=True)

# Find an input file by exact filename.
def find_input_file(filename):
    for root, dirs, files in os.walk("/kaggle/input"):
        if filename in files:
            return Path(root) / filename
    raise FileNotFoundError(f"Could not find {filename} under /kaggle/input")

# Locate clinical labels and reference tile.
clinical_path = find_input_file("data_clinical_patient.txt")
reference_path = find_input_file("reference_tile.png")

# Load clinical data.
clinical_df = pd.read_csv(clinical_path, sep="\t", comment="#", low_memory=False)

# Keep labeled A8 patients only.
a8_df = clinical_df[
    clinical_df["PATIENT_ID"].astype(str).str.startswith("TCGA-A8-")
    & clinical_df["SUBTYPE"].notna()
    & (clinical_df["SUBTYPE"] != "BRCA_Normal")
].copy()

# Sort for deterministic batch order.
a8_df = a8_df.sort_values("PATIENT_ID").reset_index(drop=True)

# -----------------------------
# A8 Batch 3
# -----------------------------
BATCH_START = 30
BATCH_END = 45

batch_df = a8_df.iloc[BATCH_START:BATCH_END].copy()
# Print sanity checks.
print("Clinical file:", clinical_path)
print("Reference tile:", reference_path)
print("Total labeled A8 patients:", a8_df["PATIENT_ID"].nunique())
print("A8 Batch 3 patients:", batch_df["PATIENT_ID"].tolist())
print("A8 Batch 3 subtype counts:")
print(batch_df["SUBTYPE"].value_counts())

# Luminosity standardization similar to staintools.
def standardize_luminosity(img):
    img = img.astype(np.float32)
    p = np.percentile(img, 95)
    if p <= 0:
        return np.clip(img, 0, 255).astype(np.uint8)
    img = img * (255.0 / p)
    return np.clip(img, 0, 255).astype(np.uint8)

# Convert RGB to optical density.
def rgb_to_od(img):
    img = img.astype(np.float32)
    return -np.log((img + 1.0) / 255.0)

# Convert optical density back to RGB.
def od_to_rgb(od):
    rgb = 255.0 * np.exp(-od)
    return np.clip(rgb, 0, 255).astype(np.uint8)

# Estimate Macenko H&E stain matrix.
def get_macenko_stain_matrix(img, beta=0.15, alpha=1):
    img = standardize_luminosity(img)
    od = rgb_to_od(img).reshape((-1, 3))
    od = od[np.all(od > beta, axis=1)]

    if od.shape[0] < 100:
        raise RuntimeError("Too few tissue pixels for Macenko fitting.")

    _, _, vh = np.linalg.svd(od, full_matrices=False)
    top_vectors = vh[:2].T

    projected = np.dot(od, top_vectors)
    angles = np.arctan2(projected[:, 1], projected[:, 0])

    min_angle = np.percentile(angles, alpha)
    max_angle = np.percentile(angles, 100 - alpha)

    v1 = np.dot(top_vectors, np.array([np.cos(min_angle), np.sin(min_angle)]))
    v2 = np.dot(top_vectors, np.array([np.cos(max_angle), np.sin(max_angle)]))

    if v1[0] > v2[0]:
        he = np.stack([v1, v2], axis=1)
    else:
        he = np.stack([v2, v1], axis=1)

    he = he / np.linalg.norm(he, axis=0, keepdims=True)
    return he

# Estimate stain concentrations.
def get_concentrations(img, stain_matrix):
    od = rgb_to_od(img).reshape((-1, 3)).T
    concentrations, _, _, _ = np.linalg.lstsq(stain_matrix, od, rcond=None)
    return concentrations

# Fit fixed reference Macenko target once.
reference_img = np.array(Image.open(reference_path).convert("RGB"))
reference_img = standardize_luminosity(reference_img)
reference_he = get_macenko_stain_matrix(reference_img)
reference_conc = get_concentrations(reference_img, reference_he)
reference_max = np.percentile(reference_conc, 99, axis=1)

# Normalize one patch to the fixed reference tile.
def normalize_patch(rgb_patch):
    try:
        patch = standardize_luminosity(rgb_patch)
        source_he = get_macenko_stain_matrix(patch)
        source_conc = get_concentrations(patch, source_he)
        source_max = np.percentile(source_conc, 99, axis=1)
        scale = reference_max / (source_max + 1e-8)
        source_conc = source_conc * scale[:, None]
        normalized_od = np.dot(reference_he, source_conc).T.reshape(patch.shape)
        normalized_rgb = od_to_rgb(normalized_od)
        return normalized_rgb
    except Exception:
        return rgb_patch

# Append one row to the preprocessing log.
def write_log(row):
    file_exists = LOG_PATH.exists()
    with open(LOG_PATH, "a", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(
            f,
            fieldnames=[
                "patient_id",
                "subtype",
                "status",
                "patches_saved",
                "tissue_patches_seen",
                "svs_files_found",
                "error_message",
            ],
        )
        if not file_exists:
            writer.writeheader()
        writer.writerow(row)

# Free disk space in GB.
def free_disk_gb(path="/kaggle/working"):
    usage = shutil.disk_usage(path)
    return usage.free / (1024 ** 3)

# Query GDC for open SVS slide files for one patient.
def query_gdc_svs_files(patient_id):
    filters = {
        "op": "and",
        "content": [
            {"op": "in", "content": {"field": "cases.submitter_id", "value": [patient_id]}},
            {"op": "in", "content": {"field": "data_type", "value": ["Slide Image"]}},
            {"op": "in", "content": {"field": "access", "value": ["open"]}},
        ],
    }

    params = {
        "filters": json.dumps(filters),
        "fields": "file_id,file_name,file_size,cases.submitter_id",
        "format": "JSON",
        "size": "200",
    }

    response = requests.get("https://api.gdc.cancer.gov/files", params=params, timeout=60)
    response.raise_for_status()
    hits = response.json()["data"]["hits"]

    svs_hits = [h for h in hits if str(h.get("file_name", "")).lower().endswith(".svs")]
    svs_hits = sorted(svs_hits, key=lambda x: x.get("file_name", ""))
    return svs_hits

# Stream-download one SVS file.
def download_svs(file_id, out_path):
    url = f"https://api.gdc.cancer.gov/data/{file_id}"

    with requests.get(url, stream=True, timeout=120) as response:
        response.raise_for_status()
        with open(out_path, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)

    if out_path.stat().st_size <= 1_000_000:
        raise RuntimeError(f"Downloaded SVS is too small: {out_path.stat().st_size} bytes")

# Choose OpenSlide level closest to 1 micrometer per pixel.
def choose_level_for_target_mpp(slide):
    mpp_x = slide.properties.get("openslide.mpp-x")

    if mpp_x is not None:
        base_mpp = float(mpp_x)
        target_downsample = TARGET_MPP / base_mpp
    else:
        target_downsample = 4.0

    downsamples = [float(d) for d in slide.level_downsamples]
    level = int(np.argmin([abs(d - target_downsample) for d in downsamples]))
    return level

# Tissue detection using HSV saturation.
def tissue_fraction_hsv(rgb_patch):
    hsv = cv2.cvtColor(rgb_patch, cv2.COLOR_RGB2HSV)
    saturation = hsv[:, :, 1]
    return float(np.mean(saturation > SATURATION_THRESHOLD))

# Save RGB patch as JPEG.
def save_jpeg(rgb_patch, out_path):
    Image.fromarray(rgb_patch).save(out_path, format="JPEG", quality=JPEG_QUALITY)

# Process one SVS slide into patient patch folder.
def process_slide_into_patient_reservoir(slide_path, patient_dir, patient_id, current_saved, tissue_seen):
    slide = openslide.open_slide(str(slide_path))
    level = choose_level_for_target_mpp(slide)
    level_w, level_h = slide.level_dimensions[level]
    downsample = float(slide.level_downsamples[level])

    print("Selected OpenSlide level:", level)
    print("Level dimensions:", level_w, level_h)
    print("Level downsample:", downsample)

    for y in range(0, level_h - PATCH_SIZE + 1, STRIDE):
        for x in range(0, level_w - PATCH_SIZE + 1, STRIDE):
            level0_x = int(x * downsample)
            level0_y = int(y * downsample)

            patch_rgba = slide.read_region((level0_x, level0_y), level, (PATCH_SIZE, PATCH_SIZE))
            patch_rgb = np.array(patch_rgba.convert("RGB"))

            if tissue_fraction_hsv(patch_rgb) < MIN_TISSUE_FRACTION:
                continue

            tissue_seen += 1
            patch_rgb = normalize_patch(patch_rgb)

            if current_saved < MAX_PATCHES_PER_PATIENT:
                out_index = current_saved
                current_saved += 1
            else:
                replacement_index = rng.randint(0, tissue_seen - 1)
                if replacement_index >= MAX_PATCHES_PER_PATIENT:
                    continue
                out_index = replacement_index

            out_name = f"{patient_id}_{out_index:05d}.jpg"
            out_path = patient_dir / out_name
            save_jpeg(patch_rgb, out_path)

    slide.close()
    return current_saved, tissue_seen

# Process each patient in A8 Batch 3.
for row_index, row in batch_df.iterrows():
    patient_id = row["PATIENT_ID"]
    subtype = row["SUBTYPE"]
    patient_dir = PATCH_ROOT / patient_id

    print("\n" + "=" * 80)
    print(f"Patient {row_index + 1}/{len(batch_df)}: {patient_id} | {subtype}")
    print(f"Free disk before patient: {free_disk_gb():.2f} GB")

    if patient_dir.exists() and any(patient_dir.glob("*.jpg")):
        existing_count = len(list(patient_dir.glob("*.jpg")))
        print(f"Skipping existing patient folder with {existing_count} JPEGs.")
        write_log({
            "patient_id": patient_id,
            "subtype": subtype,
            "status": "skipped_existing",
            "patches_saved": existing_count,
            "tissue_patches_seen": "",
            "svs_files_found": "",
            "error_message": "",
        })
        continue

    if free_disk_gb() < 2.0:
        print("Stopping safely because free disk is below 2 GB.")
        break

    patient_dir.mkdir(parents=True, exist_ok=True)

    current_saved = 0
    tissue_seen = 0
    svs_files = []

    try:
        svs_files = query_gdc_svs_files(patient_id)
        print(f"SVS files found: {len(svs_files)}")

        if len(svs_files) == 0:
            raise RuntimeError("No open SVS files found in GDC.")

        for svs_index, svs in enumerate(svs_files):
            if free_disk_gb() < 2.0:
                raise RuntimeError("Free disk dropped below 2 GB before download.")

            file_id = svs["file_id"]
            file_name = svs["file_name"]
            svs_path = TMP_DIR / f"{patient_id}_{svs_index}_{file_name}"

            print(f"Downloading SVS {svs_index + 1}/{len(svs_files)}: {file_name}")
            download_svs(file_id, svs_path)

            print(f"Processing slide: {svs_path.name}")
            current_saved, tissue_seen = process_slide_into_patient_reservoir(
                svs_path,
                patient_dir,
                patient_id,
                current_saved,
                tissue_seen,
            )

            if svs_path.exists():
                os.remove(svs_path)

            gc.collect()

            print(f"Patches saved so far: {current_saved}")
            print(f"Tissue patches seen so far: {tissue_seen}")
            print(f"Free disk after slide: {free_disk_gb():.2f} GB")

        status = "success" if current_saved > 0 else "failed_no_patches"

        write_log({
            "patient_id": patient_id,
            "subtype": subtype,
            "status": status,
            "patches_saved": current_saved,
            "tissue_patches_seen": tissue_seen,
            "svs_files_found": len(svs_files),
            "error_message": "",
        })

        print(f"Finished {patient_id}: {status}, saved {current_saved} patches.")

    except Exception as e:
        error_message = repr(e)
        print(f"FAILED {patient_id}: {error_message}")
        print(traceback.format_exc())

        for leftover in TMP_DIR.glob(f"{patient_id}_*"):
            try:
                os.remove(leftover)
            except Exception:
                pass

        write_log({
            "patient_id": patient_id,
            "subtype": subtype,
            "status": "failed",
            "patches_saved": current_saved,
            "tissue_patches_seen": tissue_seen,
            "svs_files_found": len(svs_files),
            "error_message": error_message,
        })

    print(f"Free disk after patient: {free_disk_gb():.2f} GB")

# Final summary.
print("\n" + "=" * 80)
print("A8 batch 3 preprocessing finished.")
print("Patch output folder:", PATCH_ROOT)
print("Log file:", LOG_PATH)

summary_rows = []
for patient_folder in sorted(PATCH_ROOT.glob("TCGA-A8-*")):
    summary_rows.append({
        "patient_id": patient_folder.name,
        "jpg_count": len(list(patient_folder.glob("*.jpg"))),
    })

summary_df = pd.DataFrame(summary_rows)
print(summary_df)

if LOG_PATH.exists():
    print(pd.read_csv(LOG_PATH))
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   libopenslide0
# Suggested packages:
#   libtiff-tools
# The following NEW packages will be installed:
#   libopenslide0 openslide-tools
# 0 upgraded, 2 newly installed, 0 to remove and 83 not upgraded.
# Need to get 104 kB of archives.
# After this operation, 297 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenslide0 amd64 3.4.1+dfsg-5build1 [89.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 openslide-tools amd64 3.4.1+dfsg-5build1 [13.8 kB]
# Fetched 104 kB in 0s (893 kB/s)
# Selecting previously unselected package libopenslide0.
# (Reading database ... 121026 files and directories currently installed.)
# Preparing to unpack .../libopenslide0_3.4.1+dfsg-5build1_amd64.deb ...
# Unpacking libopenslide0 (3.4.1+dfsg-5build1) ...
# Selecting previously unselected package openslide-tools.
# Preparing to unpack .../openslide-tools_3.4.1+dfsg-5build1_amd64.deb ...
# Unpacking openslide-tools (3.4.1+dfsg-5build1) ...
# Setting up libopenslide0 (3.4.1+dfsg-5build1) ...
# Setting up openslide-tools (3.4.1+dfsg-5build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# Clinical file: /kaggle/input/datasets/anishapanja/brca-pancancer-atlas-clinical/data_clinical_patient.txt
# Reference tile: /kaggle/input/datasets/anishapanja/bc-xai-macenko-reference-a2e2/reference_tile.png
# Total labeled A8 patients: 73
# A8 Batch 3 patients: ['TCGA-A8-A08B', 'TCGA-A8-A08G', 'TCGA-A8-A08I', 'TCGA-A8-A08J', 'TCGA-A8-A08L', 'TCGA-A8-A08O', 'TCGA-A8-A08P', 'TCGA-A8-A08R', 'TCGA-A8-A08T', 'TCGA-A8-A08X', 'TCGA-A8-A08Z', 'TCGA-A8-A090', 'TCGA-A8-A091', 'TCGA-A8-A092', 'TCGA-A8-A093']
# A8 Batch 3 subtype counts:
# SUBTYPE
# BRCA_LumA     6
# BRCA_Her2     4
# BRCA_LumB     4
# BRCA_Basal    1
# Name: count, dtype: int64
#
# ================================================================================
# Patient 31/15: TCGA-A8-A08B | BRCA_Her2
# Free disk before patient: 19.50 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A08B-01A-01-BS1.cd256d6e-99c5-4b32-8bbc-7c1811004b8b.svs
# Processing slide: TCGA-A8-A08B_0_TCGA-A8-A08B-01A-01-BS1.cd256d6e-99c5-4b32-8bbc-7c1811004b8b.svs
# Selected OpenSlide level: 1
# Level dimensions: 16322 6504
# Level downsample: 4.0
# /tmp/ipykernel_16/1120676938.py:109: RuntimeWarning: overflow encountered in exp
#   rgb = 255.0 * np.exp(-od)
# /tmp/ipykernel_16/1120676938.py:109: RuntimeWarning: overflow encountered in multiply
#   rgb = 255.0 * np.exp(-od)
# Patches saved so far: 405
# Tissue patches seen so far: 405
# Free disk after slide: 19.48 GB
# Downloading SVS 2/3: TCGA-A8-A08B-01A-01-MS1.6513191e-0189-4a23-9a56-5ac94a553b43.svs
# Processing slide: TCGA-A8-A08B_1_TCGA-A8-A08B-01A-01-MS1.6513191e-0189-4a23-9a56-5ac94a553b43.svs
# Selected OpenSlide level: 1
# Level dimensions: 27051 7849
# Level downsample: 4.000182855580065
# Patches saved so far: 1197
# Tissue patches seen so far: 1197
# Free disk after slide: 19.44 GB
# Downloading SVS 3/3: TCGA-A8-A08B-01Z-00-DX1.416316FD-E8BF-402C-939A-08920F08A181.svs
# Processing slide: TCGA-A8-A08B_2_TCGA-A8-A08B-01Z-00-DX1.416316FD-E8BF-402C-939A-08920F08A181.svs
# Selected OpenSlide level: 1
# Level dimensions: 17664 22592
# Level downsample: 4.0
# Patches saved so far: 1648
# Tissue patches seen so far: 1648
# Free disk after slide: 19.41 GB
# Finished TCGA-A8-A08B: success, saved 1648 patches.
# Free disk after patient: 19.41 GB
#
# ================================================================================
# Patient 32/15: TCGA-A8-A08G | BRCA_LumB
# Free disk before patient: 19.41 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A08G-01A-01-BS1.1db0beb9-ba79-4391-8e89-ba0ece7fd68c.svs
# Processing slide: TCGA-A8-A08G_0_TCGA-A8-A08G-01A-01-BS1.1db0beb9-ba79-4391-8e89-ba0ece7fd68c.svs
# Selected OpenSlide level: 1
# Level dimensions: 36244 8160
# Level downsample: 4.000027590773645
# Patches saved so far: 975
# Tissue patches seen so far: 975
# Free disk after slide: 19.36 GB
# Downloading SVS 2/3: TCGA-A8-A08G-01A-01-TS1.00c53463-683f-443f-b693-5673b3b564ff.svs
# Processing slide: TCGA-A8-A08G_1_TCGA-A8-A08G-01A-01-TS1.00c53463-683f-443f-b693-5673b3b564ff.svs
# Selected OpenSlide level: 1
# Level dimensions: 17762 5942
# Level downsample: 4.000280590238916
# Patches saved so far: 1385
# Tissue patches seen so far: 1385
# Free disk after slide: 19.34 GB
# Downloading SVS 3/3: TCGA-A8-A08G-01Z-00-DX1.C3BB7FEC-91B7-4B45-8DFC-36CABCC0FD57.svs
# Processing slide: TCGA-A8-A08G_2_TCGA-A8-A08G-01Z-00-DX1.C3BB7FEC-91B7-4B45-8DFC-36CABCC0FD57.svs
# Selected OpenSlide level: 1
# Level dimensions: 11968 12864
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2058
# Free disk after slide: 19.30 GB
# Finished TCGA-A8-A08G: success, saved 2000 patches.
# Free disk after patient: 19.30 GB
#
# ================================================================================
# Patient 33/15: TCGA-A8-A08I | BRCA_LumB
# Free disk before patient: 19.30 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A08I-01A-01-BS1.6a1dc7c0-efb4-45dd-b714-b4f97c92ac2f.svs
# Processing slide: TCGA-A8-A08I_0_TCGA-A8-A08I-01A-01-BS1.6a1dc7c0-efb4-45dd-b714-b4f97c92ac2f.svs
# Selected OpenSlide level: 1
# Level dimensions: 21362 6330
# Level downsample: 4.0002047899793425
# Patches saved so far: 475
# Tissue patches seen so far: 475
# Free disk after slide: 19.27 GB
# Downloading SVS 2/3: TCGA-A8-A08I-01A-01-TS1.0634cf0b-038e-4a34-9c8e-37634b5bd935.svs
# Processing slide: TCGA-A8-A08I_1_TCGA-A8-A08I-01A-01-TS1.0634cf0b-038e-4a34-9c8e-37634b5bd935.svs
# Selected OpenSlide level: 1
# Level dimensions: 31924 7045
# Level downsample: 4.000141944641589
# Patches saved so far: 1094
# Tissue patches seen so far: 1094
# Free disk after slide: 19.23 GB
# Downloading SVS 3/3: TCGA-A8-A08I-01Z-00-DX1.96A0065E-5430-40F6-835E-1A7238A79DDA.svs
# Processing slide: TCGA-A8-A08I_2_TCGA-A8-A08I-01Z-00-DX1.96A0065E-5430-40F6-835E-1A7238A79DDA.svs
# Selected OpenSlide level: 1
# Level dimensions: 24576 23872
# Level downsample: 4.0
# Patches saved so far: 1645
# Tissue patches seen so far: 1645
# Free disk after slide: 19.19 GB
# Finished TCGA-A8-A08I: success, saved 1645 patches.
# Free disk after patient: 19.19 GB
#
# ================================================================================
# Patient 34/15: TCGA-A8-A08J | BRCA_Her2
# Free disk before patient: 19.19 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A08J-01A-01-BS1.c5948da8-a676-4cbf-819c-b636c968cf46.svs
# Processing slide: TCGA-A8-A08J_0_TCGA-A8-A08J-01A-01-BS1.c5948da8-a676-4cbf-819c-b636c968cf46.svs
# Selected OpenSlide level: 1
# Level dimensions: 31443 6878
# Level downsample: 4.000193096473689
# Patches saved so far: 914
# Tissue patches seen so far: 914
# Free disk after slide: 19.15 GB
# Downloading SVS 2/3: TCGA-A8-A08J-01A-01-TS1.51017c5f-8abd-4c99-89c9-b94a5a64249f.svs
# Processing slide: TCGA-A8-A08J_1_TCGA-A8-A08J-01A-01-TS1.51017c5f-8abd-4c99-89c9-b94a5a64249f.svs
# Selected OpenSlide level: 1
# Level dimensions: 28323 6937
# Level downsample: 4.000251538794806
# Patches saved so far: 1892
# Tissue patches seen so far: 1892
# Free disk after slide: 19.10 GB
# Downloading SVS 3/3: TCGA-A8-A08J-01Z-00-DX1.4607286A-033B-4C44-8306-50DB9C596166.svs
# Processing slide: TCGA-A8-A08J_2_TCGA-A8-A08J-01Z-00-DX1.4607286A-033B-4C44-8306-50DB9C596166.svs
# Selected OpenSlide level: 1
# Level dimensions: 24576 27456
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2634
# Free disk after slide: 19.09 GB
# Finished TCGA-A8-A08J: success, saved 2000 patches.
# Free disk after patient: 19.09 GB
#
# ================================================================================
# Patient 35/15: TCGA-A8-A08L | BRCA_Her2
# Free disk before patient: 19.09 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A08L-01A-01-BSA.974269aa-b6eb-414a-afc3-0b0ceb146c9f.svs
# Processing slide: TCGA-A8-A08L_0_TCGA-A8-A08L-01A-01-BSA.974269aa-b6eb-414a-afc3-0b0ceb146c9f.svs
# Selected OpenSlide level: 1
# Level dimensions: 28009 7461
# Level downsample: 4.000017851404905
# Patches saved so far: 950
# Tissue patches seen so far: 950
# Free disk after slide: 19.03 GB
# Downloading SVS 2/3: TCGA-A8-A08L-01A-01-TSA.ecd66fe2-ffc0-402e-8808-7dedb0f6a5b9.svs
# Processing slide: TCGA-A8-A08L_1_TCGA-A8-A08L-01A-01-TSA.ecd66fe2-ffc0-402e-8808-7dedb0f6a5b9.svs
# Selected OpenSlide level: 1
# Level dimensions: 29206 8921
# Level downsample: 4.00001711976991
# Patches saved so far: 1938
# Tissue patches seen so far: 1938
# Free disk after slide: 18.97 GB
# Downloading SVS 3/3: TCGA-A8-A08L-01Z-00-DX1.0FC652B1-336D-4198-93FE-58D2214866D3.svs
# Processing slide: TCGA-A8-A08L_2_TCGA-A8-A08L-01Z-00-DX1.0FC652B1-336D-4198-93FE-58D2214866D3.svs
# Selected OpenSlide level: 1
# Level dimensions: 16512 24896
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2990
# Free disk after slide: 18.97 GB
# Finished TCGA-A8-A08L: success, saved 2000 patches.
# Free disk after patient: 18.97 GB
#
# ================================================================================
# Patient 36/15: TCGA-A8-A08O | BRCA_LumA
# Free disk before patient: 18.97 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A08O-01A-01-BS1.4d78f0ab-bbcc-469e-a381-a4e9b763fd03.svs
# Processing slide: TCGA-A8-A08O_0_TCGA-A8-A08O-01A-01-BS1.4d78f0ab-bbcc-469e-a381-a4e9b763fd03.svs
# Selected OpenSlide level: 1
# Level dimensions: 18962 7508
# Level downsample: 4.000092964157853
# Patches saved so far: 671
# Tissue patches seen so far: 671
# Free disk after slide: 18.93 GB
# Downloading SVS 2/3: TCGA-A8-A08O-01A-02-BS2.6b4babf5-86ae-4b21-ba69-9ea213e76c0d.svs
# Processing slide: TCGA-A8-A08O_1_TCGA-A8-A08O-01A-02-BS2.6b4babf5-86ae-4b21-ba69-9ea213e76c0d.svs
# Selected OpenSlide level: 1
# Level dimensions: 15361 5889
# Level downsample: 4.000182553950999
# Patches saved so far: 1012
# Tissue patches seen so far: 1012
# Free disk after slide: 18.92 GB
# Downloading SVS 3/3: TCGA-A8-A08O-01Z-00-DX1.BC87C01D-F081-41CA-939A-875C61588E88.svs
# Processing slide: TCGA-A8-A08O_2_TCGA-A8-A08O-01Z-00-DX1.BC87C01D-F081-41CA-939A-875C61588E88.svs
# Selected OpenSlide level: 1
# Level dimensions: 10944 7360
# Level downsample: 4.0
# Patches saved so far: 1337
# Tissue patches seen so far: 1337
# Free disk after slide: 18.90 GB
# Finished TCGA-A8-A08O: success, saved 1337 patches.
# Free disk after patient: 18.90 GB
#
# ================================================================================
# Patient 37/15: TCGA-A8-A08P | BRCA_LumB
# Free disk before patient: 18.90 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A08P-01A-01-BS1.c33472d7-2ca3-4195-a4fb-48118362da45.svs
# Processing slide: TCGA-A8-A08P_0_TCGA-A8-A08P-01A-01-BS1.c33472d7-2ca3-4195-a4fb-48118362da45.svs
# Selected OpenSlide level: 1
# Level dimensions: 29043 9959
# Level downsample: 4.0000846375486745
# Patches saved so far: 1971
# Tissue patches seen so far: 1971
# Free disk after slide: 18.79 GB
# Downloading SVS 2/3: TCGA-A8-A08P-01A-01-TS1.f72d0f1e-98aa-42b1-9c2c-6e3ed1be276e.svs
# Processing slide: TCGA-A8-A08P_1_TCGA-A8-A08P-01A-01-TS1.f72d0f1e-98aa-42b1-9c2c-6e3ed1be276e.svs
# Selected OpenSlide level: 1
# Level dimensions: 24483 9348
# Level downsample: 4.000160462130937
# Patches saved so far: 2000
# Tissue patches seen so far: 3316
# Free disk after slide: 18.79 GB
# Downloading SVS 3/3: TCGA-A8-A08P-01Z-00-DX1.431A1290-9CF4-4CE7-A9F0-13F9ADA46ADA.svs
# Processing slide: TCGA-A8-A08P_2_TCGA-A8-A08P-01Z-00-DX1.431A1290-9CF4-4CE7-A9F0-13F9ADA46ADA.svs
# Selected OpenSlide level: 1
# Level dimensions: 16896 11584
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 4756
# Free disk after slide: 18.78 GB
# Finished TCGA-A8-A08P: success, saved 2000 patches.
# Free disk after patient: 18.78 GB
#
# ================================================================================
# Patient 38/15: TCGA-A8-A08R | BRCA_Basal
# Free disk before patient: 18.78 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A08R-01A-01-BS1.7d1f1daf-4f4f-4126-8b13-3febf866f042.svs
# Processing slide: TCGA-A8-A08R_0_TCGA-A8-A08R-01A-01-BS1.7d1f1daf-4f4f-4126-8b13-3febf866f042.svs
# Selected OpenSlide level: 1
# Level dimensions: 29283 9679
# Level downsample: 4.00003414950654
# Patches saved so far: 971
# Tissue patches seen so far: 971
# Free disk after slide: 18.73 GB
# Downloading SVS 2/3: TCGA-A8-A08R-01A-01-MS1.cb32d356-ca60-4eab-b186-b63ed3b941d1.svs
# Processing slide: TCGA-A8-A08R_1_TCGA-A8-A08R-01A-01-MS1.cb32d356-ca60-4eab-b186-b63ed3b941d1.svs
# Selected OpenSlide level: 1
# Level dimensions: 27603 7834
# Level downsample: 4.000100052301612
# Patches saved so far: 2000
# Tissue patches seen so far: 2247
# Free disk after slide: 18.68 GB
# Downloading SVS 3/3: TCGA-A8-A08R-01Z-00-DX1.72FBD9A3-5EB9-4855-89EB-697883C2EA9B.svs
# Processing slide: TCGA-A8-A08R_2_TCGA-A8-A08R-01Z-00-DX1.72FBD9A3-5EB9-4855-89EB-697883C2EA9B.svs
# Selected OpenSlide level: 1
# Level dimensions: 9536 23360
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2461
# Free disk after slide: 18.67 GB
# Finished TCGA-A8-A08R: success, saved 2000 patches.
# Free disk after patient: 18.67 GB
#
# ================================================================================
# Patient 39/15: TCGA-A8-A08T | BRCA_LumA
# Free disk before patient: 18.67 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A08T-01A-01-BS1.a4f425d3-222d-4ef0-96f4-97bdde661971.svs
# Processing slide: TCGA-A8-A08T_0_TCGA-A8-A08T-01A-01-BS1.a4f425d3-222d-4ef0-96f4-97bdde661971.svs
# Selected OpenSlide level: 1
# Level dimensions: 23042 12652
# Level downsample: 4.000144137402886
# Patches saved so far: 518
# Tissue patches seen so far: 518
# Free disk after slide: 18.65 GB
# Downloading SVS 2/3: TCGA-A8-A08T-01A-02-BS2.f401c61c-3713-4bb9-a709-71423c478c8b.svs
# Processing slide: TCGA-A8-A08T_1_TCGA-A8-A08T-01A-02-BS2.f401c61c-3713-4bb9-a709-71423c478c8b.svs
# Selected OpenSlide level: 1
# Level dimensions: 18722 6669
# Level downsample: 4.00010168030763
# Patches saved so far: 735
# Tissue patches seen so far: 735
# Free disk after slide: 18.64 GB
# Downloading SVS 3/3: TCGA-A8-A08T-01Z-00-DX1.ABA1ABF2-DDB1-4E31-89DC-0F7821311D11.svs
# Processing slide: TCGA-A8-A08T_2_TCGA-A8-A08T-01Z-00-DX1.ABA1ABF2-DDB1-4E31-89DC-0F7821311D11.svs
# Selected OpenSlide level: 1
# Level dimensions: 8896 12224
# Level downsample: 4.0
# Patches saved so far: 1470
# Tissue patches seen so far: 1470
# Free disk after slide: 18.59 GB
# Finished TCGA-A8-A08T: success, saved 1470 patches.
# Free disk after patient: 18.59 GB
#
# ================================================================================
# Patient 40/15: TCGA-A8-A08X | BRCA_Her2
# Free disk before patient: 18.59 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A08X-01A-01-BS1.e4d6c832-f42b-4a1d-8a98-4fbdb3ce0e2a.svs
# Processing slide: TCGA-A8-A08X_0_TCGA-A8-A08X-01A-01-BS1.e4d6c832-f42b-4a1d-8a98-4fbdb3ce0e2a.svs
# Selected OpenSlide level: 1
# Level dimensions: 25136 9008
# Level downsample: 4.000150796010732
# Patches saved so far: 1192
# Tissue patches seen so far: 1192
# Free disk after slide: 18.53 GB
# Downloading SVS 2/3: TCGA-A8-A08X-01A-02-BS2.4b3c6470-5a74-4ef6-a268-8fdb5b0f02ad.svs
# Processing slide: TCGA-A8-A08X_1_TCGA-A8-A08X-01A-02-BS2.4b3c6470-5a74-4ef6-a268-8fdb5b0f02ad.svs
# Selected OpenSlide level: 1
# Level dimensions: 23282 6831
# Level downsample: 4.000284014630795
# Patches saved so far: 1950
# Tissue patches seen so far: 1950
# Free disk after slide: 18.49 GB
# Downloading SVS 3/3: TCGA-A8-A08X-01Z-00-DX1.01FB49CC-6B8E-4317-8C42-6B6D81187A40.svs
# Processing slide: TCGA-A8-A08X_2_TCGA-A8-A08X-01Z-00-DX1.01FB49CC-6B8E-4317-8C42-6B6D81187A40.svs
# Selected OpenSlide level: 1
# Level dimensions: 9536 8384
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2489
# Free disk after slide: 18.48 GB
# Finished TCGA-A8-A08X: success, saved 2000 patches.
# Free disk after patient: 18.48 GB
#
# ================================================================================
# Patient 41/15: TCGA-A8-A08Z | BRCA_LumA
# Free disk before patient: 18.48 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A08Z-01A-01-BS1.1fb87e93-fd85-4c69-a7e0-a8e3d889851a.svs
# Processing slide: TCGA-A8-A08Z_0_TCGA-A8-A08Z-01A-01-BS1.1fb87e93-fd85-4c69-a7e0-a8e3d889851a.svs
# Selected OpenSlide level: 1
# Level dimensions: 39739 11664
# Level downsample: 4.000123480176603
# Patches saved so far: 1614
# Tissue patches seen so far: 1614
# Free disk after slide: 18.40 GB
# Downloading SVS 2/3: TCGA-A8-A08Z-01A-02-BS2.5d948ef0-cfa3-40bd-a383-ba99e6b28378.svs
# Processing slide: TCGA-A8-A08Z_1_TCGA-A8-A08Z-01A-02-BS2.5d948ef0-cfa3-40bd-a383-ba99e6b28378.svs
# Selected OpenSlide level: 1
# Level dimensions: 38542 8037
# Level downsample: 4.000038918582326
# Patches saved so far: 2000
# Tissue patches seen so far: 3082
# Free disk after slide: 18.38 GB
# Downloading SVS 3/3: TCGA-A8-A08Z-01Z-00-DX1.D0AADCA6-C27C-4FB8-89C1-94B5901146E7.svs
# Processing slide: TCGA-A8-A08Z_2_TCGA-A8-A08Z-01Z-00-DX1.D0AADCA6-C27C-4FB8-89C1-94B5901146E7.svs
# Selected OpenSlide level: 1
# Level dimensions: 12480 24000
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 3935
# Free disk after slide: 18.37 GB
# Finished TCGA-A8-A08Z: success, saved 2000 patches.
# Free disk after patient: 18.37 GB
#
# ================================================================================
# Patient 42/15: TCGA-A8-A090 | BRCA_LumA
# Free disk before patient: 18.37 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A090-01A-01-BS1.8191e1aa-9dc1-4474-ba6e-92e33942722e.svs
# Processing slide: TCGA-A8-A090_0_TCGA-A8-A090-01A-01-BS1.8191e1aa-9dc1-4474-ba6e-92e33942722e.svs
# Selected OpenSlide level: 1
# Level dimensions: 26403 8619
# Level downsample: 4.00001893724198
# Patches saved so far: 480
# Tissue patches seen so far: 480
# Free disk after slide: 18.35 GB
# Downloading SVS 2/3: TCGA-A8-A090-01A-01-TS1.6fd65ca8-2e04-4f0b-902a-070cd65c2d93.svs
# Processing slide: TCGA-A8-A090_1_TCGA-A8-A090-01A-01-TS1.6fd65ca8-2e04-4f0b-902a-070cd65c2d93.svs
# Selected OpenSlide level: 1
# Level dimensions: 24003 7950
# Level downsample: 4.000062893081761
# Patches saved so far: 1206
# Tissue patches seen so far: 1206
# Free disk after slide: 18.32 GB
# Downloading SVS 3/3: TCGA-A8-A090-01Z-00-DX1.01574070-D65E-486F-B69D-0F8E3816D057.svs
# Processing slide: TCGA-A8-A090_2_TCGA-A8-A090-01Z-00-DX1.01574070-D65E-486F-B69D-0F8E3816D057.svs
# Selected OpenSlide level: 1
# Level dimensions: 13120 9408
# Level downsample: 4.0
# Patches saved so far: 1536
# Tissue patches seen so far: 1536
# Free disk after slide: 18.30 GB
# Finished TCGA-A8-A090: success, saved 1536 patches.
# Free disk after patient: 18.30 GB
#
# ================================================================================
# Patient 43/15: TCGA-A8-A091 | BRCA_LumA
# Free disk before patient: 18.30 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A091-01A-01-BS1.e7e9318d-a627-472a-9f2e-10cc917036d3.svs
# Processing slide: TCGA-A8-A091_0_TCGA-A8-A091-01A-01-BS1.e7e9318d-a627-472a-9f2e-10cc917036d3.svs
# Selected OpenSlide level: 1
# Level dimensions: 24897 8946
# Level downsample: 4.000131864542816
# Patches saved so far: 1060
# Tissue patches seen so far: 1060
# Free disk after slide: 18.25 GB
# Downloading SVS 2/3: TCGA-A8-A091-01A-01-TS1.c06440ae-88c4-4ed8-a1be-cd23967db5c3.svs
# Processing slide: TCGA-A8-A091_1_TCGA-A8-A091-01A-01-TS1.c06440ae-88c4-4ed8-a1be-cd23967db5c3.svs
# Selected OpenSlide level: 1
# Level dimensions: 32079 7501
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2233
# Free disk after slide: 18.20 GB
# Downloading SVS 3/3: TCGA-A8-A091-01Z-00-DX1.1F38CADB-A093-416E-A8A8-31E61CD730BA.svs
# Processing slide: TCGA-A8-A091_2_TCGA-A8-A091-01Z-00-DX1.1F38CADB-A093-416E-A8A8-31E61CD730BA.svs
# Selected OpenSlide level: 1
# Level dimensions: 11584 9920
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2707
# Free disk after slide: 18.19 GB
# Finished TCGA-A8-A091: success, saved 2000 patches.
# Free disk after patient: 18.19 GB
#
# ================================================================================
# Patient 44/15: TCGA-A8-A092 | BRCA_LumB
# Free disk before patient: 18.19 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A092-01A-01-BS1.32f105e4-98d4-424c-a3d5-b103a6e7bc20.svs
# Processing slide: TCGA-A8-A092_0_TCGA-A8-A092-01A-01-BS1.32f105e4-98d4-424c-a3d5-b103a6e7bc20.svs
# Selected OpenSlide level: 1
# Level dimensions: 30243 8111
# Level downsample: 4.000049598254142
# Patches saved so far: 608
# Tissue patches seen so far: 608
# Free disk after slide: 18.16 GB
# Downloading SVS 2/3: TCGA-A8-A092-01A-01-TS1.02da5bd6-e61a-4986-943e-a0afcfaf3d28.svs
# Processing slide: TCGA-A8-A092_1_TCGA-A8-A092-01A-01-TS1.02da5bd6-e61a-4986-943e-a0afcfaf3d28.svs
# Selected OpenSlide level: 1
# Level dimensions: 15601 6392
# Level downsample: 4.00033081601826
# Patches saved so far: 948
# Tissue patches seen so far: 948
# Free disk after slide: 18.15 GB
# Downloading SVS 3/3: TCGA-A8-A092-01Z-00-DX1.2A55EA0C-47CD-426B-9697-F2B761730585.svs
# Processing slide: TCGA-A8-A092_2_TCGA-A8-A092-01Z-00-DX1.2A55EA0C-47CD-426B-9697-F2B761730585.svs
# Selected OpenSlide level: 1
# Level dimensions: 12352 16064
# Level downsample: 4.0
# Patches saved so far: 1806
# Tissue patches seen so far: 1806
# Free disk after slide: 18.09 GB
# Finished TCGA-A8-A092: success, saved 1806 patches.
# Free disk after patient: 18.09 GB
#
# ================================================================================
# Patient 45/15: TCGA-A8-A093 | BRCA_LumA
# Free disk before patient: 18.09 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A093-01A-01-BS1.3909d441-2e91-4182-ad97-9e55853961a9.svs
# Processing slide: TCGA-A8-A093_0_TCGA-A8-A093-01A-01-BS1.3909d441-2e91-4182-ad97-9e55853961a9.svs
# Selected OpenSlide level: 1
# Level dimensions: 27363 7778
# Level downsample: 4.000146840605407
# Patches saved so far: 276
# Tissue patches seen so far: 276
# Free disk after slide: 18.08 GB
# Downloading SVS 2/3: TCGA-A8-A093-01A-01-TS1.7e6676b5-51e6-4111-b21d-d11367681795.svs
# Processing slide: TCGA-A8-A093_1_TCGA-A8-A093-01A-01-TS1.7e6676b5-51e6-4111-b21d-d11367681795.svs
# Selected OpenSlide level: 1
# Level dimensions: 17762 9356
# Level downsample: 4.000188474908292
# Patches saved so far: 786
# Tissue patches seen so far: 786
# Free disk after slide: 18.05 GB
# Downloading SVS 3/3: TCGA-A8-A093-01Z-00-DX1.1C8056D1-11CD-482D-9A23-3A9D1B4E63F0.svs
# Processing slide: TCGA-A8-A093_2_TCGA-A8-A093-01Z-00-DX1.1C8056D1-11CD-482D-9A23-3A9D1B4E63F0.svs
# Selected OpenSlide level: 1
# Level dimensions: 11712 21952
# Level downsample: 4.0
# Patches saved so far: 1095
# Tissue patches seen so far: 1095
# Free disk after slide: 18.03 GB
# Finished TCGA-A8-A093: success, saved 1095 patches.
# Free disk after patient: 18.03 GB
#
# ================================================================================
# A8 batch 3 preprocessing finished.
# Patch output folder: /kaggle/working/patches/A8
# Log file: /kaggle/working/preprocessing_log.csv
#       patient_id  jpg_count
# 0   TCGA-A8-A08B       1648
# 1   TCGA-A8-A08G       2000
# 2   TCGA-A8-A08I       1645
# 3   TCGA-A8-A08J       2000
# 4   TCGA-A8-A08L       2000
# 5   TCGA-A8-A08O       1337
# 6   TCGA-A8-A08P       2000
# 7   TCGA-A8-A08R       2000
# 8   TCGA-A8-A08T       1470
# 9   TCGA-A8-A08X       2000
# 10  TCGA-A8-A08Z       2000
# 11  TCGA-A8-A090       1536
# 12  TCGA-A8-A091       2000
# 13  TCGA-A8-A092       1806
# 14  TCGA-A8-A093       1095
#       patient_id     subtype   status  patches_saved  tissue_patches_seen  \
# 0   TCGA-A8-A08B   BRCA_Her2  success           1648                 1648
# 1   TCGA-A8-A08G   BRCA_LumB  success           2000                 2058
# 2   TCGA-A8-A08I   BRCA_LumB  success           1645                 1645
# 3   TCGA-A8-A08J   BRCA_Her2  success           2000                 2634
# 4   TCGA-A8-A08L   BRCA_Her2  success           2000                 2990
# 5   TCGA-A8-A08O   BRCA_LumA  success           1337                 1337
# 6   TCGA-A8-A08P   BRCA_LumB  success           2000                 4756
# 7   TCGA-A8-A08R  BRCA_Basal  success           2000                 2461
# 8   TCGA-A8-A08T   BRCA_LumA  success           1470                 1470
# 9   TCGA-A8-A08X   BRCA_Her2  success           2000                 2489
# 10  TCGA-A8-A08Z   BRCA_LumA  success           2000                 3935
# 11  TCGA-A8-A090   BRCA_LumA  success           1536                 1536
# 12  TCGA-A8-A091   BRCA_LumA  success           2000                 2707
# 13  TCGA-A8-A092   BRCA_LumB  success           1806                 1806
# 14  TCGA-A8-A093   BRCA_LumA  success           1095                 1095
#
#     svs_files_found  error_message
# 0                 3            NaN
# 1                 3            NaN
# 2                 3            NaN
# 3                 3            NaN
# 4                 3            NaN
# 5                 3            NaN
# 6                 3            NaN
# 7                 3            NaN
# 8                 3            NaN
# 9                 3            NaN
# 10                3            NaN
# 11                3            NaN
# 12                3            NaN
# 13                3            NaN
# 14                3            NaN
