# %%
# !pip install -q timm albumentations
import os
import gc
import random
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

from PIL import Image
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import (
    Dataset,
    DataLoader,
    WeightedRandomSampler
)

from torchvision.models import swin_t, Swin_T_Weights

import albumentations as A
from albumentations.pytorch import ToTensorV2

from sklearn.model_selection import (
    StratifiedGroupKFold
)

from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
    confusion_matrix,
    classification_report
)

from sklearn.preprocessing import label_binarize

import matplotlib.pyplot as plt
import seaborn as sns

SEED = 42

random.seed(SEED)
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

print(DEVICE)

MANIFEST_DIR = (
    "/kaggle/input/datasets/hritishachoudhury/bc-xai-quality-filtering"
)

df = pd.read_csv(
    f"{MANIFEST_DIR}/filtered_manifest.csv"
)

print(df.shape)

label_map = {
    "LumA": 0,
    "LumB": 1,
    "Her2": 2,
    "Basal": 3
}

df["label"] = (
    df["subtype_clean"]
    .map(label_map)
)

print(df.label.value_counts())

DATASET_ROOTS = {

    "bc-xai-a2-2000-partial":
    "/kaggle/input/datasets/anishapanja/bc-xai-a2-2000-partial",

    "bc-xai-e2-2000":
    "/kaggle/input/datasets/anishapanja/bc-xai-e2-2000",

    "bc-xai-a8-patches-batch1":
    "/kaggle/input/datasets/anishapanja/bc-xai-a8-patches-batch1",

    "bc-xai-a8-patches-batch2":
    "/kaggle/input/datasets/anishapanja/bc-xai-a8-patches-batch2",

    "bc-xai-a8-patches-batch3":
    "/kaggle/input/datasets/anishapanja/bc-xai-a8-patches-batch3",

    "bc-xai-a8-patches-batch4":
    "/kaggle/input/datasets/anishapanja/bc-xai-a8-patches-batch4",

    "bc-xai-a8-patches-batch5":
    "/kaggle/input/datasets/anishapanja/bc-xai-a8-patches-batch5",

    "bc-xai-c8-patches-batch1":
    "/kaggle/input/datasets/anishapanja/bc-xai-c8-patches-batch1",

    "bc-xai-c8-patches-batch2":
    "/kaggle/input/datasets/anishapanja/bc-xai-c8-patches-batch2",

    "bc-xai-c8-patches-batch3":
    "/kaggle/input/datasets/anishapanja/bc-xai-c8-patches-batch3",

    "bc-xai-c8-patches-batch4":
    "/kaggle/input/datasets/anishapanja/bc-xai-c8-patches-batch4",

    "bc-xai-bh-patches":
    "/kaggle/input/datasets/hritishachoudhury/bc-xai-bh-patches",

    "bc-xai-d8-patches":
    "/kaggle/input/datasets/hritishachoudhury/bc-xai-d8-patches"
}


def get_path(row):

    root = DATASET_ROOTS[row["dataset"]]

    return os.path.join(
        root,
        row["relative_path"]
    )


# augmentation
train_tfms = A.Compose([

    A.RandomResizedCrop(
        size=(300, 300),
        scale=(0.8, 1.0)
    ),

    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),

    A.Rotate(limit=90, p=0.5),

    A.ColorJitter(
        brightness=0.2,
        contrast=0.2,
        saturation=0.2,
        hue=0.1,
        p=0.7
    ),

    A.RandomGamma(
        gamma_limit=(80, 120),
        p=0.4
    ),

    A.GaussNoise(p=0.3),

    A.GaussianBlur(p=0.2),

    A.Normalize(),

    ToTensorV2()
])

val_tfms = A.Compose([

    A.Resize(300, 300),

    A.Normalize(),

    ToTensorV2()
])


# datasets
class BCDataset(Dataset):

    def __init__(self, df, transforms):

        self.df = df
        self.transforms = transforms

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):

        row = self.df.iloc[idx]

        img = Image.open(
            get_path(row)
        ).convert("RGB")

        img = np.array(img)

        img = self.transforms(
            image=img
        )["image"]

        label = int(row.label)

        patient = row.patient_id

        return img, label, patient


# focal loss
class FocalLoss(nn.Module):

    def __init__(self, gamma=2):
        super().__init__()

        self.gamma = gamma

    def forward(
        self,
        logits,
        targets
    ):

        ce = F.cross_entropy(
            logits,
            targets,
            reduction="none",
            label_smoothing=0.1
        )

        pt = torch.exp(-ce)

        loss = (
            ((1 - pt) ** self.gamma)
            * ce
        )

        return loss.mean()


# full 3-fold training
sgkf = StratifiedGroupKFold(
    n_splits=3,
    shuffle=True,
    random_state=42
)

all_results = []

for fold, (train_idx, val_idx) in enumerate(
    sgkf.split(
        df,
        df["label"],
        groups=df["patient_id"]
    )
):

    print("\n" + "=" * 60)
    print(f"FOLD {fold+1}")
    print("=" * 60)

    train_df = (
        df.iloc[train_idx]
        .reset_index(drop=True)
    )

    val_df = (
        df.iloc[val_idx]
        .reset_index(drop=True)
    )

    # fold-wise patient counts
    print(
        "Train Patients:",
        train_df.patient_id.nunique()
    )

    print(
        "Val Patients:",
        val_df.patient_id.nunique()
    )

    ###################################################
    # DATALOADER
    ###################################################

    counts = train_df.label.value_counts()

    weights = len(train_df) / counts

    sample_weights = (
        train_df.label.map(weights)
    )

    sampler = WeightedRandomSampler(
        sample_weights.values,
        len(sample_weights),
        replacement=True
    )

    train_ds = BCDataset(
        train_df,
        train_tfms
    )

    val_ds = BCDataset(
        val_df,
        val_tfms
    )

    BATCH_SIZE = 28

    train_loader = DataLoader(
        train_ds,
        batch_size=BATCH_SIZE,
        sampler=sampler,
        num_workers=4,
        pin_memory=True,
        persistent_workers=True,
        prefetch_factor=2
    )

    val_loader = DataLoader(
        val_ds,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
        persistent_workers=True,
        prefetch_factor=2
    )

    ###################################################
    # MODEL
    ###################################################

    weights = Swin_T_Weights.DEFAULT
    model = swin_t(weights=weights)
    model.head = nn.Linear(model.head.in_features, 4)

    model = model.to(DEVICE)

    criterion = FocalLoss()

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=1e-4,
        weight_decay=5e-4
    )

    scheduler = (
        torch.optim.lr_scheduler
        .CosineAnnealingLR(
            optimizer,
            T_max=10
        )
    )

    scaler = torch.amp.GradScaler(enabled=(DEVICE == "cuda"))

    ###################################################
    # TRAINING
    ###################################################

    BEST = 0
    PATIENCE = 5
    counter = 0

    for epoch in range(10):

        print(f"\nEpoch {epoch+1}")

        model.train()

        losses = []

        for images, labels, _ in tqdm(train_loader):

            images = images.to(DEVICE)
            labels = labels.to(DEVICE)

            optimizer.zero_grad()

            with torch.amp.autocast(
                device_type=DEVICE,
                enabled=(DEVICE == "cuda")
            ):

                outputs = model(images)

                loss = criterion(
                    outputs,
                    labels
                )

            scaler.scale(loss).backward()

            scaler.step(optimizer)

            scaler.update()

            losses.append(loss.item())

        ###################################################
        # VALIDATION
        ###################################################

        model.eval()

        patient_probs = {}

        with torch.no_grad():

            for images, labels, patients in tqdm(val_loader):

                images = images.to(DEVICE)

                logits = model(images)

                probs = F.softmax(
                    logits,
                    dim=1
                )

                probs = probs.cpu().numpy()

                for p, prob in zip(
                    patients,
                    probs
                ):

                    if p not in patient_probs:
                        patient_probs[p] = []

                    patient_probs[p].append(prob)

        gt = (
            val_df
            .groupby("patient_id")
            .first()
        )

        preds = []
        targets = []

        for patient in patient_probs:

            avg = np.mean(
                patient_probs[patient],
                axis=0
            )

            pred = np.argmax(avg)

            target = gt.loc[
                patient,
                "label"
            ]

            preds.append(pred)
            targets.append(target)

        f1 = f1_score(
            targets,
            preds,
            average="macro"
        )

        print(
            "Loss:",
            np.mean(losses)
        )

        print(
            "Patient F1:",
            f1
        )

        scheduler.step()

        if f1 > BEST:

            BEST = f1

            counter = 0

            torch.save(
                model.state_dict(),
                f"best_swin_t_fold_{fold+1}.pth"
            )

        else:
            counter += 1

        if counter >= PATIENCE:

            print("Early stopping")

            break

    ###################################################
    # FINAL EVALUATION
    ###################################################

    model.load_state_dict(
        torch.load(
            f"best_swin_t_fold_{fold+1}.pth",
            map_location=DEVICE,
            weights_only=True
        )
    )

    model.eval()

    patient_probs = {}

    with torch.no_grad():

        for images, labels, patients in tqdm(val_loader):

            images = images.to(DEVICE)

            logits = model(images)

            probs = F.softmax(
                logits,
                dim=1
            )

            probs = probs.cpu().numpy()

            for p, prob in zip(
                patients,
                probs
            ):

                if p not in patient_probs:
                    patient_probs[p] = []

                patient_probs[p].append(prob)

    gt = (
        val_df
        .groupby("patient_id")
        .first()
    )

    preds = []
    targets = []
    avg_probs = []

    for patient in patient_probs:

        avg = np.mean(
            patient_probs[patient],
            axis=0
        )

        pred = np.argmax(avg)

        target = gt.loc[
            patient,
            "label"
        ]

        preds.append(pred)
        targets.append(target)
        avg_probs.append(avg)

    avg_probs = np.array(avg_probs)

    acc = accuracy_score(
        targets,
        preds
    )

    precision = precision_score(
        targets,
        preds,
        average="macro",
        zero_division=0
    )

    recall = recall_score(
        targets,
        preds,
        average="macro",
        zero_division=0
    )

    f1 = f1_score(
        targets,
        preds,
        average="macro",
        zero_division=0
    )

    try:

        auc = roc_auc_score(
            label_binarize(
                targets,
                classes=[0, 1, 2, 3]
            ),
            avg_probs,
            average="macro",
            multi_class="ovr"
        )

    except Exception as e:

        print(e)

        auc = np.nan

    print("\nFold Metrics")

    print(f"Accuracy : {acc:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall   : {recall:.4f}")
    print(f"Macro F1 : {f1:.4f}")
    print(f"Macro AUC: {auc:.4f}")

    report = classification_report(
        targets,
        preds,
        target_names=[
            "LumA",
            "LumB",
            "Her2",
            "Basal"
        ],
        output_dict=True,
        zero_division=0
    )

    print(
        classification_report(
            targets,
            preds,
            target_names=[
                "LumA",
                "LumB",
                "Her2",
                "Basal"
            ],
            zero_division=0
        )
    )

    report_df = pd.DataFrame(report).T

    report_df.to_csv(
        f"classification_report_fold_{fold+1}.csv"
    )

    display(report_df)

    cm = confusion_matrix(
        targets,
        preds
    )

    plt.figure(figsize=(8, 6))

    sns.heatmap(
        cm,
        annot=True,
        fmt="d",
        cmap="Blues",
        xticklabels=[
            "LumA",
            "LumB",
            "Her2",
            "Basal"
        ],
        yticklabels=[
            "LumA",
            "LumB",
            "Her2",
            "Basal"
        ]
    )

    plt.title(
        f"Fold {fold+1} Confusion Matrix"
    )

    plt.savefig(
        f"cm_fold_{fold+1}.png",
        dpi=300,
        bbox_inches="tight"
    )

    plt.show()

    pd.DataFrame({

        "patient_id": list(patient_probs.keys()),
        "true": targets,
        "pred": preds,

        "LumA_prob": avg_probs[:, 0],
        "LumB_prob": avg_probs[:, 1],
        "Her2_prob": avg_probs[:, 2],
        "Basal_prob": avg_probs[:, 3]

    }).to_csv(

        f"patient_predictions_fold_{fold+1}.csv",
        index=False
    )

    all_results.append({

        "fold": fold + 1,

        "accuracy": acc,
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "auc": auc
    })

    # free GPU memory between folds
    del model, optimizer, scheduler, scaler
    gc.collect()
    torch.cuda.empty_cache()

###################################################
# CROSS-VALIDATION SUMMARY (outside fold loop)
###################################################

results = pd.DataFrame(all_results)

print("\nFINAL RESULTS")
display(results)

results = results.dropna(
    subset=["f1"]
)

best_fold = results.loc[
    results["f1"].idxmax()
]

print("\nBest Fold:")
print(best_fold)

best_fold_num = int(best_fold["fold"])

print(
    f"\nBest model is Fold {best_fold_num}"
)

pd.DataFrame(best_fold).T.to_csv(
    "best_fold_summary.csv",
    index=False
)

print(
    "\nMean Accuracy:",
    results.accuracy.mean(),
    "±",
    results.accuracy.std()
)

print(
    "Mean Precision:",
    results.precision.mean(),
    "±",
    results.precision.std()
)

print(
    "Mean Recall:",
    results.recall.mean(),
    "±",
    results.recall.std()
)

print(
    "Mean F1:",
    results.f1.mean(),
    "±",
    results.f1.std()
)

print(
    "Mean AUC:",
    results.auc.mean(),
    "±",
    results.auc.std()
)

results.to_csv(
    "cross_validation_results.csv",
    index=False
)
# Out:
# cuda
# (75000, 9)
# label
# 0    33454
# 1    19643
# 3    12197
# 2     9706
# Name: count, dtype: int64
#
# ============================================================
# FOLD 1
# ============================================================
# Train Patients: 228
# Val Patients: 115
# Downloading: "https://download.pytorch.org/models/swin_t-704ceda3.pth" to /root/.cache/torch/hub/checkpoints/swin_t-704ceda3.pth
# 100%|██████████| 108M/108M [00:00<00:00, 156MB/s]
# Epoch 1
# 100%|██████████| 1797/1797 [11:34<00:00,  2.59it/s]
# 100%|██████████| 882/882 [04:25<00:00,  3.32it/s]
# Loss: 0.6325678466324284
# Patient F1: 0.47170132127759246
#
# Epoch 2
# 100%|██████████| 1797/1797 [11:41<00:00,  2.56it/s]
# 100%|██████████| 882/882 [04:24<00:00,  3.33it/s]
# Loss: 0.5301598728565488
# Patient F1: 0.49582807004733914
#
# Epoch 3
# 100%|██████████| 1797/1797 [11:42<00:00,  2.56it/s]
# 100%|██████████| 882/882 [04:24<00:00,  3.34it/s]
# Loss: 0.48242016060357634
# Patient F1: 0.47049889765407005
#
# Epoch 4
# 100%|██████████| 1797/1797 [11:40<00:00,  2.57it/s]
# 100%|██████████| 882/882 [04:26<00:00,  3.31it/s]
# Loss: 0.43967222819145213
# Patient F1: 0.5507054392236976
#
# Epoch 5
# 100%|██████████| 1797/1797 [11:40<00:00,  2.56it/s]
# 100%|██████████| 882/882 [04:24<00:00,  3.34it/s]
# Loss: 0.40484955495572716
# Patient F1: 0.39846504070642
#
# Epoch 6
# 100%|██████████| 1797/1797 [11:40<00:00,  2.57it/s]
# 100%|██████████| 882/882 [04:26<00:00,  3.31it/s]
# Loss: 0.37705481524227324
# Patient F1: 0.540065537084399
#
# Epoch 7
# 100%|██████████| 1797/1797 [11:42<00:00,  2.56it/s]
# 100%|██████████| 882/882 [04:24<00:00,  3.33it/s]
# Loss: 0.3441635750785561
# Patient F1: 0.5330525525006908
#
# Epoch 8
# 100%|██████████| 1797/1797 [11:40<00:00,  2.57it/s]
# 100%|██████████| 882/882 [04:26<00:00,  3.30it/s]
# Loss: 0.32073152033351965
# Patient F1: 0.5165497896213184
#
# Epoch 9
# 100%|██████████| 1797/1797 [11:40<00:00,  2.56it/s]
# 100%|██████████| 882/882 [04:26<00:00,  3.30it/s]
# Loss: 0.30184763470124587
# Patient F1: 0.5280178429027114
# Early stopping
# 100%|██████████| 882/882 [04:26<00:00,  3.31it/s]
# Fold Metrics
# Accuracy : 0.5826
# Precision: 0.5472
# Recall   : 0.5552
# Macro F1 : 0.5507
# Macro AUC: 0.7686
#               precision    recall  f1-score   support
#
#         LumA       0.67      0.71      0.69        31
#         LumB       0.67      0.63      0.65        46
#         Her2       0.32      0.32      0.32        22
#        Basal       0.53      0.56      0.55        16
#
#     accuracy                           0.58       115
#    macro avg       0.55      0.56      0.55       115
# weighted avg       0.58      0.58      0.58       115
#               precision    recall  f1-score     support
# LumA           0.666667  0.709677  0.687500   31.000000
# LumB           0.674419  0.630435  0.651685   46.000000
# Her2           0.318182  0.318182  0.318182   22.000000
# Basal          0.529412  0.562500  0.545455   16.000000
# accuracy       0.582609  0.582609  0.582609    0.582609
# macro avg      0.547170  0.555199  0.550705  115.000000
# weighted avg   0.584004  0.582609  0.582759  115.000000
# ============================================================
# FOLD 2
# ============================================================
# Train Patients: 230
# Val Patients: 113
#
# Epoch 1
# 100%|██████████| 1787/1787 [11:49<00:00,  2.52it/s]
# 100%|██████████| 892/892 [04:27<00:00,  3.33it/s]
# Loss: 0.6489861306693211
# Patient F1: 0.4780982905982906
#
# Epoch 2
# 100%|██████████| 1787/1787 [11:37<00:00,  2.56it/s]
# 100%|██████████| 892/892 [04:29<00:00,  3.31it/s]
# Loss: 0.5475881408564393
# Patient F1: 0.44559609654280063
#
# Epoch 3
# 100%|██████████| 1787/1787 [11:38<00:00,  2.56it/s]
# 100%|██████████| 892/892 [04:30<00:00,  3.30it/s]
# Loss: 0.48865912297649894
# Patient F1: 0.4755321488794937
#
# Epoch 4
# 100%|██████████| 1787/1787 [11:36<00:00,  2.57it/s]
# 100%|██████████| 892/892 [04:29<00:00,  3.31it/s]
# Loss: 0.4464143340522241
# Patient F1: 0.4650057783608196
#
# Epoch 5
# 100%|██████████| 1787/1787 [11:38<00:00,  2.56it/s]
# 100%|██████████| 892/892 [04:30<00:00,  3.30it/s]
# Loss: 0.40975592879523226
# Patient F1: 0.5811986361251966
#
# Epoch 6
# 100%|██████████| 1787/1787 [11:38<00:00,  2.56it/s]
# 100%|██████████| 892/892 [04:30<00:00,  3.30it/s]
# Loss: 0.3783540342964136
# Patient F1: 0.530203766594628
#
# Epoch 7
# 100%|██████████| 1787/1787 [11:37<00:00,  2.56it/s]
# 100%|██████████| 892/892 [04:30<00:00,  3.30it/s]
# Loss: 0.34608017380970046
# Patient F1: 0.5123594796008589
#
# Epoch 8
# 100%|██████████| 1787/1787 [11:37<00:00,  2.56it/s]
# 100%|██████████| 892/892 [04:29<00:00,  3.30it/s]
# Loss: 0.3210398884595408
# Patient F1: 0.5038810218106289
#
# Epoch 9
# 100%|██████████| 1787/1787 [11:36<00:00,  2.57it/s]
# 100%|██████████| 892/892 [04:29<00:00,  3.30it/s]
# Loss: 0.303395770573556
# Patient F1: 0.46810279153289436
#
# Epoch 10
# 100%|██████████| 1787/1787 [11:37<00:00,  2.56it/s]
# 100%|██████████| 892/892 [04:26<00:00,  3.34it/s]
# Loss: 0.2949418557602464
# Patient F1: 0.5045673076923077
# Early stopping
# 100%|██████████| 892/892 [04:28<00:00,  3.32it/s]
# Fold Metrics
# Accuracy : 0.6018
# Precision: 0.5939
# Recall   : 0.5864
# Macro F1 : 0.5812
# Macro AUC: 0.8186
#               precision    recall  f1-score   support
#
#         LumA       0.74      0.62      0.67        47
#         LumB       0.54      0.63      0.58        35
#         Her2       0.43      0.60      0.50        15
#        Basal       0.67      0.50      0.57        16
#
#     accuracy                           0.60       113
#    macro avg       0.59      0.59      0.58       113
# weighted avg       0.63      0.60      0.61       113
#               precision    recall  f1-score    support
# LumA           0.743590  0.617021  0.674419   47.00000
# LumB           0.536585  0.628571  0.578947   35.00000
# Her2           0.428571  0.600000  0.500000   15.00000
# Basal          0.666667  0.500000  0.571429   16.00000
# accuracy       0.601770  0.601770  0.601770    0.60177
# macro avg      0.593853  0.586398  0.581199  113.00000
# weighted avg   0.626765  0.601770  0.607112  113.00000
# ============================================================
# FOLD 3
# ============================================================
# Train Patients: 228
# Val Patients: 115
#
# Epoch 1
# 100%|██████████| 1774/1774 [11:32<00:00,  2.56it/s]
# 100%|██████████| 905/905 [04:34<00:00,  3.30it/s]
# Loss: 0.688444449758449
# Patient F1: 0.49701474703626025
#
# Epoch 2
# 100%|██████████| 1774/1774 [11:32<00:00,  2.56it/s]
# 100%|██████████| 905/905 [04:33<00:00,  3.31it/s]
# Loss: 0.5810291016014479
# Patient F1: 0.4510057118541431
#
# Epoch 3
# 100%|██████████| 1774/1774 [11:31<00:00,  2.56it/s]
# 100%|██████████| 905/905 [04:33<00:00,  3.31it/s]
# Loss: 0.5208929372949288
# Patient F1: 0.6207459055819712
#
# Epoch 4
# 100%|██████████| 1774/1774 [11:31<00:00,  2.57it/s]
# 100%|██████████| 905/905 [04:33<00:00,  3.31it/s]
# Loss: 0.47078116641305345
# Patient F1: 0.4400734360583365
#
# Epoch 5
# 100%|██████████| 1774/1774 [11:32<00:00,  2.56it/s]
# 100%|██████████| 905/905 [04:32<00:00,  3.32it/s]
# Loss: 0.4330480832442759
# Patient F1: 0.5797150646288577
#
# Epoch 6
# 100%|██████████| 1774/1774 [11:31<00:00,  2.57it/s]
# 100%|██████████| 905/905 [04:33<00:00,  3.31it/s]
# Loss: 0.3984146027446734
# Patient F1: 0.6047595094375778
#
# Epoch 7
# 100%|██████████| 1774/1774 [11:32<00:00,  2.56it/s]
# 100%|██████████| 905/905 [04:32<00:00,  3.32it/s]
# Loss: 0.3673173732963194
# Patient F1: 0.6037851037851039
#
# Epoch 8
# 100%|██████████| 1774/1774 [11:31<00:00,  2.56it/s]
# 100%|██████████| 905/905 [04:32<00:00,  3.33it/s]
# Loss: 0.34261076348038916
# Patient F1: 0.5958143674136321
# Early stopping
# 100%|██████████| 905/905 [04:32<00:00,  3.32it/s]
# Fold Metrics
# Accuracy : 0.6522
# Precision: 0.6165
# Recall   : 0.6399
# Macro F1 : 0.6207
# Macro AUC: 0.8400
#               precision    recall  f1-score   support
#
#         LumA       0.76      0.76      0.76        54
#         LumB       0.59      0.47      0.52        34
#         Her2       0.40      0.62      0.48        13
#        Basal       0.71      0.71      0.71        14
#
#     accuracy                           0.65       115
#    macro avg       0.62      0.64      0.62       115
# weighted avg       0.66      0.65      0.65       115
#               precision    recall  f1-score     support
# LumA           0.759259  0.759259  0.759259   54.000000
# LumB           0.592593  0.470588  0.524590   34.000000
# Her2           0.400000  0.615385  0.484848   13.000000
# Basal          0.714286  0.714286  0.714286   14.000000
# accuracy       0.652174  0.652174  0.652174    0.652174
# macro avg      0.616534  0.639879  0.620746  115.000000
# weighted avg   0.663897  0.652174  0.653383  115.000000
# FINAL RESULTS
#    fold  accuracy  precision    recall        f1       auc
# 0     1  0.582609   0.547170  0.555199  0.550705  0.768617
# 1     2  0.601770   0.593853  0.586398  0.581199  0.818592
# 2     3  0.652174   0.616534  0.639879  0.620746  0.840003
# Best Fold:
# fold         3.000000
# accuracy     0.652174
# precision    0.616534
# recall       0.639879
# f1           0.620746
# auc          0.840003
# Name: 2, dtype: float64
#
# Best model is Fold 3
#
# Mean Accuracy: 0.6121841734000256 ± 0.03593288891527485
# Mean Precision: 0.5858524687520495 ± 0.03536770599659
# Mean Recall: 0.5938253791280194 ± 0.04282625798354696
# Mean F1: 0.5842166603102884 ± 0.03511763210137411
# Mean AUC: 0.8090709622430287 ± 0.03663335429455811
