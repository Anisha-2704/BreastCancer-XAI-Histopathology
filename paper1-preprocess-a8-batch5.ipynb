# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/anishapanja/brca-pancancer-atlas-clinical/data_clinical_patient.txt
# /kaggle/input/datasets/anishapanja/bc-xai-macenko-reference-a2e2/reference_tile.png

# %%
# Install OpenSlide system tools for reading SVS whole-slide images.
import subprocess
subprocess.run(["apt-get", "install", "-y", "openslide-tools", "-q"], check=True)

# Install only libraries that work on Kaggle Python 3.12.
# Do NOT install staintools because it imports missing spams on Python 3.12.
subprocess.run(["pip", "install", "openslide-python", "scikit-image", "requests", "-q"], check=True)

# Import standard libraries.
import os
import gc
import csv
import json
import shutil
import random
import traceback
from pathlib import Path

# Import scientific and image-processing libraries.
import cv2
import numpy as np
import pandas as pd
import requests
import openslide
from PIL import Image

# Fixed random seed for reproducibility.
SEED = 42
rng = random.Random(SEED)

# Site and batch settings.
SITE_CODE = "A8"
BATCH_SIZE = 15

# Frozen preprocessing parameters.
PATCH_SIZE = 256
STRIDE = 256
TARGET_MPP = 1.0
MIN_TISSUE_FRACTION = 0.50
SATURATION_THRESHOLD = 15
MAX_PATCHES_PER_PATIENT = 2000
JPEG_QUALITY = 95

# Output paths.
WORK_DIR = Path("/kaggle/working")
PATCH_ROOT = WORK_DIR / "patches" / SITE_CODE
TMP_DIR = WORK_DIR / "tmp_svs"
LOG_PATH = WORK_DIR / "preprocessing_log.csv"

# Create output folders.
PATCH_ROOT.mkdir(parents=True, exist_ok=True)
TMP_DIR.mkdir(parents=True, exist_ok=True)

# Find an input file by exact filename.
def find_input_file(filename):
    for root, dirs, files in os.walk("/kaggle/input"):
        if filename in files:
            return Path(root) / filename
    raise FileNotFoundError(f"Could not find {filename} under /kaggle/input")

# Locate clinical labels and reference tile.
clinical_path = find_input_file("data_clinical_patient.txt")
reference_path = find_input_file("reference_tile.png")

# Load clinical data.
clinical_df = pd.read_csv(clinical_path, sep="\t", comment="#", low_memory=False)

# Keep labeled A8 patients only.
a8_df = clinical_df[
    clinical_df["PATIENT_ID"].astype(str).str.startswith("TCGA-A8-")
    & clinical_df["SUBTYPE"].notna()
    & (clinical_df["SUBTYPE"] != "BRCA_Normal")
].copy()

# Sort for deterministic batch order.
a8_df = a8_df.sort_values("PATIENT_ID").reset_index(drop=True)


# -----------------------------
# A8 Batch 5 + Retry Patients
# -----------------------------

FAILED_PATIENTS = [
    "TCGA-A8-A06N",
    "TCGA-A8-A08A",
]

remaining_df = a8_df.iloc[60:73].copy()

retry_df = a8_df[
    a8_df["PATIENT_ID"].isin(FAILED_PATIENTS)
].copy()

batch_df = (
    pd.concat([remaining_df, retry_df], ignore_index=True)
      .drop_duplicates(subset="PATIENT_ID")
      .sort_values("PATIENT_ID")
      .reset_index(drop=True)
)
# Print sanity checks.
print("Clinical file:", clinical_path)
print("Reference tile:", reference_path)
print("Total labeled A8 patients:", a8_df["PATIENT_ID"].nunique())
print("A8 Batch 5 + Retry patients:", batch_df["PATIENT_ID"].tolist())
print("A8 Batch 5 + Retry subtype counts:")
print(batch_df["SUBTYPE"].value_counts())

# Luminosity standardization similar to staintools.
def standardize_luminosity(img):
    img = img.astype(np.float32)
    p = np.percentile(img, 95)
    if p <= 0:
        return np.clip(img, 0, 255).astype(np.uint8)
    img = img * (255.0 / p)
    return np.clip(img, 0, 255).astype(np.uint8)

# Convert RGB to optical density.
def rgb_to_od(img):
    img = img.astype(np.float32)
    return -np.log((img + 1.0) / 255.0)

# Convert optical density back to RGB.
def od_to_rgb(od):
    rgb = 255.0 * np.exp(-od)
    return np.clip(rgb, 0, 255).astype(np.uint8)

# Estimate Macenko H&E stain matrix.
def get_macenko_stain_matrix(img, beta=0.15, alpha=1):
    img = standardize_luminosity(img)
    od = rgb_to_od(img).reshape((-1, 3))
    od = od[np.all(od > beta, axis=1)]

    if od.shape[0] < 100:
        raise RuntimeError("Too few tissue pixels for Macenko fitting.")

    _, _, vh = np.linalg.svd(od, full_matrices=False)
    top_vectors = vh[:2].T

    projected = np.dot(od, top_vectors)
    angles = np.arctan2(projected[:, 1], projected[:, 0])

    min_angle = np.percentile(angles, alpha)
    max_angle = np.percentile(angles, 100 - alpha)

    v1 = np.dot(top_vectors, np.array([np.cos(min_angle), np.sin(min_angle)]))
    v2 = np.dot(top_vectors, np.array([np.cos(max_angle), np.sin(max_angle)]))

    if v1[0] > v2[0]:
        he = np.stack([v1, v2], axis=1)
    else:
        he = np.stack([v2, v1], axis=1)

    he = he / np.linalg.norm(he, axis=0, keepdims=True)
    return he

# Estimate stain concentrations.
def get_concentrations(img, stain_matrix):
    od = rgb_to_od(img).reshape((-1, 3)).T
    concentrations, _, _, _ = np.linalg.lstsq(stain_matrix, od, rcond=None)
    return concentrations

# Fit fixed reference Macenko target once.
reference_img = np.array(Image.open(reference_path).convert("RGB"))
reference_img = standardize_luminosity(reference_img)
reference_he = get_macenko_stain_matrix(reference_img)
reference_conc = get_concentrations(reference_img, reference_he)
reference_max = np.percentile(reference_conc, 99, axis=1)

# Normalize one patch to the fixed reference tile.
def normalize_patch(rgb_patch):
    try:
        patch = standardize_luminosity(rgb_patch)
        source_he = get_macenko_stain_matrix(patch)
        source_conc = get_concentrations(patch, source_he)
        source_max = np.percentile(source_conc, 99, axis=1)
        scale = reference_max / (source_max + 1e-8)
        source_conc = source_conc * scale[:, None]
        normalized_od = np.dot(reference_he, source_conc).T.reshape(patch.shape)
        normalized_rgb = od_to_rgb(normalized_od)
        return normalized_rgb
    except Exception:
        return rgb_patch

# Append one row to the preprocessing log.
def write_log(row):
    file_exists = LOG_PATH.exists()
    with open(LOG_PATH, "a", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(
            f,
            fieldnames=[
                "patient_id",
                "subtype",
                "status",
                "patches_saved",
                "tissue_patches_seen",
                "svs_files_found",
                "error_message",
            ],
        )
        if not file_exists:
            writer.writeheader()
        writer.writerow(row)

# Free disk space in GB.
def free_disk_gb(path="/kaggle/working"):
    usage = shutil.disk_usage(path)
    return usage.free / (1024 ** 3)

# Query GDC for open SVS slide files for one patient.
def query_gdc_svs_files(patient_id):
    filters = {
        "op": "and",
        "content": [
            {"op": "in", "content": {"field": "cases.submitter_id", "value": [patient_id]}},
            {"op": "in", "content": {"field": "data_type", "value": ["Slide Image"]}},
            {"op": "in", "content": {"field": "access", "value": ["open"]}},
        ],
    }

    params = {
        "filters": json.dumps(filters),
        "fields": "file_id,file_name,file_size,cases.submitter_id",
        "format": "JSON",
        "size": "200",
    }

    response = requests.get("https://api.gdc.cancer.gov/files", params=params, timeout=60)
    response.raise_for_status()
    hits = response.json()["data"]["hits"]

    svs_hits = [h for h in hits if str(h.get("file_name", "")).lower().endswith(".svs")]
    svs_hits = sorted(svs_hits, key=lambda x: x.get("file_name", ""))
    return svs_hits

# Stream-download one SVS file.
def download_svs(file_id, out_path):
    url = f"https://api.gdc.cancer.gov/data/{file_id}"

    with requests.get(url, stream=True, timeout=120) as response:
        response.raise_for_status()
        with open(out_path, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)

    if out_path.stat().st_size <= 1_000_000:
        raise RuntimeError(f"Downloaded SVS is too small: {out_path.stat().st_size} bytes")

# Choose OpenSlide level closest to 1 micrometer per pixel.
def choose_level_for_target_mpp(slide):
    mpp_x = slide.properties.get("openslide.mpp-x")

    if mpp_x is not None:
        base_mpp = float(mpp_x)
        target_downsample = TARGET_MPP / base_mpp
    else:
        target_downsample = 4.0

    downsamples = [float(d) for d in slide.level_downsamples]
    level = int(np.argmin([abs(d - target_downsample) for d in downsamples]))
    return level

# Tissue detection using HSV saturation.
def tissue_fraction_hsv(rgb_patch):
    hsv = cv2.cvtColor(rgb_patch, cv2.COLOR_RGB2HSV)
    saturation = hsv[:, :, 1]
    return float(np.mean(saturation > SATURATION_THRESHOLD))

# Save RGB patch as JPEG.
def save_jpeg(rgb_patch, out_path):
    Image.fromarray(rgb_patch).save(out_path, format="JPEG", quality=JPEG_QUALITY)

# Process one SVS slide into patient patch folder.
def process_slide_into_patient_reservoir(slide_path, patient_dir, patient_id, current_saved, tissue_seen):
    slide = openslide.open_slide(str(slide_path))
    level = choose_level_for_target_mpp(slide)
    level_w, level_h = slide.level_dimensions[level]
    downsample = float(slide.level_downsamples[level])

    print("Selected OpenSlide level:", level)
    print("Level dimensions:", level_w, level_h)
    print("Level downsample:", downsample)

    for y in range(0, level_h - PATCH_SIZE + 1, STRIDE):
        for x in range(0, level_w - PATCH_SIZE + 1, STRIDE):
            level0_x = int(x * downsample)
            level0_y = int(y * downsample)

            patch_rgba = slide.read_region((level0_x, level0_y), level, (PATCH_SIZE, PATCH_SIZE))
            patch_rgb = np.array(patch_rgba.convert("RGB"))

            if tissue_fraction_hsv(patch_rgb) < MIN_TISSUE_FRACTION:
                continue

            tissue_seen += 1
            patch_rgb = normalize_patch(patch_rgb)

            if current_saved < MAX_PATCHES_PER_PATIENT:
                out_index = current_saved
                current_saved += 1
            else:
                replacement_index = rng.randint(0, tissue_seen - 1)
                if replacement_index >= MAX_PATCHES_PER_PATIENT:
                    continue
                out_index = replacement_index

            out_name = f"{patient_id}_{out_index:05d}.jpg"
            out_path = patient_dir / out_name
            save_jpeg(patch_rgb, out_path)

    slide.close()
    return current_saved, tissue_seen

# Process A8 Batch 5 + retry failed patients.
for row_index, row in batch_df.iterrows():
    patient_id = row["PATIENT_ID"]
    subtype = row["SUBTYPE"]
    patient_dir = PATCH_ROOT / patient_id

    print("\n" + "=" * 80)
    print(f"Patient {row_index + 1}/{len(batch_df)}: {patient_id} | {subtype}")
    print(f"Free disk before patient: {free_disk_gb():.2f} GB")

    if patient_dir.exists() and any(patient_dir.glob("*.jpg")):
        existing_count = len(list(patient_dir.glob("*.jpg")))
        print(f"Skipping existing patient folder with {existing_count} JPEGs.")
        write_log({
            "patient_id": patient_id,
            "subtype": subtype,
            "status": "skipped_existing",
            "patches_saved": existing_count,
            "tissue_patches_seen": "",
            "svs_files_found": "",
            "error_message": "",
        })
        continue

    if free_disk_gb() < 2.0:
        print("Stopping safely because free disk is below 2 GB.")
        break

    patient_dir.mkdir(parents=True, exist_ok=True)

    current_saved = 0
    tissue_seen = 0
    svs_files = []

    try:
        svs_files = query_gdc_svs_files(patient_id)
        print(f"SVS files found: {len(svs_files)}")

        if len(svs_files) == 0:
            raise RuntimeError("No open SVS files found in GDC.")

        for svs_index, svs in enumerate(svs_files):
            if free_disk_gb() < 2.0:
                raise RuntimeError("Free disk dropped below 2 GB before download.")

            file_id = svs["file_id"]
            file_name = svs["file_name"]
            svs_path = TMP_DIR / f"{patient_id}_{svs_index}_{file_name}"

            print(f"Downloading SVS {svs_index + 1}/{len(svs_files)}: {file_name}")
            download_svs(file_id, svs_path)

            print(f"Processing slide: {svs_path.name}")
            current_saved, tissue_seen = process_slide_into_patient_reservoir(
                svs_path,
                patient_dir,
                patient_id,
                current_saved,
                tissue_seen,
            )

            if svs_path.exists():
                os.remove(svs_path)

            gc.collect()

            print(f"Patches saved so far: {current_saved}")
            print(f"Tissue patches seen so far: {tissue_seen}")
            print(f"Free disk after slide: {free_disk_gb():.2f} GB")

        status = "success" if current_saved > 0 else "failed_no_patches"

        write_log({
            "patient_id": patient_id,
            "subtype": subtype,
            "status": status,
            "patches_saved": current_saved,
            "tissue_patches_seen": tissue_seen,
            "svs_files_found": len(svs_files),
            "error_message": "",
        })

        print(f"Finished {patient_id}: {status}, saved {current_saved} patches.")

    except Exception as e:
        error_message = repr(e)
        print(f"FAILED {patient_id}: {error_message}")
        print(traceback.format_exc())

        for leftover in TMP_DIR.glob(f"{patient_id}_*"):
            try:
                os.remove(leftover)
            except Exception:
                pass

        write_log({
            "patient_id": patient_id,
            "subtype": subtype,
            "status": "failed",
            "patches_saved": current_saved,
            "tissue_patches_seen": tissue_seen,
            "svs_files_found": len(svs_files),
            "error_message": error_message,
        })

    print(f"Free disk after patient: {free_disk_gb():.2f} GB")

# Final summary.
print("\n" + "=" * 80)
print("A8 batch 5 + retry preprocessing finished.")
print("Patch output folder:", PATCH_ROOT)
print("Log file:", LOG_PATH)

summary_rows = []
for patient_folder in sorted(PATCH_ROOT.glob("TCGA-A8-*")):
    summary_rows.append({
        "patient_id": patient_folder.name,
        "jpg_count": len(list(patient_folder.glob("*.jpg"))),
    })

summary_df = pd.DataFrame(summary_rows)
print(summary_df)

if LOG_PATH.exists():
    print(pd.read_csv(LOG_PATH))
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   libopenslide0
# Suggested packages:
#   libtiff-tools
# The following NEW packages will be installed:
#   libopenslide0 openslide-tools
# 0 upgraded, 2 newly installed, 0 to remove and 83 not upgraded.
# Need to get 104 kB of archives.
# After this operation, 297 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenslide0 amd64 3.4.1+dfsg-5build1 [89.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 openslide-tools amd64 3.4.1+dfsg-5build1 [13.8 kB]
# Fetched 104 kB in 1s (124 kB/s)
# Selecting previously unselected package libopenslide0.
# (Reading database ... 121026 files and directories currently installed.)
# Preparing to unpack .../libopenslide0_3.4.1+dfsg-5build1_amd64.deb ...
# Unpacking libopenslide0 (3.4.1+dfsg-5build1) ...
# Selecting previously unselected package openslide-tools.
# Preparing to unpack .../openslide-tools_3.4.1+dfsg-5build1_amd64.deb ...
# Unpacking openslide-tools (3.4.1+dfsg-5build1) ...
# Setting up libopenslide0 (3.4.1+dfsg-5build1) ...
# Setting up openslide-tools (3.4.1+dfsg-5build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# Clinical file: /kaggle/input/datasets/anishapanja/brca-pancancer-atlas-clinical/data_clinical_patient.txt
# Reference tile: /kaggle/input/datasets/anishapanja/bc-xai-macenko-reference-a2e2/reference_tile.png
# Total labeled A8 patients: 73
# A8 Batch 5 + Retry patients: ['TCGA-A8-A06N', 'TCGA-A8-A08A', 'TCGA-A8-A09T', 'TCGA-A8-A09V', 'TCGA-A8-A09W', 'TCGA-A8-A09X', 'TCGA-A8-A09Z', 'TCGA-A8-A0A1', 'TCGA-A8-A0A2', 'TCGA-A8-A0A4', 'TCGA-A8-A0A6', 'TCGA-A8-A0A7', 'TCGA-A8-A0A9', 'TCGA-A8-A0AB', 'TCGA-A8-A0AD']
# A8 Batch 5 + Retry subtype counts:
# SUBTYPE
# BRCA_LumA    10
# BRCA_LumB     3
# BRCA_Her2     2
# Name: count, dtype: int64
#
# ================================================================================
# Patient 1/15: TCGA-A8-A06N | BRCA_LumB
# Free disk before patient: 19.50 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A06N-01A-01-BS1.12bf6cf9-767e-469a-ab07-accd6b3b134e.svs
# Processing slide: TCGA-A8-A06N_0_TCGA-A8-A06N-01A-01-BS1.12bf6cf9-767e-469a-ab07-accd6b3b134e.svs
# Selected OpenSlide level: 1
# Level dimensions: 33036 9727
# Level downsample: 4.0001482116334595
# /tmp/ipykernel_16/3106150027.py:124: RuntimeWarning: overflow encountered in exp
#   rgb = 255.0 * np.exp(-od)
# /tmp/ipykernel_16/3106150027.py:124: RuntimeWarning: overflow encountered in multiply
#   rgb = 255.0 * np.exp(-od)
# Patches saved so far: 1183
# Tissue patches seen so far: 1183
# Free disk after slide: 19.43 GB
# Downloading SVS 2/3: TCGA-A8-A06N-01A-01-TS1.0e8d431f-4df4-4e2e-a8d2-3febb0f1beb9.svs
# Processing slide: TCGA-A8-A06N_1_TCGA-A8-A06N-01A-01-TS1.0e8d431f-4df4-4e2e-a8d2-3febb0f1beb9.svs
# Selected OpenSlide level: 1
# Level dimensions: 40936 13315
# Level downsample: 4.000074194197499
# Patches saved so far: 2000
# Tissue patches seen so far: 2059
# Free disk after slide: 19.39 GB
# Downloading SVS 3/3: TCGA-A8-A06N-01Z-00-DX1.E25E65F8-DFE0-47CF-9FAB-B82EE8E321F7.svs
# Processing slide: TCGA-A8-A06N_2_TCGA-A8-A06N-01Z-00-DX1.E25E65F8-DFE0-47CF-9FAB-B82EE8E321F7.svs
# Selected OpenSlide level: 1
# Level dimensions: 12224 13504
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2712
# Free disk after slide: 19.38 GB
# Finished TCGA-A8-A06N: success, saved 2000 patches.
# Free disk after patient: 19.38 GB
#
# ================================================================================
# Patient 2/15: TCGA-A8-A08A | BRCA_LumA
# Free disk before patient: 19.38 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A08A-01A-01-BS1.db510b27-0937-42da-b559-6d65271401f1.svs
# Processing slide: TCGA-A8-A08A_0_TCGA-A8-A08A-01A-01-BS1.db510b27-0937-42da-b559-6d65271401f1.svs
# Selected OpenSlide level: 1
# Level dimensions: 28727 6755
# Level downsample: 4.000256868192072
# Patches saved so far: 864
# Tissue patches seen so far: 864
# Free disk after slide: 19.34 GB
# Downloading SVS 2/3: TCGA-A8-A08A-01A-01-TS1.e7bdf564-67d2-46dc-bd6a-439cdc74e163.svs
# Processing slide: TCGA-A8-A08A_1_TCGA-A8-A08A-01A-01-TS1.e7bdf564-67d2-46dc-bd6a-439cdc74e163.svs
# Selected OpenSlide level: 1
# Level dimensions: 26333 6514
# Level downsample: 4.0002682484218415
# Patches saved so far: 1629
# Tissue patches seen so far: 1629
# Free disk after slide: 19.29 GB
# Downloading SVS 3/3: TCGA-A8-A08A-01Z-00-DX1.3BB777A0-8652-4483-8DD6-8EB88AB0A8EF.svs
# Processing slide: TCGA-A8-A08A_2_TCGA-A8-A08A-01Z-00-DX1.3BB777A0-8652-4483-8DD6-8EB88AB0A8EF.svs
# Selected OpenSlide level: 1
# Level dimensions: 19584 14784
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2205
# Free disk after slide: 19.26 GB
# Finished TCGA-A8-A08A: success, saved 2000 patches.
# Free disk after patient: 19.26 GB
#
# ================================================================================
# Patient 3/15: TCGA-A8-A09T | BRCA_LumA
# Free disk before patient: 19.26 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A09T-01A-01-BS1.ea346b92-4ab8-40b7-a058-681a2a269463.svs
# Processing slide: TCGA-A8-A09T_0_TCGA-A8-A09T-01A-01-BS1.ea346b92-4ab8-40b7-a058-681a2a269463.svs
# Selected OpenSlide level: 1
# Level dimensions: 30243 5536
# Level downsample: 4.000230234092292
# Patches saved so far: 545
# Tissue patches seen so far: 545
# Free disk after slide: 19.23 GB
# Downloading SVS 2/3: TCGA-A8-A09T-01A-01-TS1.46733e61-04d6-4b8f-97ba-d115e9208e9b.svs
# Processing slide: TCGA-A8-A09T_1_TCGA-A8-A09T-01A-01-TS1.46733e61-04d6-4b8f-97ba-d115e9208e9b.svs
# Selected OpenSlide level: 1
# Level dimensions: 24963 5934
# Level downsample: 4.000084260195484
# Patches saved so far: 991
# Tissue patches seen so far: 991
# Free disk after slide: 19.21 GB
# Downloading SVS 3/3: TCGA-A8-A09T-01Z-00-DX1.4183BBA4-AF11-4602-9EC2-35083C34A393.svs
# Processing slide: TCGA-A8-A09T_2_TCGA-A8-A09T-01Z-00-DX1.4183BBA4-AF11-4602-9EC2-35083C34A393.svs
# Selected OpenSlide level: 1
# Level dimensions: 9280 8128
# Level downsample: 4.0
# Patches saved so far: 1457
# Tissue patches seen so far: 1457
# Free disk after slide: 19.18 GB
# Finished TCGA-A8-A09T: success, saved 1457 patches.
# Free disk after patient: 19.18 GB
#
# ================================================================================
# Patient 4/15: TCGA-A8-A09V | BRCA_LumA
# Free disk before patient: 19.18 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A09V-01A-01-BS1.2d168522-0774-4867-a685-672e2fa1d0d0.svs
# Processing slide: TCGA-A8-A09V_0_TCGA-A8-A09V-01A-01-BS1.2d168522-0774-4867-a685-672e2fa1d0d0.svs
# Selected OpenSlide level: 1
# Level dimensions: 19442 7843
# Level downsample: 4.000153219750063
# Patches saved so far: 360
# Tissue patches seen so far: 360
# Free disk after slide: 19.16 GB
# Downloading SVS 2/3: TCGA-A8-A09V-01A-01-TS1.14e629f6-1c04-41cc-9143-ac7a14f40f87.svs
# Processing slide: TCGA-A8-A09V_1_TCGA-A8-A09V-01A-01-TS1.14e629f6-1c04-41cc-9143-ac7a14f40f87.svs
# Selected OpenSlide level: 1
# Level dimensions: 21842 8176
# Level downsample: 4.000190984227411
# Patches saved so far: 750
# Tissue patches seen so far: 750
# Free disk after slide: 19.14 GB
# Downloading SVS 3/3: TCGA-A8-A09V-01Z-00-DX1.2D6731CA-5712-4EB8-8602-E53301BF4238.svs
# Processing slide: TCGA-A8-A09V_2_TCGA-A8-A09V-01Z-00-DX1.2D6731CA-5712-4EB8-8602-E53301BF4238.svs
# Selected OpenSlide level: 1
# Level dimensions: 8000 11328
# Level downsample: 4.0
# Patches saved so far: 1047
# Tissue patches seen so far: 1047
# Free disk after slide: 19.12 GB
# Finished TCGA-A8-A09V: success, saved 1047 patches.
# Free disk after patient: 19.12 GB
#
# ================================================================================
# Patient 5/15: TCGA-A8-A09W | BRCA_LumB
# Free disk before patient: 19.12 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A09W-01A-01-BS1.35bdda00-d682-4d57-8ce9-d1e7234b0db8.svs
# Processing slide: TCGA-A8-A09W_0_TCGA-A8-A09W-01A-01-BS1.35bdda00-d682-4d57-8ce9-d1e7234b0db8.svs
# Selected OpenSlide level: 1
# Level dimensions: 25443 7389
# Level downsample: 4.0
# Patches saved so far: 809
# Tissue patches seen so far: 809
# Free disk after slide: 19.08 GB
# Downloading SVS 2/3: TCGA-A8-A09W-01A-01-TS1.98c12c3a-dc1b-4e28-b3ce-89c5ad01c8bc.svs
# Processing slide: TCGA-A8-A09W_1_TCGA-A8-A09W-01A-01-TS1.98c12c3a-dc1b-4e28-b3ce-89c5ad01c8bc.svs
# Selected OpenSlide level: 1
# Level dimensions: 30483 10461
# Level downsample: 4.000097004332908
# Patches saved so far: 1684
# Tissue patches seen so far: 1684
# Free disk after slide: 19.03 GB
# Downloading SVS 3/3: TCGA-A8-A09W-01Z-00-DX1.BF33B0F9-5786-4682-B59E-DCBD33D7BB03.svs
# Processing slide: TCGA-A8-A09W_2_TCGA-A8-A09W-01Z-00-DX1.BF33B0F9-5786-4682-B59E-DCBD33D7BB03.svs
# Selected OpenSlide level: 1
# Level dimensions: 16640 10048
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2350
# Free disk after slide: 19.00 GB
# Finished TCGA-A8-A09W: success, saved 2000 patches.
# Free disk after patient: 19.00 GB
#
# ================================================================================
# Patient 6/15: TCGA-A8-A09X | BRCA_Her2
# Free disk before patient: 19.00 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A09X-01A-01-BS1.6f6ae7cd-631e-4030-9183-725f5a48c942.svs
# Processing slide: TCGA-A8-A09X_0_TCGA-A8-A09X-01A-01-BS1.6f6ae7cd-631e-4030-9183-725f5a48c942.svs
# Selected OpenSlide level: 1
# Level dimensions: 42005 9216
# Level downsample: 4.000120410289284
# Patches saved so far: 1580
# Tissue patches seen so far: 1580
# Free disk after slide: 18.92 GB
# Downloading SVS 2/3: TCGA-A8-A09X-01A-01-TS1.d3ba5442-6c1f-4e86-8960-1befbfa026f3.svs
# Processing slide: TCGA-A8-A09X_1_TCGA-A8-A09X-01A-01-TS1.d3ba5442-6c1f-4e86-8960-1befbfa026f3.svs
# Selected OpenSlide level: 1
# Level dimensions: 33364 10290
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2435
# Free disk after slide: 18.89 GB
# Downloading SVS 3/3: TCGA-A8-A09X-01Z-00-DX1.17B5BE28-944F-427B-8F90-44885C3EDD36.svs
# Processing slide: TCGA-A8-A09X_2_TCGA-A8-A09X-01Z-00-DX1.17B5BE28-944F-427B-8F90-44885C3EDD36.svs
# Selected OpenSlide level: 1
# Level dimensions: 21376 30400
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 3094
# Free disk after slide: 18.89 GB
# Finished TCGA-A8-A09X: success, saved 2000 patches.
# Free disk after patient: 18.89 GB
#
# ================================================================================
# Patient 7/15: TCGA-A8-A09Z | BRCA_LumB
# Free disk before patient: 18.89 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A09Z-01A-01-BS1.b0b90543-85c2-4867-9ed7-9bf913e49cc8.svs
# Processing slide: TCGA-A8-A09Z_0_TCGA-A8-A09Z-01A-01-BS1.b0b90543-85c2-4867-9ed7-9bf913e49cc8.svs
# Selected OpenSlide level: 1
# Level dimensions: 40085 13360
# Level downsample: 4.000037425149701
# Patches saved so far: 940
# Tissue patches seen so far: 940
# Free disk after slide: 18.83 GB
# Downloading SVS 2/3: TCGA-A8-A09Z-01A-01-TS1.f9bd85b3-3a3e-43c7-90f2-6bfe1ba2bd35.svs
# Processing slide: TCGA-A8-A09Z_1_TCGA-A8-A09Z-01A-01-TS1.f9bd85b3-3a3e-43c7-90f2-6bfe1ba2bd35.svs
# Selected OpenSlide level: 1
# Level dimensions: 40565 7595
# Level downsample: 4.000065832784727
# Patches saved so far: 2000
# Tissue patches seen so far: 2496
# Free disk after slide: 18.77 GB
# Downloading SVS 3/3: TCGA-A8-A09Z-01Z-00-DX1.D56497BE-5099-4537-9600-60F3213F7BF5.svs
# Processing slide: TCGA-A8-A09Z_2_TCGA-A8-A09Z-01Z-00-DX1.D56497BE-5099-4537-9600-60F3213F7BF5.svs
# Selected OpenSlide level: 1
# Level dimensions: 24576 24384
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 4036
# Free disk after slide: 18.76 GB
# Finished TCGA-A8-A09Z: success, saved 2000 patches.
# Free disk after patient: 18.76 GB
#
# ================================================================================
# Patient 8/15: TCGA-A8-A0A1 | BRCA_LumA
# Free disk before patient: 18.76 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A0A1-01A-01-BS1.d1aa77ae-acf6-4469-828d-ac152d6e9ed9.svs
# Processing slide: TCGA-A8-A0A1_0_TCGA-A8-A0A1-01A-01-BS1.d1aa77ae-acf6-4469-828d-ac152d6e9ed9.svs
# Selected OpenSlide level: 1
# Level dimensions: 22082 10415
# Level downsample: 4.000067928629653
# Patches saved so far: 684
# Tissue patches seen so far: 684
# Free disk after slide: 18.73 GB
# Downloading SVS 2/3: TCGA-A8-A0A1-01A-01-TS1.eb96c625-348f-4355-a9d2-7e44853a1888.svs
# Processing slide: TCGA-A8-A0A1_1_TCGA-A8-A0A1-01A-01-TS1.eb96c625-348f-4355-a9d2-7e44853a1888.svs
# Selected OpenSlide level: 1
# Level dimensions: 32404 12305
# Level downsample: 4.00012190166599
# Patches saved so far: 1374
# Tissue patches seen so far: 1374
# Free disk after slide: 18.70 GB
# Downloading SVS 3/3: TCGA-A8-A0A1-01Z-00-DX1.CA64E221-E2A8-42B5-B611-25B9FE5FB0B0.svs
# Processing slide: TCGA-A8-A0A1_2_TCGA-A8-A0A1-01Z-00-DX1.CA64E221-E2A8-42B5-B611-25B9FE5FB0B0.svs
# Selected OpenSlide level: 1
# Level dimensions: 13376 21696
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2197
# Free disk after slide: 18.65 GB
# Finished TCGA-A8-A0A1: success, saved 2000 patches.
# Free disk after patient: 18.65 GB
#
# ================================================================================
# Patient 9/15: TCGA-A8-A0A2 | BRCA_LumA
# Free disk before patient: 18.65 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A0A2-01A-01-BS1.aa79e63b-6f53-4b40-8a47-8df76d7367d2.svs
# Processing slide: TCGA-A8-A0A2_0_TCGA-A8-A0A2-01A-01-BS1.aa79e63b-6f53-4b40-8a47-8df76d7367d2.svs
# Selected OpenSlide level: 1
# Level dimensions: 18962 6948
# Level downsample: 4.000242257991121
# Patches saved so far: 451
# Tissue patches seen so far: 451
# Free disk after slide: 18.63 GB
# Downloading SVS 2/3: TCGA-A8-A0A2-01A-01-TS1.124134ed-c4d2-4a08-937c-1def71bfcc42.svs
# Processing slide: TCGA-A8-A0A2_1_TCGA-A8-A0A2-01A-01-TS1.124134ed-c4d2-4a08-937c-1def71bfcc42.svs
# Selected OpenSlide level: 1
# Level dimensions: 20642 4372
# Level downsample: 4.000277173188943
# Patches saved so far: 697
# Tissue patches seen so far: 697
# Free disk after slide: 18.61 GB
# Downloading SVS 3/3: TCGA-A8-A0A2-01Z-00-DX1.47BCDF13-1065-466A-B7CB-F91F5EAD7D91.svs
# Processing slide: TCGA-A8-A0A2_2_TCGA-A8-A0A2-01Z-00-DX1.47BCDF13-1065-466A-B7CB-F91F5EAD7D91.svs
# Selected OpenSlide level: 1
# Level dimensions: 10432 28608
# Level downsample: 4.0
# Patches saved so far: 1127
# Tissue patches seen so far: 1127
# Free disk after slide: 18.58 GB
# Finished TCGA-A8-A0A2: success, saved 1127 patches.
# Free disk after patient: 18.58 GB
#
# ================================================================================
# Patient 10/15: TCGA-A8-A0A4 | BRCA_LumA
# Free disk before patient: 18.58 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A0A4-01A-01-BS1.b2f7bff9-16c8-4bf7-8228-fd2a98995fdf.svs
# Processing slide: TCGA-A8-A0A4_0_TCGA-A8-A0A4-01A-01-BS1.b2f7bff9-16c8-4bf7-8228-fd2a98995fdf.svs
# Selected OpenSlide level: 1
# Level dimensions: 29523 8615
# Level downsample: 4.000166884455295
# Patches saved so far: 1044
# Tissue patches seen so far: 1044
# Free disk after slide: 18.53 GB
# Downloading SVS 2/3: TCGA-A8-A0A4-01A-01-TS1.eaac12f0-ead1-4f67-875d-8bda8a4649d9.svs
# Processing slide: TCGA-A8-A0A4_1_TCGA-A8-A0A4-01A-01-TS1.eaac12f0-ead1-4f67-875d-8bda8a4649d9.svs
# Selected OpenSlide level: 1
# Level dimensions: 21602 4147
# Level downsample: 4.000166861096085
# Patches saved so far: 1345
# Tissue patches seen so far: 1345
# Free disk after slide: 18.52 GB
# Downloading SVS 3/3: TCGA-A8-A0A4-01Z-00-DX1.06C38F98-F34B-49F0-AFB5-7F0086188346.svs
# Processing slide: TCGA-A8-A0A4_2_TCGA-A8-A0A4-01Z-00-DX1.06C38F98-F34B-49F0-AFB5-7F0086188346.svs
# Selected OpenSlide level: 1
# Level dimensions: 9024 24384
# Level downsample: 4.0
# Patches saved so far: 1772
# Tissue patches seen so far: 1772
# Free disk after slide: 18.48 GB
# Finished TCGA-A8-A0A4: success, saved 1772 patches.
# Free disk after patient: 18.48 GB
#
# ================================================================================
# Patient 11/15: TCGA-A8-A0A6 | BRCA_LumA
# Free disk before patient: 18.48 GB
# SVS files found: 2
# Downloading SVS 1/2: TCGA-A8-A0A6-01A-01-MS1.8a85e02c-6098-4347-be13-b645b860057d.svs
# Processing slide: TCGA-A8-A0A6_0_TCGA-A8-A0A6-01A-01-MS1.8a85e02c-6098-4347-be13-b645b860057d.svs
# Selected OpenSlide level: 1
# Level dimensions: 30723 8558
# Level downsample: 4.000048823357094
# Patches saved so far: 1568
# Tissue patches seen so far: 1568
# Free disk after slide: 18.41 GB
# Downloading SVS 2/2: TCGA-A8-A0A6-01A-01-TS1.0544eda9-a392-4eed-961d-9a0683b54b5d.svs
# Processing slide: TCGA-A8-A0A6_1_TCGA-A8-A0A6-01A-01-TS1.0544eda9-a392-4eed-961d-9a0683b54b5d.svs
# Selected OpenSlide level: 1
# Level dimensions: 26883 10465
# Level downsample: 4.00006637742333
# Patches saved so far: 2000
# Tissue patches seen so far: 2622
# Free disk after slide: 18.38 GB
# Finished TCGA-A8-A0A6: success, saved 2000 patches.
# Free disk after patient: 18.38 GB
#
# ================================================================================
# Patient 12/15: TCGA-A8-A0A7 | BRCA_Her2
# Free disk before patient: 18.38 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A0A7-01A-01-BS1.4a4d1511-7d0f-4482-bd6c-7a1ebbfe2ce6.svs
# Processing slide: TCGA-A8-A0A7_0_TCGA-A8-A0A7-01A-01-BS1.4a4d1511-7d0f-4482-bd6c-7a1ebbfe2ce6.svs
# Selected OpenSlide level: 1
# Level dimensions: 8881 8135
# Level downsample: 4.000122925629993
# Patches saved so far: 495
# Tissue patches seen so far: 495
# Free disk after slide: 18.36 GB
# Downloading SVS 2/3: TCGA-A8-A0A7-01A-01-TS1.dfc11237-aff0-442f-8a39-ce81f0d4aeb1.svs
# Processing slide: TCGA-A8-A0A7_1_TCGA-A8-A0A7-01A-01-TS1.dfc11237-aff0-442f-8a39-ce81f0d4aeb1.svs
# Selected OpenSlide level: 1
# Level dimensions: 22982 10678
# Level downsample: 4.000140475744521
# Patches saved so far: 1406
# Tissue patches seen so far: 1406
# Free disk after slide: 18.31 GB
# Downloading SVS 3/3: TCGA-A8-A0A7-01Z-00-DX1.A0FD4EEF-B536-47C1-BDA1-7AC71BA3E978.svs
# Processing slide: TCGA-A8-A0A7_2_TCGA-A8-A0A7-01Z-00-DX1.A0FD4EEF-B536-47C1-BDA1-7AC71BA3E978.svs
# Selected OpenSlide level: 1
# Level dimensions: 9408 13248
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2153
# Free disk after slide: 18.26 GB
# Finished TCGA-A8-A0A7: success, saved 2000 patches.
# Free disk after patient: 18.26 GB
#
# ================================================================================
# Patient 13/15: TCGA-A8-A0A9 | BRCA_LumA
# Free disk before patient: 18.26 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A0A9-01A-01-BS1.eda51aaf-8be8-4dec-b584-1ae0ea5096e0.svs
# Processing slide: TCGA-A8-A0A9_0_TCGA-A8-A0A9-01A-01-BS1.eda51aaf-8be8-4dec-b584-1ae0ea5096e0.svs
# Selected OpenSlide level: 1
# Level dimensions: 24243 8118
# Level downsample: 4.0
# Patches saved so far: 1085
# Tissue patches seen so far: 1085
# Free disk after slide: 18.21 GB
# Downloading SVS 2/3: TCGA-A8-A0A9-01A-01-TS1.12f6478b-a0c9-4051-8688-c40183e6e62c.svs
# Processing slide: TCGA-A8-A0A9_1_TCGA-A8-A0A9-01A-01-TS1.12f6478b-a0c9-4051-8688-c40183e6e62c.svs
# Selected OpenSlide level: 1
# Level dimensions: 21362 7561
# Level downsample: 4.000245198553063
# Patches saved so far: 1823
# Tissue patches seen so far: 1823
# Free disk after slide: 18.17 GB
# Downloading SVS 3/3: TCGA-A8-A0A9-01Z-00-DX1.16524DDD-539D-4E47-9A8F-1B910D4FEC2D.svs
# Processing slide: TCGA-A8-A0A9_2_TCGA-A8-A0A9-01Z-00-DX1.16524DDD-539D-4E47-9A8F-1B910D4FEC2D.svs
# Selected OpenSlide level: 1
# Level dimensions: 9536 6592
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2155
# Free disk after slide: 18.15 GB
# Finished TCGA-A8-A0A9: success, saved 2000 patches.
# Free disk after patient: 18.15 GB
#
# ================================================================================
# Patient 14/15: TCGA-A8-A0AB | BRCA_LumA
# Free disk before patient: 18.15 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A0AB-01A-01-BS1.4f685a36-8110-4af5-b290-7384bee2c8f6.svs
# Processing slide: TCGA-A8-A0AB_0_TCGA-A8-A0AB-01A-01-BS1.4f685a36-8110-4af5-b290-7384bee2c8f6.svs
# Selected OpenSlide level: 1
# Level dimensions: 22802 8119
# Level downsample: 4.000188951581001
# Patches saved so far: 721
# Tissue patches seen so far: 721
# Free disk after slide: 18.12 GB
# Downloading SVS 2/3: TCGA-A8-A0AB-01A-01-TS1.caa920cc-a74f-41a3-9b12-d8143dda8786.svs
# Processing slide: TCGA-A8-A0AB_1_TCGA-A8-A0AB-01A-01-TS1.caa920cc-a74f-41a3-9b12-d8143dda8786.svs
# Selected OpenSlide level: 1
# Level dimensions: 20642 8569
# Level downsample: 4.000165144649719
# Patches saved so far: 1306
# Tissue patches seen so far: 1306
# Free disk after slide: 18.09 GB
# Downloading SVS 3/3: TCGA-A8-A0AB-01Z-00-DX1.103ED338-A0F9-403B-A10C-49840BD60EB8.svs
# Processing slide: TCGA-A8-A0AB_2_TCGA-A8-A0AB-01Z-00-DX1.103ED338-A0F9-403B-A10C-49840BD60EB8.svs
# Selected OpenSlide level: 1
# Level dimensions: 8896 10688
# Level downsample: 4.0
# Patches saved so far: 1674
# Tissue patches seen so far: 1674
# Free disk after slide: 18.06 GB
# Finished TCGA-A8-A0AB: success, saved 1674 patches.
# Free disk after patient: 18.06 GB
#
# ================================================================================
# Patient 15/15: TCGA-A8-A0AD | BRCA_LumA
# Free disk before patient: 18.06 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A0AD-01A-01-BS1.bb944067-e1c7-495d-8d92-957340d3173e.svs
# Processing slide: TCGA-A8-A0AD_0_TCGA-A8-A0AD-01A-01-BS1.bb944067-e1c7-495d-8d92-957340d3173e.svs
# Selected OpenSlide level: 1
# Level dimensions: 23042 11197
# Level downsample: 4.000109753334009
# Patches saved so far: 683
# Tissue patches seen so far: 683
# Free disk after slide: 18.02 GB
# Downloading SVS 2/3: TCGA-A8-A0AD-01A-01-TS1.4f7d3b85-05f4-44d2-8176-3ee94105f10f.svs
# Processing slide: TCGA-A8-A0AD_1_TCGA-A8-A0AD-01A-01-TS1.4f7d3b85-05f4-44d2-8176-3ee94105f10f.svs
# Selected OpenSlide level: 1
# Level dimensions: 21842 8904
# Level downsample: 4.000068675029759
# Patches saved so far: 1366
# Tissue patches seen so far: 1366
# Free disk after slide: 17.98 GB
# Downloading SVS 3/3: TCGA-A8-A0AD-01Z-00-DX1.A831FB53-7605-4138-9341-6BBCA284441C.svs
# Processing slide: TCGA-A8-A0AD_2_TCGA-A8-A0AD-01Z-00-DX1.A831FB53-7605-4138-9341-6BBCA284441C.svs
# Selected OpenSlide level: 1
# Level dimensions: 10560 12224
# Level downsample: 4.0
# Patches saved so far: 1742
# Tissue patches seen so far: 1742
# Free disk after slide: 17.96 GB
# Finished TCGA-A8-A0AD: success, saved 1742 patches.
# Free disk after patient: 17.96 GB
#
# ================================================================================
# A8 batch 5 + retry preprocessing finished.
# Patch output folder: /kaggle/working/patches/A8
# Log file: /kaggle/working/preprocessing_log.csv
#       patient_id  jpg_count
# 0   TCGA-A8-A06N       2000
# 1   TCGA-A8-A08A       2000
# 2   TCGA-A8-A09T       1457
# 3   TCGA-A8-A09V       1047
# 4   TCGA-A8-A09W       2000
# 5   TCGA-A8-A09X       2000
# 6   TCGA-A8-A09Z       2000
# 7   TCGA-A8-A0A1       2000
# 8   TCGA-A8-A0A2       1127
# 9   TCGA-A8-A0A4       1772
# 10  TCGA-A8-A0A6       2000
# 11  TCGA-A8-A0A7       2000
# 12  TCGA-A8-A0A9       2000
# 13  TCGA-A8-A0AB       1674
# 14  TCGA-A8-A0AD       1742
#       patient_id    subtype   status  patches_saved  tissue_patches_seen  \
# 0   TCGA-A8-A06N  BRCA_LumB  success           2000                 2712
# 1   TCGA-A8-A08A  BRCA_LumA  success           2000                 2205
# 2   TCGA-A8-A09T  BRCA_LumA  success           1457                 1457
# 3   TCGA-A8-A09V  BRCA_LumA  success           1047                 1047
# 4   TCGA-A8-A09W  BRCA_LumB  success           2000                 2350
# 5   TCGA-A8-A09X  BRCA_Her2  success           2000                 3094
# 6   TCGA-A8-A09Z  BRCA_LumB  success           2000                 4036
# 7   TCGA-A8-A0A1  BRCA_LumA  success           2000                 2197
# 8   TCGA-A8-A0A2  BRCA_LumA  success           1127                 1127
# 9   TCGA-A8-A0A4  BRCA_LumA  success           1772                 1772
# 10  TCGA-A8-A0A6  BRCA_LumA  success           2000                 2622
# 11  TCGA-A8-A0A7  BRCA_Her2  success           2000                 2153
# 12  TCGA-A8-A0A9  BRCA_LumA  success           2000                 2155
# 13  TCGA-A8-A0AB  BRCA_LumA  success           1674                 1674
# 14  TCGA-A8-A0AD  BRCA_LumA  success           1742                 1742
#
#     svs_files_found  error_message
# 0                 3            NaN
# 1                 3            NaN
# 2                 3            NaN
# 3                 3            NaN
# 4                 3            NaN
# 5                 3            NaN
# 6                 3            NaN
# 7                 3            NaN
# 8                 3            NaN
# 9                 3            NaN
# 10                2            NaN
# 11                3            NaN
# 12                3            NaN
# 13                3            NaN
# 14                3            NaN
