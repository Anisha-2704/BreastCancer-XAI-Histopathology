# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/anishapanja/bc-xai-macenko-reference-a2e2/reference_tile.png
# /kaggle/input/datasets/anishapanja/brca-pancancer-atlas-clinical/data_clinical_patient.txt

# %%
# Install OpenSlide system tools for reading SVS whole-slide images.
import subprocess
subprocess.run(["apt-get", "install", "-y", "openslide-tools", "-q"], check=True)

# Install only libraries that work on Kaggle Python 3.12.
# Do NOT install staintools because it imports missing spams on Python 3.12.
subprocess.run(["pip", "install", "openslide-python", "scikit-image", "requests", "-q"], check=True)

# Import standard libraries.
import os
import gc
import csv
import json
import shutil
import random
import traceback
from pathlib import Path

# Import scientific and image-processing libraries.
import cv2
import numpy as np
import pandas as pd
import requests
import openslide
from PIL import Image

# Fixed random seed for reproducibility.
SEED = 42
rng = random.Random(SEED)

# Site and batch settings.
SITE_CODE = "A8"
BATCH_SIZE = 15

# Frozen preprocessing parameters.
PATCH_SIZE = 256
STRIDE = 256
TARGET_MPP = 1.0
MIN_TISSUE_FRACTION = 0.50
SATURATION_THRESHOLD = 15
MAX_PATCHES_PER_PATIENT = 2000
JPEG_QUALITY = 95

# Output paths.
WORK_DIR = Path("/kaggle/working")
PATCH_ROOT = WORK_DIR / "patches" / SITE_CODE
TMP_DIR = WORK_DIR / "tmp_svs"
LOG_PATH = WORK_DIR / "preprocessing_log.csv"

# Create output folders.
PATCH_ROOT.mkdir(parents=True, exist_ok=True)
TMP_DIR.mkdir(parents=True, exist_ok=True)

# Find an input file by exact filename.
def find_input_file(filename):
    for root, dirs, files in os.walk("/kaggle/input"):
        if filename in files:
            return Path(root) / filename
    raise FileNotFoundError(f"Could not find {filename} under /kaggle/input")

# Locate clinical labels and reference tile.
clinical_path = find_input_file("data_clinical_patient.txt")
reference_path = find_input_file("reference_tile.png")

# Load clinical data.
clinical_df = pd.read_csv(clinical_path, sep="\t", comment="#", low_memory=False)

# Keep labeled A8 patients only.
a8_df = clinical_df[
    clinical_df["PATIENT_ID"].astype(str).str.startswith("TCGA-A8-")
    & clinical_df["SUBTYPE"].notna()
    & (clinical_df["SUBTYPE"] != "BRCA_Normal")
].copy()

# Sort for deterministic batch order.
a8_df = a8_df.sort_values("PATIENT_ID").reset_index(drop=True)

# -----------------------------
# A8 Batch 2
# -----------------------------
BATCH_START = 15
BATCH_END = 30

batch_df = a8_df.iloc[BATCH_START:BATCH_END].copy()
# Print sanity checks.
print("Clinical file:", clinical_path)
print("Reference tile:", reference_path)
print("Total labeled A8 patients:", a8_df["PATIENT_ID"].nunique())
print("A8 Batch 2 patients:", batch_df["PATIENT_ID"].tolist())
print("A8 Batch 2 subtype counts:")
print(batch_df["SUBTYPE"].value_counts())

# Luminosity standardization similar to staintools.
def standardize_luminosity(img):
    img = img.astype(np.float32)
    p = np.percentile(img, 95)
    if p <= 0:
        return np.clip(img, 0, 255).astype(np.uint8)
    img = img * (255.0 / p)
    return np.clip(img, 0, 255).astype(np.uint8)

# Convert RGB to optical density.
def rgb_to_od(img):
    img = img.astype(np.float32)
    return -np.log((img + 1.0) / 255.0)

# Convert optical density back to RGB.
def od_to_rgb(od):
    rgb = 255.0 * np.exp(-od)
    return np.clip(rgb, 0, 255).astype(np.uint8)

# Estimate Macenko H&E stain matrix.
def get_macenko_stain_matrix(img, beta=0.15, alpha=1):
    img = standardize_luminosity(img)
    od = rgb_to_od(img).reshape((-1, 3))
    od = od[np.all(od > beta, axis=1)]

    if od.shape[0] < 100:
        raise RuntimeError("Too few tissue pixels for Macenko fitting.")

    _, _, vh = np.linalg.svd(od, full_matrices=False)
    top_vectors = vh[:2].T

    projected = np.dot(od, top_vectors)
    angles = np.arctan2(projected[:, 1], projected[:, 0])

    min_angle = np.percentile(angles, alpha)
    max_angle = np.percentile(angles, 100 - alpha)

    v1 = np.dot(top_vectors, np.array([np.cos(min_angle), np.sin(min_angle)]))
    v2 = np.dot(top_vectors, np.array([np.cos(max_angle), np.sin(max_angle)]))

    if v1[0] > v2[0]:
        he = np.stack([v1, v2], axis=1)
    else:
        he = np.stack([v2, v1], axis=1)

    he = he / np.linalg.norm(he, axis=0, keepdims=True)
    return he

# Estimate stain concentrations.
def get_concentrations(img, stain_matrix):
    od = rgb_to_od(img).reshape((-1, 3)).T
    concentrations, _, _, _ = np.linalg.lstsq(stain_matrix, od, rcond=None)
    return concentrations

# Fit fixed reference Macenko target once.
reference_img = np.array(Image.open(reference_path).convert("RGB"))
reference_img = standardize_luminosity(reference_img)
reference_he = get_macenko_stain_matrix(reference_img)
reference_conc = get_concentrations(reference_img, reference_he)
reference_max = np.percentile(reference_conc, 99, axis=1)

# Normalize one patch to the fixed reference tile.
def normalize_patch(rgb_patch):
    try:
        patch = standardize_luminosity(rgb_patch)
        source_he = get_macenko_stain_matrix(patch)
        source_conc = get_concentrations(patch, source_he)
        source_max = np.percentile(source_conc, 99, axis=1)
        scale = reference_max / (source_max + 1e-8)
        source_conc = source_conc * scale[:, None]
        normalized_od = np.dot(reference_he, source_conc).T.reshape(patch.shape)
        normalized_rgb = od_to_rgb(normalized_od)
        return normalized_rgb
    except Exception:
        return rgb_patch

# Append one row to the preprocessing log.
def write_log(row):
    file_exists = LOG_PATH.exists()
    with open(LOG_PATH, "a", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(
            f,
            fieldnames=[
                "patient_id",
                "subtype",
                "status",
                "patches_saved",
                "tissue_patches_seen",
                "svs_files_found",
                "error_message",
            ],
        )
        if not file_exists:
            writer.writeheader()
        writer.writerow(row)

# Free disk space in GB.
def free_disk_gb(path="/kaggle/working"):
    usage = shutil.disk_usage(path)
    return usage.free / (1024 ** 3)

# Query GDC for open SVS slide files for one patient.
def query_gdc_svs_files(patient_id):
    filters = {
        "op": "and",
        "content": [
            {"op": "in", "content": {"field": "cases.submitter_id", "value": [patient_id]}},
            {"op": "in", "content": {"field": "data_type", "value": ["Slide Image"]}},
            {"op": "in", "content": {"field": "access", "value": ["open"]}},
        ],
    }

    params = {
        "filters": json.dumps(filters),
        "fields": "file_id,file_name,file_size,cases.submitter_id",
        "format": "JSON",
        "size": "200",
    }

    response = requests.get("https://api.gdc.cancer.gov/files", params=params, timeout=60)
    response.raise_for_status()
    hits = response.json()["data"]["hits"]

    svs_hits = [h for h in hits if str(h.get("file_name", "")).lower().endswith(".svs")]
    svs_hits = sorted(svs_hits, key=lambda x: x.get("file_name", ""))
    return svs_hits

# Stream-download one SVS file.
def download_svs(file_id, out_path):
    url = f"https://api.gdc.cancer.gov/data/{file_id}"

    with requests.get(url, stream=True, timeout=120) as response:
        response.raise_for_status()
        with open(out_path, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)

    if out_path.stat().st_size <= 1_000_000:
        raise RuntimeError(f"Downloaded SVS is too small: {out_path.stat().st_size} bytes")

# Choose OpenSlide level closest to 1 micrometer per pixel.
def choose_level_for_target_mpp(slide):
    mpp_x = slide.properties.get("openslide.mpp-x")

    if mpp_x is not None:
        base_mpp = float(mpp_x)
        target_downsample = TARGET_MPP / base_mpp
    else:
        target_downsample = 4.0

    downsamples = [float(d) for d in slide.level_downsamples]
    level = int(np.argmin([abs(d - target_downsample) for d in downsamples]))
    return level

# Tissue detection using HSV saturation.
def tissue_fraction_hsv(rgb_patch):
    hsv = cv2.cvtColor(rgb_patch, cv2.COLOR_RGB2HSV)
    saturation = hsv[:, :, 1]
    return float(np.mean(saturation > SATURATION_THRESHOLD))

# Save RGB patch as JPEG.
def save_jpeg(rgb_patch, out_path):
    Image.fromarray(rgb_patch).save(out_path, format="JPEG", quality=JPEG_QUALITY)

# Process one SVS slide into patient patch folder.
def process_slide_into_patient_reservoir(slide_path, patient_dir, patient_id, current_saved, tissue_seen):
    slide = openslide.open_slide(str(slide_path))
    level = choose_level_for_target_mpp(slide)
    level_w, level_h = slide.level_dimensions[level]
    downsample = float(slide.level_downsamples[level])

    print("Selected OpenSlide level:", level)
    print("Level dimensions:", level_w, level_h)
    print("Level downsample:", downsample)

    for y in range(0, level_h - PATCH_SIZE + 1, STRIDE):
        for x in range(0, level_w - PATCH_SIZE + 1, STRIDE):
            level0_x = int(x * downsample)
            level0_y = int(y * downsample)

            patch_rgba = slide.read_region((level0_x, level0_y), level, (PATCH_SIZE, PATCH_SIZE))
            patch_rgb = np.array(patch_rgba.convert("RGB"))

            if tissue_fraction_hsv(patch_rgb) < MIN_TISSUE_FRACTION:
                continue

            tissue_seen += 1
            patch_rgb = normalize_patch(patch_rgb)

            if current_saved < MAX_PATCHES_PER_PATIENT:
                out_index = current_saved
                current_saved += 1
            else:
                replacement_index = rng.randint(0, tissue_seen - 1)
                if replacement_index >= MAX_PATCHES_PER_PATIENT:
                    continue
                out_index = replacement_index

            out_name = f"{patient_id}_{out_index:05d}.jpg"
            out_path = patient_dir / out_name
            save_jpeg(patch_rgb, out_path)

    slide.close()
    return current_saved, tissue_seen

# Process each patient in A8 Batch 2.
for row_index, row in batch_df.iterrows():
    patient_id = row["PATIENT_ID"]
    subtype = row["SUBTYPE"]
    patient_dir = PATCH_ROOT / patient_id

    print("\n" + "=" * 80)
    print(f"Patient {row_index + 1}/{len(batch_df)}: {patient_id} | {subtype}")
    print(f"Free disk before patient: {free_disk_gb():.2f} GB")

    if patient_dir.exists() and any(patient_dir.glob("*.jpg")):
        existing_count = len(list(patient_dir.glob("*.jpg")))
        print(f"Skipping existing patient folder with {existing_count} JPEGs.")
        write_log({
            "patient_id": patient_id,
            "subtype": subtype,
            "status": "skipped_existing",
            "patches_saved": existing_count,
            "tissue_patches_seen": "",
            "svs_files_found": "",
            "error_message": "",
        })
        continue

    if free_disk_gb() < 2.0:
        print("Stopping safely because free disk is below 2 GB.")
        break

    patient_dir.mkdir(parents=True, exist_ok=True)

    current_saved = 0
    tissue_seen = 0
    svs_files = []

    try:
        svs_files = query_gdc_svs_files(patient_id)
        print(f"SVS files found: {len(svs_files)}")

        if len(svs_files) == 0:
            raise RuntimeError("No open SVS files found in GDC.")

        for svs_index, svs in enumerate(svs_files):
            if free_disk_gb() < 2.0:
                raise RuntimeError("Free disk dropped below 2 GB before download.")

            file_id = svs["file_id"]
            file_name = svs["file_name"]
            svs_path = TMP_DIR / f"{patient_id}_{svs_index}_{file_name}"

            print(f"Downloading SVS {svs_index + 1}/{len(svs_files)}: {file_name}")
            download_svs(file_id, svs_path)

            print(f"Processing slide: {svs_path.name}")
            current_saved, tissue_seen = process_slide_into_patient_reservoir(
                svs_path,
                patient_dir,
                patient_id,
                current_saved,
                tissue_seen,
            )

            if svs_path.exists():
                os.remove(svs_path)

            gc.collect()

            print(f"Patches saved so far: {current_saved}")
            print(f"Tissue patches seen so far: {tissue_seen}")
            print(f"Free disk after slide: {free_disk_gb():.2f} GB")

        status = "success" if current_saved > 0 else "failed_no_patches"

        write_log({
            "patient_id": patient_id,
            "subtype": subtype,
            "status": status,
            "patches_saved": current_saved,
            "tissue_patches_seen": tissue_seen,
            "svs_files_found": len(svs_files),
            "error_message": "",
        })

        print(f"Finished {patient_id}: {status}, saved {current_saved} patches.")

    except Exception as e:
        error_message = repr(e)
        print(f"FAILED {patient_id}: {error_message}")
        print(traceback.format_exc())

        for leftover in TMP_DIR.glob(f"{patient_id}_*"):
            try:
                os.remove(leftover)
            except Exception:
                pass

        write_log({
            "patient_id": patient_id,
            "subtype": subtype,
            "status": "failed",
            "patches_saved": current_saved,
            "tissue_patches_seen": tissue_seen,
            "svs_files_found": len(svs_files),
            "error_message": error_message,
        })

    print(f"Free disk after patient: {free_disk_gb():.2f} GB")

# Final summary.
print("\n" + "=" * 80)
print("A8 batch 2 preprocessing finished.")
print("Patch output folder:", PATCH_ROOT)
print("Log file:", LOG_PATH)

summary_rows = []
for patient_folder in sorted(PATCH_ROOT.glob("TCGA-A8-*")):
    summary_rows.append({
        "patient_id": patient_folder.name,
        "jpg_count": len(list(patient_folder.glob("*.jpg"))),
    })

summary_df = pd.DataFrame(summary_rows)
print(summary_df)

if LOG_PATH.exists():
    print(pd.read_csv(LOG_PATH))
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   libopenslide0
# Suggested packages:
#   libtiff-tools
# The following NEW packages will be installed:
#   libopenslide0 openslide-tools
# 0 upgraded, 2 newly installed, 0 to remove and 83 not upgraded.
# Need to get 104 kB of archives.
# After this operation, 297 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenslide0 amd64 3.4.1+dfsg-5build1 [89.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 openslide-tools amd64 3.4.1+dfsg-5build1 [13.8 kB]
# Fetched 104 kB in 1s (194 kB/s)
# Selecting previously unselected package libopenslide0.
# (Reading database ... 121026 files and directories currently installed.)
# Preparing to unpack .../libopenslide0_3.4.1+dfsg-5build1_amd64.deb ...
# Unpacking libopenslide0 (3.4.1+dfsg-5build1) ...
# Selecting previously unselected package openslide-tools.
# Preparing to unpack .../openslide-tools_3.4.1+dfsg-5build1_amd64.deb ...
# Unpacking openslide-tools (3.4.1+dfsg-5build1) ...
# Setting up libopenslide0 (3.4.1+dfsg-5build1) ...
# Setting up openslide-tools (3.4.1+dfsg-5build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# Clinical file: /kaggle/input/datasets/anishapanja/brca-pancancer-atlas-clinical/data_clinical_patient.txt
# Reference tile: /kaggle/input/datasets/anishapanja/bc-xai-macenko-reference-a2e2/reference_tile.png
# Total labeled A8 patients: 73
# A8 Batch 2 patients: ['TCGA-A8-A07F', 'TCGA-A8-A07G', 'TCGA-A8-A07I', 'TCGA-A8-A07J', 'TCGA-A8-A07L', 'TCGA-A8-A07O', 'TCGA-A8-A07P', 'TCGA-A8-A07U', 'TCGA-A8-A07W', 'TCGA-A8-A07Z', 'TCGA-A8-A081', 'TCGA-A8-A082', 'TCGA-A8-A083', 'TCGA-A8-A086', 'TCGA-A8-A08A']
# A8 Batch 2 subtype counts:
# SUBTYPE
# BRCA_LumA     8
# BRCA_LumB     4
# BRCA_Basal    2
# BRCA_Her2     1
# Name: count, dtype: int64
#
# ================================================================================
# Patient 16/15: TCGA-A8-A07F | BRCA_LumA
# Free disk before patient: 19.50 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A07F-01A-01-BS1.288ddf7f-30dc-4fed-a4ca-18fa8172e3ee.svs
# Processing slide: TCGA-A8-A07F_0_TCGA-A8-A07F-01A-01-BS1.288ddf7f-30dc-4fed-a4ca-18fa8172e3ee.svs
# Selected OpenSlide level: 1
# Level dimensions: 26403 10745
# Level downsample: 4.000158537055847
# /tmp/ipykernel_16/1820722635.py:109: RuntimeWarning: overflow encountered in exp
#   rgb = 255.0 * np.exp(-od)
# /tmp/ipykernel_16/1820722635.py:109: RuntimeWarning: overflow encountered in multiply
#   rgb = 255.0 * np.exp(-od)
# Patches saved so far: 720
# Tissue patches seen so far: 720
# Free disk after slide: 19.46 GB
# Downloading SVS 2/3: TCGA-A8-A07F-01A-01-TS1.b4547802-0778-49f5-8465-4e3de9ffbf41.svs
# Processing slide: TCGA-A8-A07F_1_TCGA-A8-A07F-01A-01-TS1.b4547802-0778-49f5-8465-4e3de9ffbf41.svs
# Selected OpenSlide level: 1
# Level dimensions: 13681 8297
# Level downsample: 4.000253882308783
# Patches saved so far: 962
# Tissue patches seen so far: 962
# Free disk after slide: 19.45 GB
# Downloading SVS 3/3: TCGA-A8-A07F-01Z-00-DX1.E6FE5B3A-A412-4E7B-A710-7DFD3596F4E3.svs
# Processing slide: TCGA-A8-A07F_2_TCGA-A8-A07F-01Z-00-DX1.E6FE5B3A-A412-4E7B-A710-7DFD3596F4E3.svs
# Selected OpenSlide level: 1
# Level dimensions: 18944 15424
# Level downsample: 4.0
# Patches saved so far: 1558
# Tissue patches seen so far: 1558
# Free disk after slide: 19.42 GB
# Finished TCGA-A8-A07F: success, saved 1558 patches.
# Free disk after patient: 19.42 GB
#
# ================================================================================
# Patient 17/15: TCGA-A8-A07G | BRCA_LumA
# Free disk before patient: 19.42 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A07G-01A-01-BS1.77d7598e-9d52-424b-8e97-50f45155b8b7.svs
# Processing slide: TCGA-A8-A07G_0_TCGA-A8-A07G-01A-01-BS1.77d7598e-9d52-424b-8e97-50f45155b8b7.svs
# Selected OpenSlide level: 1
# Level dimensions: 26643 8618
# Level downsample: 4.00019282096035
# Patches saved so far: 900
# Tissue patches seen so far: 900
# Free disk after slide: 19.38 GB
# Downloading SVS 2/3: TCGA-A8-A07G-01A-01-TS1.ed5520f2-535b-4bb4-b580-b2372714d3fb.svs
# Processing slide: TCGA-A8-A07G_1_TCGA-A8-A07G-01A-01-TS1.ed5520f2-535b-4bb4-b580-b2372714d3fb.svs
# Selected OpenSlide level: 1
# Level dimensions: 20402 5044
# Level downsample: 4.000049014802471
# Patches saved so far: 1273
# Tissue patches seen so far: 1273
# Free disk after slide: 19.36 GB
# Downloading SVS 3/3: TCGA-A8-A07G-01Z-00-DX1.37E8A762-8141-4BE6-935A-B3DCB712BB4A.svs
# Processing slide: TCGA-A8-A07G_2_TCGA-A8-A07G-01Z-00-DX1.37E8A762-8141-4BE6-935A-B3DCB712BB4A.svs
# Selected OpenSlide level: 1
# Level dimensions: 12608 11968
# Level downsample: 4.0
# Patches saved so far: 1338
# Tissue patches seen so far: 1338
# Free disk after slide: 19.35 GB
# Finished TCGA-A8-A07G: success, saved 1338 patches.
# Free disk after patient: 19.35 GB
#
# ================================================================================
# Patient 18/15: TCGA-A8-A07I | BRCA_Her2
# Free disk before patient: 19.35 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A07I-01A-01-BSA.f3f1a0f0-5e66-4829-aa6d-c692c13a8bf8.svs
# Processing slide: TCGA-A8-A07I_0_TCGA-A8-A07I-01A-01-BSA.f3f1a0f0-5e66-4829-aa6d-c692c13a8bf8.svs
# Selected OpenSlide level: 1
# Level dimensions: 40325 7819
# Level downsample: 4.000127893592531
# Patches saved so far: 399
# Tissue patches seen so far: 399
# Free disk after slide: 19.33 GB
# Downloading SVS 2/3: TCGA-A8-A07I-01A-01-TSA.582a3393-09bb-43b2-907c-ba9c27db5b13.svs
# Processing slide: TCGA-A8-A07I_1_TCGA-A8-A07I-01A-01-TSA.582a3393-09bb-43b2-907c-ba9c27db5b13.svs
# Selected OpenSlide level: 1
# Level dimensions: 38404 6926
# Level downsample: 4.0001112501726785
# Patches saved so far: 1186
# Tissue patches seen so far: 1186
# Free disk after slide: 19.29 GB
# Downloading SVS 3/3: TCGA-A8-A07I-01Z-00-DX1.37E7BB2E-8210-4216-B75F-0FD06D6C9AE3.svs
# Processing slide: TCGA-A8-A07I_2_TCGA-A8-A07I-01Z-00-DX1.37E7BB2E-8210-4216-B75F-0FD06D6C9AE3.svs
# Selected OpenSlide level: 1
# Level dimensions: 13632 19392
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2167
# Free disk after slide: 19.24 GB
# Finished TCGA-A8-A07I: success, saved 2000 patches.
# Free disk after patient: 19.24 GB
#
# ================================================================================
# Patient 19/15: TCGA-A8-A07J | BRCA_LumA
# Free disk before patient: 19.24 GB
# SVS files found: 4
# Downloading SVS 1/4: TCGA-A8-A07J-01A-01-BS1.c9f54364-bf94-4431-9d02-8c2ec1732d02.svs
# Processing slide: TCGA-A8-A07J_0_TCGA-A8-A07J-01A-01-BS1.c9f54364-bf94-4431-9d02-8c2ec1732d02.svs
# Selected OpenSlide level: 1
# Level dimensions: 33754 10679
# Level downsample: 4.000091260040955
# Patches saved so far: 1204
# Tissue patches seen so far: 1204
# Free disk after slide: 19.18 GB
# Downloading SVS 2/4: TCGA-A8-A07J-01A-01-TS1.d11bd110-d6ef-46c3-b41c-c09ef5f61f3d.svs
# Processing slide: TCGA-A8-A07J_1_TCGA-A8-A07J-01A-01-TS1.d11bd110-d6ef-46c3-b41c-c09ef5f61f3d.svs
# Selected OpenSlide level: 1
# Level dimensions: 18912 8598
# Level downsample: 4.000142744357973
# Patches saved so far: 1832
# Tissue patches seen so far: 1832
# Free disk after slide: 19.14 GB
# Downloading SVS 3/4: TCGA-A8-A07J-01A-02-BS2.5d44b586-7e36-46f9-bfc8-8f8afce34625.svs
# Processing slide: TCGA-A8-A07J_2_TCGA-A8-A07J-01A-02-BS2.5d44b586-7e36-46f9-bfc8-8f8afce34625.svs
# Selected OpenSlide level: 1
# Level dimensions: 35909 8562
# Level downsample: 4.000027848171768
# Patches saved so far: 2000
# Tissue patches seen so far: 2812
# Free disk after slide: 19.14 GB
# Downloading SVS 4/4: TCGA-A8-A07J-01Z-00-DX1.FE16248C-D890-4750-A9FC-5F72BE8D8B85.svs
# Processing slide: TCGA-A8-A07J_3_TCGA-A8-A07J-01Z-00-DX1.FE16248C-D890-4750-A9FC-5F72BE8D8B85.svs
# Selected OpenSlide level: 1
# Level dimensions: 10560 11072
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 3264
# Free disk after slide: 19.13 GB
# Finished TCGA-A8-A07J: success, saved 2000 patches.
# Free disk after patient: 19.13 GB
#
# ================================================================================
# Patient 20/15: TCGA-A8-A07L | BRCA_LumB
# Free disk before patient: 19.13 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A07L-01A-01-BS1.d3dbb2ea-0d8a-4fe3-8a68-77c86ce5dd6b.svs
# Processing slide: TCGA-A8-A07L_0_TCGA-A8-A07L-01A-01-BS1.d3dbb2ea-0d8a-4fe3-8a68-77c86ce5dd6b.svs
# Selected OpenSlide level: 1
# Level dimensions: 24418 5888
# Level downsample: 4.000020476697518
# Patches saved so far: 1103
# Tissue patches seen so far: 1103
# Free disk after slide: 19.07 GB
# Downloading SVS 2/3: TCGA-A8-A07L-01A-01-TS1.ef6b6a88-8ca0-4d4f-90fe-4996e6a12e0f.svs
# Processing slide: TCGA-A8-A07L_1_TCGA-A8-A07L-01A-01-TS1.ef6b6a88-8ca0-4d4f-90fe-4996e6a12e0f.svs
# Selected OpenSlide level: 1
# Level dimensions: 30164 6619
# Level downsample: 4.000226620335399
# Patches saved so far: 2000
# Tissue patches seen so far: 2037
# Free disk after slide: 19.02 GB
# Downloading SVS 3/3: TCGA-A8-A07L-01Z-00-DX1.D9E1051F-724E-4E88-940A-C97005DC5BEB.svs
# Processing slide: TCGA-A8-A07L_2_TCGA-A8-A07L-01Z-00-DX1.D9E1051F-724E-4E88-940A-C97005DC5BEB.svs
# Selected OpenSlide level: 1
# Level dimensions: 9792 9792
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2512
# Free disk after slide: 19.02 GB
# Finished TCGA-A8-A07L: success, saved 2000 patches.
# Free disk after patient: 19.02 GB
#
# ================================================================================
# Patient 21/15: TCGA-A8-A07O | BRCA_Basal
# Free disk before patient: 19.02 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A07O-01A-01-BS1.073882c6-14ca-4b97-8992-fbfe1e9479c7.svs
# Processing slide: TCGA-A8-A07O_0_TCGA-A8-A07O-01A-01-BS1.073882c6-14ca-4b97-8992-fbfe1e9479c7.svs
# Selected OpenSlide level: 1
# Level dimensions: 22562 13268
# Level downsample: 4.000141852777395
# Patches saved so far: 1285
# Tissue patches seen so far: 1285
# Free disk after slide: 18.94 GB
# Downloading SVS 2/3: TCGA-A8-A07O-01A-01-TS1.19908799-8b6d-43fb-8555-2db3071f0d31.svs
# Processing slide: TCGA-A8-A07O_1_TCGA-A8-A07O-01A-01-TS1.19908799-8b6d-43fb-8555-2db3071f0d31.svs
# Selected OpenSlide level: 1
# Level dimensions: 34804 12247
# Level downsample: 4.000014366164809
# Patches saved so far: 2000
# Tissue patches seen so far: 2715
# Free disk after slide: 18.90 GB
# Downloading SVS 3/3: TCGA-A8-A07O-01Z-00-DX1.3D657129-F2A7-4BC1-A910-805FBDCE2212.svs
# Processing slide: TCGA-A8-A07O_2_TCGA-A8-A07O-01Z-00-DX1.3D657129-F2A7-4BC1-A910-805FBDCE2212.svs
# Selected OpenSlide level: 1
# Level dimensions: 10560 14656
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 3261
# Free disk after slide: 18.90 GB
# Finished TCGA-A8-A07O: success, saved 2000 patches.
# Free disk after patient: 18.90 GB
#
# ================================================================================
# Patient 22/15: TCGA-A8-A07P | BRCA_LumA
# Free disk before patient: 18.90 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A07P-01A-01-BS1.4bb95702-b8db-403d-9f30-1519eb9c7b11.svs
# Processing slide: TCGA-A8-A07P_0_TCGA-A8-A07P-01A-01-BS1.4bb95702-b8db-403d-9f30-1519eb9c7b11.svs
# Selected OpenSlide level: 1
# Level dimensions: 15121 6841
# Level downsample: 4.000099199788374
# Patches saved so far: 349
# Tissue patches seen so far: 349
# Free disk after slide: 18.88 GB
# Downloading SVS 2/3: TCGA-A8-A07P-01A-01-TS1.26774e35-740d-4849-b1bb-b89bbc1667d4.svs
# Processing slide: TCGA-A8-A07P_1_TCGA-A8-A07P-01A-01-TS1.26774e35-740d-4849-b1bb-b89bbc1667d4.svs
# Selected OpenSlide level: 1
# Level dimensions: 18002 5774
# Level downsample: 4.0002009648545
# Patches saved so far: 801
# Tissue patches seen so far: 801
# Free disk after slide: 18.85 GB
# Downloading SVS 3/3: TCGA-A8-A07P-01Z-00-DX1.2C7C75EF-EEE2-4A42-994C-A1A40850C87A.svs
# Processing slide: TCGA-A8-A07P_2_TCGA-A8-A07P-01Z-00-DX1.2C7C75EF-EEE2-4A42-994C-A1A40850C87A.svs
# Selected OpenSlide level: 1
# Level dimensions: 6848 10048
# Level downsample: 4.0
# Patches saved so far: 1163
# Tissue patches seen so far: 1163
# Free disk after slide: 18.83 GB
# Finished TCGA-A8-A07P: success, saved 1163 patches.
# Free disk after patient: 18.83 GB
#
# ================================================================================
# Patient 23/15: TCGA-A8-A07U | BRCA_Basal
# Free disk before patient: 18.83 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A07U-01A-01-MS1.92764161-0edd-431b-a770-259c8e240364.svs
# Processing slide: TCGA-A8-A07U_0_TCGA-A8-A07U-01A-01-MS1.92764161-0edd-431b-a770-259c8e240364.svs
# Selected OpenSlide level: 1
# Level dimensions: 27291 6190
# Level downsample: 4.000179871946754
# Patches saved so far: 605
# Tissue patches seen so far: 605
# Free disk after slide: 18.79 GB
# Downloading SVS 2/3: TCGA-A8-A07U-01A-01-TS1.f7ef0926-a88e-4ad1-88a4-2369a3b8e5dd.svs
# Processing slide: TCGA-A8-A07U_1_TCGA-A8-A07U-01A-01-TS1.f7ef0926-a88e-4ad1-88a4-2369a3b8e5dd.svs
# Selected OpenSlide level: 1
# Level dimensions: 22322 6049
# Level downsample: 4.000232514860977
# Patches saved so far: 1015
# Tissue patches seen so far: 1015
# Free disk after slide: 18.77 GB
# Downloading SVS 3/3: TCGA-A8-A07U-01Z-00-DX1.69D356C3-C7FC-47E9-B753-BE421263343F.svs
# Processing slide: TCGA-A8-A07U_2_TCGA-A8-A07U-01Z-00-DX1.69D356C3-C7FC-47E9-B753-BE421263343F.svs
# Selected OpenSlide level: 1
# Level dimensions: 12480 27072
# Level downsample: 4.0
# Patches saved so far: 1990
# Tissue patches seen so far: 1990
# Free disk after slide: 18.70 GB
# Finished TCGA-A8-A07U: success, saved 1990 patches.
# Free disk after patient: 18.70 GB
#
# ================================================================================
# Patient 24/15: TCGA-A8-A07W | BRCA_LumB
# Free disk before patient: 18.70 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A07W-01A-01-BSA.0f13b36e-14b4-4e59-8800-2e8d86b08079.svs
# Processing slide: TCGA-A8-A07W_0_TCGA-A8-A07W-01A-01-BSA.0f13b36e-14b4-4e59-8800-2e8d86b08079.svs
# Selected OpenSlide level: 1
# Level dimensions: 31203 10180
# Level downsample: 4.000146304127853
# Patches saved so far: 647
# Tissue patches seen so far: 647
# Free disk after slide: 18.67 GB
# Downloading SVS 2/3: TCGA-A8-A07W-01A-01-TSA.eae41004-b3f5-4528-9e95-cbda9ea764c1.svs
# Processing slide: TCGA-A8-A07W_1_TCGA-A8-A07W-01A-01-TSA.eae41004-b3f5-4528-9e95-cbda9ea764c1.svs
# Selected OpenSlide level: 1
# Level dimensions: 23763 6383
# Level downsample: 4.000156666144447
# Patches saved so far: 1045
# Tissue patches seen so far: 1045
# Free disk after slide: 18.65 GB
# Downloading SVS 3/3: TCGA-A8-A07W-01Z-00-DX1.5970CF33-D675-4AF4-800F-7182AA1A44A6.svs
# Processing slide: TCGA-A8-A07W_2_TCGA-A8-A07W-01Z-00-DX1.5970CF33-D675-4AF4-800F-7182AA1A44A6.svs
# Selected OpenSlide level: 1
# Level dimensions: 15360 26816
# Level downsample: 4.0
# Patches saved so far: 1901
# Tissue patches seen so far: 1901
# Free disk after slide: 18.59 GB
# Finished TCGA-A8-A07W: success, saved 1901 patches.
# Free disk after patient: 18.59 GB
#
# ================================================================================
# Patient 25/15: TCGA-A8-A07Z | BRCA_LumA
# Free disk before patient: 18.59 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A07Z-01A-01-BS1.9ea011c8-570d-479f-9023-54ddc5fe1e04.svs
# Processing slide: TCGA-A8-A07Z_0_TCGA-A8-A07Z-01A-01-BS1.9ea011c8-570d-479f-9023-54ddc5fe1e04.svs
# Selected OpenSlide level: 1
# Level dimensions: 16278 7722
# Level downsample: 4.0002216490421425
# Patches saved so far: 409
# Tissue patches seen so far: 409
# Free disk after slide: 18.57 GB
# Downloading SVS 2/3: TCGA-A8-A07Z-01A-01-TS1.3f1c6bb6-4c45-41ab-96cd-8b9003751009.svs
# Processing slide: TCGA-A8-A07Z_1_TCGA-A8-A07Z-01A-01-TS1.3f1c6bb6-4c45-41ab-96cd-8b9003751009.svs
# Selected OpenSlide level: 1
# Level dimensions: 15800 6257
# Level downsample: 4.00015982100048
# Patches saved so far: 685
# Tissue patches seen so far: 685
# Free disk after slide: 18.56 GB
# Downloading SVS 3/3: TCGA-A8-A07Z-01Z-00-DX1.713945D9-6855-456D-87FB-EF8AF8980F51.svs
# Processing slide: TCGA-A8-A07Z_2_TCGA-A8-A07Z-01Z-00-DX1.713945D9-6855-456D-87FB-EF8AF8980F51.svs
# Selected OpenSlide level: 1
# Level dimensions: 7616 13888
# Level downsample: 4.0
# Patches saved so far: 1250
# Tissue patches seen so far: 1250
# Free disk after slide: 18.52 GB
# Finished TCGA-A8-A07Z: success, saved 1250 patches.
# Free disk after patient: 18.52 GB
#
# ================================================================================
# Patient 26/15: TCGA-A8-A081 | BRCA_LumB
# Free disk before patient: 18.52 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A081-01A-01-BS1.e32b7065-c27c-48dc-bfc1-97ec920ee1a4.svs
# Processing slide: TCGA-A8-A081_0_TCGA-A8-A081-01A-01-BS1.e32b7065-c27c-48dc-bfc1-97ec920ee1a4.svs
# Selected OpenSlide level: 1
# Level dimensions: 22562 14723
# Level downsample: 4.000168364877816
# Patches saved so far: 532
# Tissue patches seen so far: 532
# Free disk after slide: 18.49 GB
# Downloading SVS 2/3: TCGA-A8-A081-01A-01-TS1.83c4b643-47aa-4bfb-b116-0fd0146e4fc5.svs
# Processing slide: TCGA-A8-A081_1_TCGA-A8-A081-01A-01-TS1.83c4b643-47aa-4bfb-b116-0fd0146e4fc5.svs
# Selected OpenSlide level: 1
# Level dimensions: 24003 10412
# Level downsample: 4.0001440645409145
# Patches saved so far: 1206
# Tissue patches seen so far: 1206
# Free disk after slide: 18.45 GB
# Downloading SVS 3/3: TCGA-A8-A081-01Z-00-DX1.06D727F7-4B41-419B-A251-3D804235ACE5.svs
# Processing slide: TCGA-A8-A081_2_TCGA-A8-A081-01Z-00-DX1.06D727F7-4B41-419B-A251-3D804235ACE5.svs
# Selected OpenSlide level: 1
# Level dimensions: 7232 7872
# Level downsample: 4.0
# Patches saved so far: 1505
# Tissue patches seen so far: 1505
# Free disk after slide: 18.43 GB
# Finished TCGA-A8-A081: success, saved 1505 patches.
# Free disk after patient: 18.43 GB
#
# ================================================================================
# Patient 27/15: TCGA-A8-A082 | BRCA_LumB
# Free disk before patient: 18.43 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A082-01A-01-BS1.eb5e4053-9044-46f8-adeb-93d86318ec71.svs
# Processing slide: TCGA-A8-A082_0_TCGA-A8-A082-01A-01-BS1.eb5e4053-9044-46f8-adeb-93d86318ec71.svs
# Selected OpenSlide level: 1
# Level dimensions: 36244 9055
# Level downsample: 4.000138026996726
# Patches saved so far: 1600
# Tissue patches seen so far: 1600
# Free disk after slide: 18.34 GB
# Downloading SVS 2/3: TCGA-A8-A082-01A-01-TS1.3cad4a77-47a6-4658-becf-d8cffa161d3a.svs
# Processing slide: TCGA-A8-A082_1_TCGA-A8-A082-01A-01-TS1.3cad4a77-47a6-4658-becf-d8cffa161d3a.svs
# Selected OpenSlide level: 1
# Level dimensions: 24243 7670
# Level downsample: 4.0000651890482395
# Patches saved so far: 2000
# Tissue patches seen so far: 2376
# Free disk after slide: 18.32 GB
# Downloading SVS 3/3: TCGA-A8-A082-01Z-00-DX1.5F82E38D-0DFD-4C2C-BC05-8F0EFEFC507C.svs
# Processing slide: TCGA-A8-A082_2_TCGA-A8-A082-01Z-00-DX1.5F82E38D-0DFD-4C2C-BC05-8F0EFEFC507C.svs
# Selected OpenSlide level: 1
# Level dimensions: 20224 23104
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2933
# Free disk after slide: 18.31 GB
# Finished TCGA-A8-A082: success, saved 2000 patches.
# Free disk after patient: 18.31 GB
#
# ================================================================================
# Patient 28/15: TCGA-A8-A083 | BRCA_LumA
# Free disk before patient: 18.31 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A083-01A-01-BS1.c88095e4-de9c-4e38-ac8e-70ac290b1dfb.svs
# Processing slide: TCGA-A8-A083_0_TCGA-A8-A083-01A-01-BS1.c88095e4-de9c-4e38-ac8e-70ac290b1dfb.svs
# Selected OpenSlide level: 1
# Level dimensions: 25923 7388
# Level downsample: 4.000086965205626
# Patches saved so far: 405
# Tissue patches seen so far: 405
# Free disk after slide: 18.29 GB
# Downloading SVS 2/3: TCGA-A8-A083-01A-02-MS2.b47eda6e-54a6-4cfe-be0b-bbcb776be723.svs
# FAILED TCGA-A8-A083: ConnectionError(ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py", line 787, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py", line 534, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connection.py", line 565, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/http/client.py", line 1450, in getresponse
#     response.begin()
#   File "/usr/lib/python3.12/http/client.py", line 336, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/http/client.py", line 305, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/requests/adapters.py", line 667, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py", line 841, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/util/retry.py", line 474, in increment
#     raise reraise(type(error), error, _stacktrace)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/util/util.py", line 38, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py", line 787, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py", line 534, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connection.py", line 565, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/http/client.py", line 1450, in getresponse
#     response.begin()
#   File "/usr/lib/python3.12/http/client.py", line 336, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/http/client.py", line 305, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/tmp/ipykernel_16/1820722635.py", line 349, in <cell line: 0>
#     download_svs(file_id, svs_path)
#   File "/tmp/ipykernel_16/1820722635.py", line 224, in download_svs
#     with requests.get(url, stream=True, timeout=120) as response:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/requests/adapters.py", line 682, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Free disk after patient: 18.29 GB
#
# ================================================================================
# Patient 29/15: TCGA-A8-A086 | BRCA_LumA
# Free disk before patient: 18.29 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A086-01A-01-BSA.f75d10e3-5a89-4b4f-9b40-6bca77731bb2.svs
# Processing slide: TCGA-A8-A086_0_TCGA-A8-A086-01A-01-BSA.f75d10e3-5a89-4b4f-9b40-6bca77731bb2.svs
# Selected OpenSlide level: 1
# Level dimensions: 18002 11426
# Level downsample: 4.000159054229597
# Patches saved so far: 446
# Tissue patches seen so far: 446
# Free disk after slide: 18.27 GB
# Downloading SVS 2/3: TCGA-A8-A086-01A-01-TSA.a432a95f-5863-4ad9-a2eb-7f986c62e096.svs
# Processing slide: TCGA-A8-A086_1_TCGA-A8-A086-01A-01-TSA.a432a95f-5863-4ad9-a2eb-7f986c62e096.svs
# Selected OpenSlide level: 1
# Level dimensions: 21122 10975
# Level downsample: 4.000138460174636
# Patches saved so far: 993
# Tissue patches seen so far: 993
# Free disk after slide: 18.24 GB
# Downloading SVS 3/3: TCGA-A8-A086-01Z-00-DX1.E5FD8C53-2068-4018-B3C0-08EED253ACD2.svs
# Processing slide: TCGA-A8-A086_2_TCGA-A8-A086-01Z-00-DX1.E5FD8C53-2068-4018-B3C0-08EED253ACD2.svs
# Selected OpenSlide level: 1
# Level dimensions: 15488 24384
# Level downsample: 4.0
# Patches saved so far: 2000
# Tissue patches seen so far: 2071
# Free disk after slide: 18.17 GB
# Finished TCGA-A8-A086: success, saved 2000 patches.
# Free disk after patient: 18.17 GB
#
# ================================================================================
# Patient 30/15: TCGA-A8-A08A | BRCA_LumA
# Free disk before patient: 18.17 GB
# SVS files found: 3
# Downloading SVS 1/3: TCGA-A8-A08A-01A-01-BS1.db510b27-0937-42da-b559-6d65271401f1.svs
# Processing slide: TCGA-A8-A08A_0_TCGA-A8-A08A-01A-01-BS1.db510b27-0937-42da-b559-6d65271401f1.svs
# Selected OpenSlide level: 1
# Level dimensions: 28727 6755
# Level downsample: 4.000256868192072
# Patches saved so far: 864
# Tissue patches seen so far: 864
# Free disk after slide: 18.12 GB
# Downloading SVS 2/3: TCGA-A8-A08A-01A-01-TS1.e7bdf564-67d2-46dc-bd6a-439cdc74e163.svs
# FAILED TCGA-A8-A08A: ConnectionError(ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py", line 787, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py", line 534, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connection.py", line 565, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/http/client.py", line 1450, in getresponse
#     response.begin()
#   File "/usr/lib/python3.12/http/client.py", line 336, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/http/client.py", line 305, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/requests/adapters.py", line 667, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py", line 841, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/util/retry.py", line 474, in increment
#     raise reraise(type(error), error, _stacktrace)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/util/util.py", line 38, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py", line 787, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py", line 534, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connection.py", line 565, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/http/client.py", line 1450, in getresponse
#     response.begin()
#   File "/usr/lib/python3.12/http/client.py", line 336, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/http/client.py", line 305, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/tmp/ipykernel_16/1820722635.py", line 349, in <cell line: 0>
#     download_svs(file_id, svs_path)
#   File "/tmp/ipykernel_16/1820722635.py", line 224, in download_svs
#     with requests.get(url, stream=True, timeout=120) as response:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/requests/adapters.py", line 682, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Free disk after patient: 18.12 GB
#
# ================================================================================
# A8 batch 2 preprocessing finished.
# Patch output folder: /kaggle/working/patches/A8
# Log file: /kaggle/working/preprocessing_log.csv
#       patient_id  jpg_count
# 0   TCGA-A8-A07F       1558
# 1   TCGA-A8-A07G       1338
# 2   TCGA-A8-A07I       2000
# 3   TCGA-A8-A07J       2000
# 4   TCGA-A8-A07L       2000
# 5   TCGA-A8-A07O       2000
# 6   TCGA-A8-A07P       1163
# 7   TCGA-A8-A07U       1990
# 8   TCGA-A8-A07W       1901
# 9   TCGA-A8-A07Z       1250
# 10  TCGA-A8-A081       1505
# 11  TCGA-A8-A082       2000
# 12  TCGA-A8-A083        405
# 13  TCGA-A8-A086       2000
# 14  TCGA-A8-A08A        864
#       patient_id     subtype   status  patches_saved  tissue_patches_seen  \
# 0   TCGA-A8-A07F   BRCA_LumA  success           1558                 1558
# 1   TCGA-A8-A07G   BRCA_LumA  success           1338                 1338
# 2   TCGA-A8-A07I   BRCA_Her2  success           2000                 2167
# 3   TCGA-A8-A07J   BRCA_LumA  success           2000                 3264
# 4   TCGA-A8-A07L   BRCA_LumB  success           2000                 2512
# 5   TCGA-A8-A07O  BRCA_Basal  success           2000                 3261
# 6   TCGA-A8-A07P   BRCA_LumA  success           1163                 1163
# 7   TCGA-A8-A07U  BRCA_Basal  success           1990                 1990
# 8   TCGA-A8-A07W   BRCA_LumB  success           1901                 1901
# 9   TCGA-A8-A07Z   BRCA_LumA  success           1250                 1250
# 10  TCGA-A8-A081   BRCA_LumB  success           1505                 1505
# 11  TCGA-A8-A082   BRCA_LumB  success           2000                 2933
# 12  TCGA-A8-A083   BRCA_LumA   failed            405                  405
# 13  TCGA-A8-A086   BRCA_LumA  success           2000                 2071
# 14  TCGA-A8-A08A   BRCA_LumA   failed            864                  864
#
#     svs_files_found                                      error_message
# 0                 3                                                NaN
# 1                 3                                                NaN
# 2                 3                                                NaN
# 3                 4                                                NaN
# 4                 3                                                NaN
# 5                 3                                                NaN
# 6                 3                                                NaN
# 7                 3                                                NaN
# 8                 3                                                NaN
# 9                 3                                                NaN
# 10                3                                                NaN
# 11                3                                                NaN
# 12                3  ConnectionError(ProtocolError('Connection abor...
# 13                3                                                NaN
# 14                3  ConnectionError(ProtocolError('Connection abor...
